# %%
import pandas as pd
import seaborn as sns

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.inspection import DecisionBoundaryDisplay

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('encoded_df.csv')

# %%
df
# Out:
#      Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0     1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1     1     Florida State   47          Duquesne      7     Florida State
# 2     1          Illinois   38           Wyoming      6          Illinois
# 3     1            Nevada   23  New Mexico State     12            Nevada
# 4     1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
# ..   ..               ...  ...               ...    ...               ...
# 774  13     Virginia Tech   23           Liberty     22     Virginia Tech
# 775  13       Wake Forest   45          Syracuse     35       Wake Forest
# 776  13   (15) Washington   54          Colorado      7        Washington
# 777  13  Washington State   31           Arizona     20  Washington State
# 778  13         Wisconsin   15          Nebraska     14         Wisconsin
#
#                losers  home_rank  away_rank  home_team_code  away_team_code  \
# 0           Charlotte         99         99              32              37
# 1            Duquesne         99         99              34              49
# 2             Wyoming         99         99              42             224
# 3    New Mexico State         99         99              76             122
# 4         Idaho State         99         99              74              77
# ..                ...        ...        ...             ...             ...
# 774           Liberty         99         99              51             210
# 775          Syracuse         99         99             124             182
# 776          Colorado         15         99             125              44
# 777           Arizona         99         99               5             214
# 778          Nebraska         99         99              71             222
#
#      home_results  win_rank  lose_rank  day_code  hours  null  half  quart  \
# 0               0        99         99         5     19     1     0      0
# 1               0        99         99         5     17     1     0      0
# 2               0        99         99         5     16     1     0      0
# 3               1        99         99         5     22     1     0      0
# 4               0        99         99         5     15     0     1      0
# ..            ...       ...        ...       ...    ...   ...   ...    ...
# 774             1        99         99         5     12     1     0      0
# 775             0        99         99         5     20     1     0      0
# 776             0        15         99         5     21     1     0      0
# 777             1        99         99         5     14     1     0      0
# 778             1        99         99         5     12     1     0      0
#
#      three_quart
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 774            0
# 775            0
# 776            0
# 777            0
# 778            0
#
# [779 rows x 20 columns]

# %%
df = df.drop(df[df.home_results > 2].index)

# %%
df = df.drop(columns=['Winner', 'Pts', 'Loser', 'Pts.1', 'winners', 
                      'losers', 'win_rank', 'lose_rank', 'hours', 
                      'null', 'half', 'quart', 'three_quart'])

# %%
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)



# LogisticRegression(C=4.432, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)


# #Final logistic regression model parameters for deployment

# print(final_rf)

# LogisticRegression(C=4.432, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
clf = LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=1000,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
                   warm_start=False)

# %%
X = df.drop(columns=['home_results'])
y = df['home_results']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.30, random_state=0)

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=123)

# %%
predictions = clf.predict(X_test)

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[143,   5],
#        [ 64,  19]])

# %%
143+5+64+19
# Out:
# 231

# %%
64/231
# Out:
# 0.27705627705627706

# %%
143/231
# Out:
# 0.6190476190476191
