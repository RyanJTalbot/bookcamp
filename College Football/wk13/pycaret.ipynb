# %%
from pycaret.classification import *

# %%
from pycaret.regression import *
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('encoded_df.csv')

# %%
df1 = df.drop(columns=['Winner', 'Loser', 'winners', 'losers', 
                       'day_code', 'hours', 'null', 'half', 
                      'quart', 'three_quart'])

# %%
df1
# Out:
#      Wk  Pts  Pts.1  home_rank  away_rank  home_team_code  away_team_code  \
# 0     1   43     13         99         99              32              37
# 1     1   47      7         99         99              34              49
# 2     1   38      6         99         99              42             224
# 3     1   23     12         99         99              76             122
# 4     1   52     21         99         99              74              77
# ..   ..  ...    ...        ...        ...             ...             ...
# 773  13   23     22         99         99              51             210
# 774  13   45     35         99         99             124             182
# 775  13   54      7         15         99             125              44
# 776  13   31     20         99         99               5             214
# 777  13   15     14         99         99              71             222
#
#      home_results  win_rank  lose_rank
# 0               0        99         99
# ...

# %%
data = df1.drop(columns='Pts.1')

# %%
s = setup(data, target = 'Pts', fold_shuffle=True, imputation_type='iterative',
             remove_multicollinearity = True, session_id = 123)
# Out:
# <style type="text/css">
# #T_9ad0c_row40_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9ad0c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ad0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ad0c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9ad0c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9ad0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ad0c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9ad0c_row1_col1" class="data row1 col1" >Pts</td>
#     </tr>
#     <tr>
#       <th id="T_9ad0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9ad0c_row2_col0" class="data row2 col0" >Original Data</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_2929c_ th {
#   text-align: left;
# }
# ...

# %%
# !pip install autoviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 5.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 13.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 12.8 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 5.3 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.7 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 4.3 MB/s eta 0:00:00
# ...
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# ...

# %%
omp = create_model('omp')
# Out:
# <style type="text/css">
# #T_ef3ea_row10_col0, #T_ef3ea_row10_col1, #T_ef3ea_row10_col2, #T_ef3ea_row10_col3, #T_ef3ea_row10_col4, #T_ef3ea_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ef3ea_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef3ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef3ea_row0_col0" class="data row0 col0" >9.6028</td>
#       <td id="T_ef3ea_row0_col1" class="data row0 col1" >149.5546</td>
#       <td id="T_ef3ea_row0_col2" class="data row0 col2" >12.2292</td>
# ...

# %%
tuned_dt = tune_model(omp, optimize = 'MAE')
# Out:
# <style type="text/css">
# #T_567f4_row10_col0, #T_567f4_row10_col1, #T_567f4_row10_col2, #T_567f4_row10_col3, #T_567f4_row10_col4, #T_567f4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_567f4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_567f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_567f4_row0_col0" class="data row0 col0" >10.1624</td>
#       <td id="T_567f4_row0_col1" class="data row0 col1" >165.1367</td>
#       <td id="T_567f4_row0_col2" class="data row0 col2" >12.8506</td>
# ...

# %%
print(tuned_dt)
# Out:
# OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=9,
#                           normalize=False, precompute='auto', tol=None)

# %%
from sklearn.linear_model import OrthogonalMatchingPursuit

# %%
# from sklearn.linear_model import OrthogonalMatchingPursuit

# reg = OrthogonalMatchingPursuit(fit_intercept=True, n_nonzero_coefs=9,
#                           normalize=False, precompute='auto', tol=None)
# reg.fit(X_train, y_train)
# reg.predict(X_test)
