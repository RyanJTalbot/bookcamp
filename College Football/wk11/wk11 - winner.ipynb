# %% [markdown]
# # change winner/loser rank to home/away rank

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('wk12.csv')

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 644  11   5-Nov-22   7:30 PM  Sat         (12) Utah   45        NaN
# 645  11   5-Nov-22   3:30 PM  Sat        Utah State   27        NaN
# 646  11   5-Nov-22   3:30 PM  Sat  Washington State   52          @
# 647  11   5-Nov-22  12:00 PM  Sat  Western Kentucky   59          @
# 648  11   5-Nov-22  12:00 PM  Sat         Wisconsin   23        NaN
#
#                 Loser  Pts.1
# 0           Charlotte     13
# 1            Duquesne      7
# 2             Wyoming      6
# 3    New Mexico State     12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Wk          649 non-null    int64
#  1   Date        649 non-null    object
#  2   Time        647 non-null    object
#  3   Day         649 non-null    object
#  4   Winner      649 non-null    object
#  5   Pts         649 non-null    int64
#  6   Unnamed: 6  229 non-null    object
#  7   Loser       649 non-null    object
#  8   Pts.1       649 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 45.8+ KB

# %%
location = df['Unnamed: 6']
home = []

for index, row in df.iterrows():
    location = (row['Unnamed: 6'])
    if (location == 'N'):
        home.append('Neutral')
    elif (location == '@'):
        home.append(row['Loser'])
    else:
        home.append(row['Winner'])

# %%
df['home_team'] = home

# %%
away = []
for index, row in df.iterrows():
    if (row['home_team'] == row['Winner']):
        away.append(row['Loser'])
    elif (row['home_team'] == row['Loser']):
        away.append(row['Winner'])
    else:
        away.append('neutral')

# %%
df['away'] = away

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 644  11   5-Nov-22   7:30 PM  Sat         (12) Utah   45        NaN
# 645  11   5-Nov-22   3:30 PM  Sat        Utah State   27        NaN
# 646  11   5-Nov-22   3:30 PM  Sat  Washington State   52          @
# 647  11   5-Nov-22  12:00 PM  Sat  Western Kentucky   59          @
# 648  11   5-Nov-22  12:00 PM  Sat         Wisconsin   23        NaN
#
#                 Loser  Pts.1         home_team              away
# 0           Charlotte     13  Florida Atlantic         Charlotte
# ...

# %%
df['Winner'].value_counts()
# Out:
# Coastal Carolina             8
# San Jose State               7
# Troy                         7
# South Alabama                7
# Texas-San Antonio            7
#                             ..
# (13) North Carolina State    1
# (24) Texas A&M               1
# (21) Texas                   1
# (15) Tennessee               1
# (10) UCLA                    1
# Name: Winner, Length: 243, dtype: int64

# %%
home = df['home_team']

home_rank = []

for i in home:
    if (i[2] == ")"):
        home_rank.append(i[1:2])
        if(i[1] == "("):
            home_rank.append(i[1:3])
    else:
        home_rank.append(99)

# %%
away = df['away']

away_rank = []

for i in away:
    if (i[2] == ")"):
        away_rank.append(i[1:2])
        if(i[1] == "("):
            away_rank.append(i[1:3])
    else:
        away_rank.append(99)

# %%
df['home_rank'] = home_rank

# %%
df['away_rank'] = away_rank

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 644  11   5-Nov-22   7:30 PM  Sat         (12) Utah   45        NaN
# 645  11   5-Nov-22   3:30 PM  Sat        Utah State   27        NaN
# 646  11   5-Nov-22   3:30 PM  Sat  Washington State   52          @
# 647  11   5-Nov-22  12:00 PM  Sat  Western Kentucky   59          @
# 648  11   5-Nov-22  12:00 PM  Sat         Wisconsin   23        NaN
#
#                 Loser  Pts.1         home_team              away home_rank  \
# ...

# %%
df["home_team_code"] = df["home_team"].astype("category").cat.codes

# %%
df["away_team_code"] = df["away"].astype("category").cat.codes

# %%
homes = df['home_team']

# %%
df1 = df.copy()

# %%
df1
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 644  11   5-Nov-22   7:30 PM  Sat         (12) Utah   45        NaN
# 645  11   5-Nov-22   3:30 PM  Sat        Utah State   27        NaN
# 646  11   5-Nov-22   3:30 PM  Sat  Washington State   52          @
# 647  11   5-Nov-22  12:00 PM  Sat  Western Kentucky   59          @
# 648  11   5-Nov-22  12:00 PM  Sat         Wisconsin   23        NaN
#
#                 Loser  Pts.1         home_team              away home_rank  \
# ...

# %%
df1[df1['Loser'] == 'Arkansas']
# Out:
#      Wk      Date      Time  Day                  Winner  Pts Unnamed: 6  \
# 406   7  8-Oct-22  12:00 PM  Sat  (23) Mississippi State   40        NaN
# 613  11  5-Nov-22   4:00 PM  Sat            (23) Liberty   21          @
#
#         Loser  Pts.1               home_team          away home_rank  \
# 406  Arkansas     17  (23) Mississippi State      Arkansas        99
# 613  Arkansas     19                Arkansas  (23) Liberty        99
#
#     away_rank  home_team_code  away_team_code
# 406        99              71              92
# 613        99             112              50

# %%
home_results = []
for index, row in df1.iterrows():
    if (row['home_team'] == row['Winner']):
        home_results.append(0)
    elif (row['home_team'] == row['Loser']):
        home_results.append(1)
    else:
        home_results.append(3)

# %%
df1.shape
# Out:
# (649, 15)

# %%
df1['home_results'] = home_results

# %%
df1.shape
# Out:
# (649, 16)

# %%
wins = df1['Winner']

# %%
winners = []
for i in wins:
    if (i[2] == ")"):
        winners.append(i[1:2])
        if(i[1] == "("):
            winners.append(i[1:3])
    else:
        winners.append(99)

# %%
len(winners)
# Out:
# 649

# %%
df1['win_rank'] = winners

# %%
lose = df1['Loser']

# %%
losers = []
for i in lose:
    if (i[2] == ")"):
        losers.append(i[1:2])
        if(i[1] == "("):
            losers.append(i[1:3])
    else:
        losers.append(99)

# %%
len(losers)
# Out:
# 649

# %%
df1['lose_rank'] = losers

# %%
df1 = df1.drop(columns=['Unnamed: 6'])

# %%
df1
# Out:
#      Wk       Date      Time  Day            Winner  Pts             Loser  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43         Charlotte
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47          Duquesne
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38           Wyoming
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23  New Mexico State
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52       Idaho State
# ..   ..        ...       ...  ...               ...  ...               ...
# 644  11   5-Nov-22   7:30 PM  Sat         (12) Utah   45           Arizona
# 645  11   5-Nov-22   3:30 PM  Sat        Utah State   27        New Mexico
# 646  11   5-Nov-22   3:30 PM  Sat  Washington State   52          Stanford
# 647  11   5-Nov-22  12:00 PM  Sat  Western Kentucky   59         Charlotte
# 648  11   5-Nov-22  12:00 PM  Sat         Wisconsin   23          Maryland
#
# ...

# %%
df1 = df1.drop(columns=['home_team', 'away'])

# %%
df1
# Out:
#      Wk       Date      Time  Day            Winner  Pts             Loser  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43         Charlotte
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47          Duquesne
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38           Wyoming
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23  New Mexico State
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52       Idaho State
# ..   ..        ...       ...  ...               ...  ...               ...
# 644  11   5-Nov-22   7:30 PM  Sat         (12) Utah   45           Arizona
# 645  11   5-Nov-22   3:30 PM  Sat        Utah State   27        New Mexico
# 646  11   5-Nov-22   3:30 PM  Sat  Washington State   52          Stanford
# 647  11   5-Nov-22  12:00 PM  Sat  Western Kentucky   59         Charlotte
# 648  11   5-Nov-22  12:00 PM  Sat         Wisconsin   23          Maryland
#
# ...

# %%
dates = df1["Date"]

# %%
len(dates)
# Out:
# 649

# %%
month_num = []

for i in dates:
    if(i[1] =='-'):
        if(i[2:5] == 'Sep'):
            month_num.append('9')
        elif(i[2:5] == 'Oct'):
            month_num.append('10')
        elif(i[2:5] == 'Nov'):
            month_num.append('11')
        elif(i[2:5] == 'Aug'):
            month_num.append('8')
    elif(i[2] =='-'):
        if(i[3:6] == 'Aug'):
            month_num.append('8')
        elif(i[3:6] == 'Sep'):
            month_num.append('9')
        elif(i[3:6] == 'Oct'):
            month_num.append('10')
        elif(i[3:6] == 'Nov'):
            month_num.append('11')

# %%
len(month_num)
# Out:
# 649

# %%
dates
# Out:
# 0      27-Aug-22
# 1      27-Aug-22
# 2      27-Aug-22
# 3      27-Aug-22
# 4      27-Aug-22
#          ...
# 644     5-Nov-22
# 645     5-Nov-22
# 646     5-Nov-22
# 647     5-Nov-22
# 648     5-Nov-22
# Name: Date, Length: 649, dtype: object

# %%
days = []

for i in dates: 
    if(i[1] == '-'):
        days.append(i[0])
    if(i[2] == "-"):
        days.append(i[0:2])

# %%
len(days)
# Out:
# 649

# %%
years = []

for i in dates: 
    years.append('2022')
        
#         print(f'Hello {name}! This is {program}')

# %%
df1['months']= month_num
df1['years'] = years
df1['days'] = days

# %%
df1["dates"] = df1[
    'years'].astype(str) +"-"+ df1['months'].astype(str) + "-" + df1['days'].astype(str)

# %%
df1 = df1.drop(columns=['Date'])

# %%
df1 = df1.drop(columns=['months', 'years', 'days', 'Day'])

# %%
df1
# Out:
#      Wk      Time            Winner  Pts             Loser  Pts.1 home_rank  \
# 0     1   7:00 PM  Florida Atlantic   43         Charlotte     13        99
# 1     1   5:00 PM     Florida State   47          Duquesne      7        99
# 2     1   4:00 PM          Illinois   38           Wyoming      6        99
# 3     1  10:00 PM            Nevada   23  New Mexico State     12        99
# 4     1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21        99
# ..   ..       ...               ...  ...               ...    ...       ...
# 644  11   7:30 PM         (12) Utah   45           Arizona     20        99
# 645  11   3:30 PM        Utah State   27        New Mexico     10        99
# 646  11   3:30 PM  Washington State   52          Stanford     14        99
# 647  11  12:00 PM  Western Kentucky   59         Charlotte      7        99
# 648  11  12:00 PM         Wisconsin   23          Maryland     10        99
#
# ...

# %%
df1["dates"].value_counts()
# Out:
# 2022-9-10     80
# 2022-9-17     69
# 2022-9-24     60
# 2022-9-3      56
# 2022-10-1     55
# 2022-10-8     52
# 2022-11-5     51
# 2022-10-22    49
# 2022-10-15    48
# 2022-10-29    42
# 2022-9-1      16
# 2022-8-27     11
# 2022-9-2       8
# 2022-9-30      5
# 2022-10-7      4
# 2022-9-22      3
# 2022-11-4      3
# 2022-10-27     3
# 2022-9-23      3
# 2022-9-16      2
# 2022-10-21     2
# 2022-9-29      2
# 2022-11-3      2
# 2022-11-2      2
# 2022-11-1      2
# 2022-10-28     2
# 2022-9-9       2
# 2022-9-4       2
# 2022-10-20     2
# 2022-10-14     2
# 2022-10-13     2
# 2022-10-2      1
# 2022-10-5      1
# 2022-9-18      1
# 2022-10-30     1
# 2022-9-5       1
# 2022-10-12     1
# 2022-10-19     1
# Name: dates, dtype: int64

# %%
df1['dates'] = pd.to_datetime(df1['dates'])

# %%
df1["day_code"] = df1["dates"].dt.dayofweek

# %%
df1
# Out:
#      Wk      Time            Winner  Pts             Loser  Pts.1 home_rank  \
# 0     1   7:00 PM  Florida Atlantic   43         Charlotte     13        99
# 1     1   5:00 PM     Florida State   47          Duquesne      7        99
# 2     1   4:00 PM          Illinois   38           Wyoming      6        99
# 3     1  10:00 PM            Nevada   23  New Mexico State     12        99
# 4     1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21        99
# ..   ..       ...               ...  ...               ...    ...       ...
# 644  11   7:30 PM         (12) Utah   45           Arizona     20        99
# 645  11   3:30 PM        Utah State   27        New Mexico     10        99
# 646  11   3:30 PM  Washington State   52          Stanford     14        99
# 647  11  12:00 PM  Western Kentucky   59         Charlotte      7        99
# 648  11  12:00 PM         Wisconsin   23          Maryland     10        99
#
# ...

# %%
df1.corr().loc[['home_results']]
# Out:
#                    Wk       Pts     Pts.1  home_team_code  away_team_code  \
# home_results  0.13739 -0.127412  0.110057        0.138384        0.062202
#
#               home_results  day_code
# home_results           1.0  0.038636

# %%
df1.cov()
# Out:
#                        Wk         Pts       Pts.1  home_team_code  \
# Wk               8.822467   -7.865505    4.058221        2.025840
# Pts             -7.865505  156.232162   21.533951      -54.082915
# Pts.1            4.058221   21.533951  108.797138       -1.803171
# home_team_code   2.025840  -54.082915   -1.803171     3124.223796
# away_team_code -25.725922  -14.897442 -106.522026      247.501201
# home_results     0.237740   -0.927783    0.668771        4.506185
# day_code        -0.000999    0.199650    0.052609       -1.342217
#
#                 away_team_code  home_results  day_code
# Wk                  -25.725922      0.237740 -0.000999
# Pts                 -14.897442     -0.927783  0.199650
# Pts.1              -106.522026      0.668771  0.052609
# home_team_code      247.501201      4.506185 -1.342217
# away_team_code     5971.249282      2.800201 -1.308411
# home_results          2.800201      0.339392  0.013677
# ...

# %%
df2 = df1.copy()

# %%
df2.head()
# Out:
#    Wk      Time            Winner  Pts             Loser  Pts.1 home_rank  \
# 0   1   7:00 PM  Florida Atlantic   43         Charlotte     13        99
# 1   1   5:00 PM     Florida State   47          Duquesne      7        99
# 2   1   4:00 PM          Illinois   38           Wyoming      6        99
# 3   1  10:00 PM            Nevada   23  New Mexico State     12        99
# 4   1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21        99
#
#   away_rank  home_team_code  away_team_code  home_results win_rank lose_rank  \
# 0        99             136             117             0       99        99
# 1        99             138             128             0       99        99
# 2        99             145             289             0       99        99
# 3        99             176             197             1       99        99
# 4        99             174             154             0       99        99
#
#        dates  day_code
# 0 2022-08-27         5
# ...

# %%
df2 = df2.drop(columns=['Winner', 'Loser', 'Time', 'dates'])

# %%
df2
# Out:
#      Wk  Pts  Pts.1 home_rank away_rank  home_team_code  away_team_code  \
# 0     1   43     13        99        99             136             117
# 1     1   47      7        99        99             138             128
# 2     1   38      6        99        99             145             289
# 3     1   23     12        99        99             176             197
# 4     1   52     21        99        99             174             154
# ..   ..  ...    ...       ...       ...             ...             ...
# 644  11   45     20        99        99              12              90
# 645  11   27     10        99        99             215             200
# 646  11   52     14        99        99             199             279
# 647  11   59      7        99        99             126             284
# 648  11   23     10        99        99             224             180
#
#      home_results win_rank lose_rank  day_code
# 0               0       99        99         5
# ...

# %%
df3 = df2.drop(columns=['Pts', 'Pts.1', 'win_rank', 'lose_rank'])

# %%
# df3.to_csv('wk11_final.csv', index=False)

# %%
df3

# %%
y = df3['home_results']
X = df3.drop(columns=['home_results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.05, random_state=2)

# %%
X_train

# %%
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(
    DecisionTreeRegressor(max_depth=5), n_estimators=299, random_state=42
)

# %%
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)

y_1 = regr_1.predict(X_train)
y_2 = regr_2.predict(X_train)

# %%
test_pred = regr_2.predict(X_test)

# %%
print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
# print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))

# %%
data = {'y_test': y_test, 'y_pred': y_train}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)
new_df

# %%
df3.head()

# %%
la = [[12, 99, 7, 112, 174, 5]]
lsu = pd.DataFrame(la, columns=['Wk', 'home_rank', 'away_rank', 'home_team_code', 'away_team_code', 'day_code'])
lsu

# arkansas home team code = 112
# lsu away team code = 174
# ga = [[11, 52, 1, 2, 1]]
# uga = pd.DataFrame(ga, columns=['Wk', 'Pts', 'home_results', 'win_rank', 'lose_rank'])
# uga

# %%
test_pred1 = regr_1.predict(lsu)
test_pred2 = regr_2.predict(lsu)

print(test_pred1)
print(test_pred2)

# %%
df[df['away_team_code'] == 174]

# %%
df[df['home_team_code'] == 112]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
y = df3['home_results']
X = df3.drop(columns=['home_results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.05, random_state=2)

# %%
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(X_train, y_train)

# %%
test_pred = regr.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
# print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))

# %%
data = {'y_test': y_test, 'y_pred': test_pred}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)
new_df

# %%
regr.predict(lsu)

# %% [markdown]
# lsu losses - array([0.42911376])

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.datasets import make_regression

# %%
y = df3['home_results']
X = df3.drop(columns=['home_results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.05, random_state=2)

# %%
regr = AdaBoostRegressor(random_state=0, n_estimators=100)
regr.fit(X_train, y_train)

# %%
test_pred = regr.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
# print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))

# %%
data = {'y_test': y_test, 'y_pred': test_pred}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)
new_df

# %%
regr.predict(lsu)

# %% [markdown]
# lsu loses  - array([0.47887324])

# %% [markdown]
# ## three predictions that lsu loses: .47976879, .42911376, .47887324
# ## two that lsu wins: .56375839, .61007972

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor

# %%
y = df3['home_results']
X = df3.drop(columns=['home_results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.05, random_state=2)

# %%
reg = GradientBoostingRegressor(random_state=0)
reg.fit(X_train, y_train)

# %%
test_pred = reg.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
# print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))

# %%
data = {'y_test': y_test, 'y_pred': test_pred}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)
new_df

# %%
reg.predict(lsu)

# %% [markdown]
# lsu wins array([0.61007972])

# %% [markdown]
# # GradientBoostingRegressor
#
# - RMSE: 0.44658150644728895
# - R Squared: -0.3406466705549074
# - MSE TEST: 0.19943504190072997
# - MAE TEST: 0.3748675339998306
#
#
# # AdaBoostRegressor
# - RMSE: 0.43877958939402933
# - R Squared: -0.29421282757355294
# - MSE TEST: 0.19252752806879297
# - MAE TEST: 0.38935265270569114
#
#
# # RandomForestRegressor
# - RMSE: 0.4086865469553357
# - R Squared: -0.12277710739640968
# - MSE TEST: 0.1670246936622758
# - MAE TEST: 0.3875800809707881
#
#
# # DecisionTreeRegressor
# - RMSE: 0.4569672653828224
# - R Squared: -0.40372827096700226
# - MSE TEST: 0.20881908163145485
# - MAE TEST: 0.42987322941205286

# %% [markdown]
# ## RMSE values between 0.2 and 0.5 shows that the model can relatively predict the data accurately. In addition, Adjusted R-squared more than 0.75 is a very good value for showing the accuracy. In some cases, Adjusted R-squared of 0.4 or more is acceptable as well.
#
# DecisiontreeRegressor= .4569

# %% [markdown]
# ## In other fields, the standards for a good R-Squared reading can be much higher, such as 0.9 or above. In finance, an R-Squared above 0.7 would generally be seen as showing a high level of correlation, whereas a measure below 0.4 would show a low correlation.
#
# RandomForestRegressor = R Squared: -0.12277710739640968

# %% [markdown]
# ## There is no correct value for MSE. Simply put, the lower the value the better and 0 means the model is perfect. Since there is no correct answer, the MSE's basic value is in selecting one prediction model over another.
#
# RandomForestRegressor = MSE TEST: 0.1670246936622758

# %% [markdown]
# ## the closer the value of the MAE is to 0, the better.
# GradientBoostingRegressor = MAE TEST: 0.3748675339998306
