# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('lsu.csv')

# %%
df.head()
# Out:
#       Date team location           Opponent    results  pass_Cmp  pass_Att  \
# 0   9/4/22  lsu        N      Florida State  L (23-24)        20        33
# 1  9/10/22  lsu      NaN           Southern  W (65-17)         9        17
# 2  9/17/22  lsu      NaN  Mississippi State  W (31-16)        24        42
# 3  9/24/22  lsu      NaN         New Mexico   W (38-0)         4         6
# 4  10/1/22  lsu        @             Auburn  W (21-17)        19        39
#
#    pass_Pct  pass_Yds  pass_TD  ...  def_total_Avg  def_fd_Pass  def_fd_Rush  \
# 0      60.6       260        2  ...            5.4           14            8
# 1      52.9        61        0  ...            7.9           13           10
# 2      57.1       214        1  ...            5.6           11            8
# 3      66.7        51        0  ...            7.9           16           11
# 4      48.7       337        2  ...            3.6            2           14
#
#    def_Pen  def_pen_Tot  def_pen_No  def_turnovers_Yds  def_Fum  def_Int  \
# 0        3           25           4                 45        2        0
# 1        0           23           6                 40        0        2
# 2        1           20           7                 39        1        0
# 3        1           28           5                 60        1        0
# 4        3           19          10                 94        1        0
#
#    def_Tot
# 0        2
# 1        2
# 2        1
# 3        1
# 4        1
#
# [5 rows x 47 columns]

# %%
# df['Opponent'].value_counts()

# %%
df['team'].value_counts()
# Out:
# ole miss      9
# lsu           8
# tennessee     8
# alabama       8
# florida       8
# aubrun        8
# miss_state    8
# kentucky      8
# Arkansas      8
# texas_am      8
# Name: team, dtype: int64

# %%
res = df['results']

# %%
lsu_w = []

for i in res:
    if (i[0] == 'L'):
        lsu_w.append(0)
    else: 
        lsu_w.append(1)

# %%
df1 = df.copy()

# %%
df1['results'] = lsu_w

# %%
df1.head()
# Out:
#       Date team location           Opponent  results  pass_Cmp  pass_Att  \
# 0   9/4/22  lsu        N      Florida State        0        20        33
# 1  9/10/22  lsu      NaN           Southern        1         9        17
# 2  9/17/22  lsu      NaN  Mississippi State        1        24        42
# 3  9/24/22  lsu      NaN         New Mexico        1         4         6
# 4  10/1/22  lsu        @             Auburn        1        19        39
#
#    pass_Pct  pass_Yds  pass_TD  ...  def_total_Avg  def_fd_Pass  def_fd_Rush  \
# 0      60.6       260        2  ...            5.4           14            8
# 1      52.9        61        0  ...            7.9           13           10
# 2      57.1       214        1  ...            5.6           11            8
# 3      66.7        51        0  ...            7.9           16           11
# 4      48.7       337        2  ...            3.6            2           14
#
#    def_Pen  def_pen_Tot  def_pen_No  def_turnovers_Yds  def_Fum  def_Int  \
# 0        3           25           4                 45        2        0
# 1        0           23           6                 40        0        2
# 2        1           20           7                 39        1        0
# 3        1           28           5                 60        1        0
# 4        3           19          10                 94        1        0
#
#    def_Tot
# 0        2
# 1        2
# 2        1
# 3        1
# 4        1
#
# [5 rows x 47 columns]

# %%
# home away or neutral site
# home 0
# away 1
# neutral 2
locations = []

for index, row in df.iterrows():
    if(row['location'] == '@'):
        locations.append(1)
    elif(row['location'] == 'N'):
        locations.append(2)
    else:
        locations.append(0)

# %%
df1['location'] = locations

# %%
df1
# Out:
#         Date      team  location           Opponent  results  pass_Cmp  \
# 0     9/4/22       lsu         2      Florida State        0        20
# 1    9/10/22       lsu         0           Southern        1         9
# 2    9/17/22       lsu         0  Mississippi State        1        24
# 3    9/24/22       lsu         0         New Mexico        1         4
# 4    10/1/22       lsu         1             Auburn        1        19
# ..       ...       ...       ...                ...      ...       ...
# 76   9/24/22  texas_am         2           Arkansas        1        11
# 77   10/1/22  texas_am         1  Mississippi State        0        25
# 78   10/8/22  texas_am         1            Alabama        0        25
# 79  10/22/22  texas_am         1     South Carolina        0        25
# 80  10/29/22  texas_am         0        Mississippi        0        28
#
#     pass_Att  pass_Pct  pass_Yds  pass_TD  ...  def_total_Avg  def_fd_Pass  \
# 0         33      60.6       260        2  ...            5.4           14
# 1         17      52.9        61        0  ...            7.9           13
# 2         42      57.1       214        1  ...            5.6           11
# 3          6      66.7        51        0  ...            7.9           16
# 4         39      48.7       337        2  ...            3.6            2
# ..       ...       ...       ...      ...  ...            ...          ...
# 76        21      52.4       151        1  ...            5.7            7
# 77        39      64.1       252        1  ...            6.9           15
# 78        47      53.2       253        2  ...            5.7            7
# 79        47      53.2       269        1  ...            4.8            7
# 80        44      63.6       338        4  ...            6.4            5
#
#     def_fd_Rush  def_Pen  def_pen_Tot  def_pen_No  def_turnovers_Yds  def_Fum  \
# 0             8        3           25           4                 45        2
# 1            10        0           23           6                 40        0
# 2             8        1           20           7                 39        1
# 3            11        1           28           5                 60        1
# 4            14        3           19          10                 94        1
# ..          ...      ...          ...         ...                ...      ...
# 76           17        0           24           3                 30        1
# 77            6        1           22          13                138        1
# 78           13        4           24           6                 73        3
# 79            6        0           13           6                 62        2
# 80           18        3           26           7                 66        0
#
#     def_Int  def_Tot
# 0         0        2
# 1         2        2
# 2         0        1
# 3         0        1
# 4         0        1
# ..      ...      ...
# 76        0        1
# 77        0        1
# 78        1        4
# 79        0        2
# 80        0        0
#
# [81 rows x 47 columns]

# %%
fig, ax = plt.subplots(figsize=(20,5))         
sns.heatmap(df1.corr().loc[['results'],:], linewidth=.9, ax=ax)
# Out:
# <AxesSubplot:>

# %%
df1.corr().loc[['results']]
# Out:
#          location  results  pass_Cmp  pass_Att  pass_Pct  pass_Yds   pass_TD  \
# results -0.372017      1.0 -0.010401 -0.253506  0.407318   0.09828  0.315821
#
#          rush_Att  rush_Yds  rush_Avg  ...  def_total_Avg  def_fd_Pass  \
# results  0.192763  0.312037  0.299434  ...      -0.369268     0.067372
#
#          def_fd_Rush   def_Pen  def_pen_Tot  def_pen_No  def_turnovers_Yds  \
# results    -0.307848 -0.104431    -0.200394    0.072754          -0.072146
#
#          def_Fum  def_Int  def_Tot
# results -0.01212  0.20982  0.14834
#
# [1 rows x 44 columns]

# %%
big_corrs = df1.corr().loc[['results'],:]

# %%
# for index, row in big_corrs.iterrows():
#     print((row > .1) | (row < -.3))

# %%
df1.cov()
# Out:
#                     location    results    pass_Cmp    pass_Att    pass_Pct  \
# location            0.348457  -0.104167   -0.005556    0.777469   -1.470340
# results            -0.104167   0.225000   -0.037500   -1.270833    1.988333
# pass_Cmp           -0.005556  -0.037500   57.775000   71.138889   37.821528
# pass_Att            0.777469  -1.270833   71.138889  111.691049    5.209043
# pass_Pct           -1.470340   1.988333   37.821528    5.209043  105.907725
# pass_Yds           -2.846914   4.870833  582.398611  692.807562  443.454429
# pass_TD            -0.169290   0.229167    6.243056    5.505864    7.249506
# rush_Att           -0.178704   1.000000  -34.295833  -56.161574    4.086435
# rush_Yds           -5.175926  13.100000 -263.720833 -463.681019   40.727546
# rush_Avg           -0.145417   0.242500   -2.585000   -5.478333    1.336208
# rush_TD            -0.096296   0.225000   -1.154167   -4.050926    4.217315
# off_Plays           0.598765  -0.270833   36.843056   55.529475    9.295478
# off_Yds            -8.022840  17.970833  318.677778  229.126543  484.181975
# off_Avg            -0.164290   0.290417    1.598056   -1.162886    6.253506
# fd_Pass            -0.055556   0.125000   27.750000   33.576389   18.181528
# fd_Rush            -0.176543   0.408333   -7.680556  -15.035031    4.917160
# fd_Pen             -0.167593   0.075000    4.116667    5.085648    2.635880
# fd_Tot             -0.399691   0.608333   24.186111   23.627006   25.734568
# pen_No.             0.409414  -0.208333    6.788889    9.992438    3.088071
# pen_Yds             3.028704  -0.175000   68.233333   87.999074   48.039815
# off_Fum            -0.014969  -0.029167    0.623611    0.858951    0.255957
# off_Int            -0.031173  -0.029167   -0.859722   -0.515123   -2.012608
# off_turnovers      -0.046142  -0.058333   -0.236111    0.343827   -1.756651
# def_pass_Cmp       -0.002315   0.575000    1.891667   -6.008796   19.553241
# def_pass_Att       -0.213426   1.375000    6.241667   -3.131019   26.140046
# def_pass_Pct        0.529954  -0.875000   -2.984167   -8.369676   11.464315
# def_pass_yrds       4.561883   0.333333   16.177778  -43.741512  159.823364
# def_pass_TD         0.193673  -0.145833    0.859722    1.440123   -0.631142
# def_rush_Att        0.755710  -1.520833  -22.231944  -14.169136  -42.826744
# def_rush_Yds        9.811728 -17.895833 -166.377778  -74.386265 -408.723920
# def_rush_Avg        0.203611  -0.303750   -2.218750   -0.634028   -6.460931
# def_TD              0.075926  -0.250000   -2.429167   -0.781481   -5.658796
# def_Plays           0.542284  -0.145833  -15.990278  -17.300154  -16.686698
# def_total_yrds     14.373611 -17.562500 -150.200000 -118.127778 -248.900556
# def_total_Avg       0.172870  -0.250000   -0.986667   -0.326343   -2.547769
# def_fd_Pass         0.130864   0.133333   -1.976389   -5.836883    6.788040
# def_fd_Rush         0.554938  -0.629167   -9.084722   -5.267901  -19.543164
# def_Pen             0.139198  -0.091667    3.661111    4.742284    2.315123
# def_pen_Tot         0.825000  -0.587500   -7.400000   -6.362500  -10.440000
# def_pen_No         -0.404784   0.095833    2.652778    1.450154    5.540448
# def_turnovers_Yds  -1.973611  -0.875000   13.212500   19.290278    9.070556
# def_Fum             0.031327  -0.004167    0.802778    1.497377   -0.035108
# def_Int            -0.068364   0.079167    0.501389   -0.213117    1.250710
# def_Tot            -0.037037   0.075000    1.304167    1.284259    1.215602
#
#                        pass_Yds     pass_TD    rush_Att     rush_Yds  \
# location              -2.846914   -0.169290   -0.178704    -5.175926
# results                4.870833    0.229167    1.000000    13.100000
# pass_Cmp             582.398611    6.243056  -34.295833  -263.720833
# pass_Att             692.807562    5.505864  -56.161574  -463.681019
# pass_Pct             443.454429    7.249506    4.086435    40.727546
# pass_Yds           10916.818827  102.251080 -191.230093 -1669.773148
# pass_TD              102.251080    2.340123   -0.371296    14.275926
# rush_Att            -191.230093   -0.371296  119.611111   737.002778
# rush_Yds           -1669.773148   14.275926  737.002778  7833.369444
# rush_Avg             -12.334167    0.455417    4.675000   120.390000
# rush_TD               26.767593   -0.078704    8.088889    79.309722
# off_Plays            501.577469    5.134568   63.449537   273.321759
# off_Yds             9247.045679  116.527006  545.772685  6163.596296
# off_Avg               97.868580    1.286373    2.398704    72.507176
# fd_Pass              384.886111    3.968056  -10.533333   -94.320833
# fd_Rush              -35.196914    0.680710   39.496296   310.411574
# fd_Pen                45.910185    0.755093    1.090278     6.769444
# fd_Tot               395.599383    5.403858   30.053241   222.860185
# pen_No.              113.418673    0.286420    0.880093    19.973148
# pen_Yds             1093.192593    5.371296   21.138889   302.297222
# off_Fum               -1.232562   -0.018364   -0.088426    -4.281481
# off_Int               -0.275154   -0.189660   -0.727315    -1.603704
# off_turnovers         -1.507716   -0.208025   -0.815741    -5.885185
# def_pass_Cmp          54.992130    0.227315    5.744444    45.061111
# def_pass_Att         133.751852    2.075926    8.577778    68.619444
# def_pass_Pct         -85.833657   -3.821204   -5.968611   -77.666528
# def_pass_yrds        707.638735  -11.732716  155.193519   724.717130
# def_pass_TD            5.412654   -0.022840    1.014815     7.803704
# def_rush_Att        -216.511420   -4.022377  -14.071296    -2.924074
# def_rush_Yds       -2255.060957  -38.503395  -58.201852  -507.037963
# def_rush_Avg         -36.845972   -0.574861   -0.760833   -19.378333
# def_TD               -32.601852   -0.850926   -0.140278   -15.644444
# def_Plays            -82.759568   -1.946451   -5.493519    65.695370
# def_total_yrds     -1547.422222  -50.236111   96.991667   217.679167
# def_total_Avg        -18.110741   -0.610370    1.901389    -3.255278
# def_fd_Pass           18.088272   -0.514198    6.186574    53.493519
# def_fd_Rush          -91.472377   -1.988272   -4.160648    -1.612037
# def_Pen               41.109105    0.177469   -1.588426   -14.556481
# def_pen_Tot          -32.275000   -2.325000    0.437500    37.325000
# def_pen_No            53.284568    0.821451    3.506019    15.279630
# def_turnovers_Yds    383.822222    7.348611   10.295833   -13.866667
# def_Fum               17.162346    0.172840   -0.927315    -4.728704
# def_Int               -6.688272    0.164198    1.113426     7.081481
# def_Tot               10.474074    0.337037    0.186111     2.352778
#
#                      rush_Avg  ...  def_total_Avg  def_fd_Pass  def_fd_Rush  \
# location            -0.145417  ...       0.172870     0.130864     0.554938
# results              0.242500  ...      -0.250000     0.133333    -0.629167
# pass_Cmp            -2.585000  ...      -0.986667    -1.976389    -9.084722
# pass_Att            -5.478333  ...      -0.326343    -5.836883    -5.267901
# pass_Pct             1.336208  ...      -2.547769     6.788040   -19.543164
# pass_Yds           -12.334167  ...     -18.110741    18.088272   -91.472377
# pass_TD              0.455417  ...      -0.610370    -0.514198    -1.988272
# rush_Att             4.675000  ...       1.901389     6.186574    -4.160648
# rush_Yds           120.390000  ...      -3.255278    53.493519    -1.612037
# rush_Avg             2.915000  ...      -0.362750     0.790833     0.330833
# rush_TD              1.256250  ...      -0.126389     1.250926    -0.226852
# off_Plays           -0.803333  ...       1.575046     0.349691    -9.428549
# off_Yds            108.055833  ...     -21.366019    71.581790   -93.084414
# off_Avg              1.881917  ...      -0.534370     0.962052    -0.479522
# fd_Pass             -0.925000  ...      -0.567917    -1.038889    -4.322222
# fd_Rush              3.373333  ...       0.090370     1.518364    -2.182562
# fd_Pen               0.045000  ...      -0.040278     0.489352    -0.416204
# fd_Tot               2.493333  ...      -0.517824     0.968827    -6.920988
# pen_No.              0.454167  ...       0.299491     1.411728     1.147377
# pen_Yds              4.987500  ...      -1.770139    21.888426     5.348148
# off_Fum             -0.089167  ...       0.093843     0.149383    -0.332099
# off_Int              0.047083  ...      -0.219769    -0.714043    -0.055247
# off_turnovers       -0.042083  ...      -0.125926    -0.564660    -0.387346
# def_pass_Cmp         0.335000  ...       1.649306    24.296296    -7.667593
# def_pass_Att         0.547500  ...      -1.160278    28.381019   -14.687037
# def_pass_Pct        -1.510250  ...       7.633611    24.128426     3.930648
# def_pass_yrds        0.628333  ...      76.365648   330.412346   -20.208025
# def_pass_TD          0.050417  ...       0.924769     1.926543     1.392747
# def_rush_Att         1.512917  ...       3.707130   -11.776698    35.036728
# def_rush_Yds       -11.370833  ...      77.071435   -79.897068   326.152469
# def_rush_Avg        -0.518000  ...       1.687458    -0.699722     4.755694
# def_TD              -0.418750  ...       1.430278     0.993981     3.024537
# def_Plays            2.060417  ...       2.546852    16.604321    20.349691
# def_total_yrds     -10.742500  ...     153.437083   250.515278   305.944444
# def_total_Avg       -0.362750  ...       2.037111     2.335093     2.884815
# def_fd_Pass          0.790833  ...       2.335093    17.407716    -2.348765
# def_fd_Rush          0.330833  ...       2.884815    -2.348765    18.564198
# def_Pen             -0.247917  ...       0.037593     1.903549    -0.152932
# def_pen_Tot          0.873750  ...       5.257500    16.962500    16.062500
# def_pen_No          -0.095417  ...       0.193148     1.145679    -1.099691
# def_turnovers_Yds   -2.128750  ...       2.359167     1.872222     2.693056
# def_Fum              0.007083  ...       0.007731     0.235957     0.244753
# def_Int              0.055417  ...      -0.070093    -0.432716    -0.151235
# def_Tot              0.062500  ...      -0.062361    -0.196759     0.093519
#
#                      def_Pen   def_pen_Tot    def_pen_No  def_turnovers_Yds  \
# location            0.139198  8.250000e-01 -4.047840e-01          -1.973611
# results            -0.091667 -5.875000e-01  9.583333e-02          -0.875000
# pass_Cmp            3.661111 -7.400000e+00  2.652778e+00          13.212500
# pass_Att            4.742284 -6.362500e+00  1.450154e+00          19.290278
# pass_Pct            2.315123 -1.044000e+01  5.540448e+00           9.070556
# pass_Yds           41.109105 -3.227500e+01  5.328457e+01         383.822222
# pass_TD             0.177469 -2.325000e+00  8.214506e-01           7.348611
# rush_Att           -1.588426  4.375000e-01  3.506019e+00          10.295833
# rush_Yds          -14.556481  3.732500e+01  1.527963e+01         -13.866667
# rush_Avg           -0.247917  8.737500e-01 -9.541667e-02          -2.128750
# rush_TD            -0.236574  7.875000e-01  4.398148e-02          -3.883333
# off_Plays           3.153858 -5.925000e+00  4.956173e+00          29.586111
# off_Yds            26.552623  5.050000e+00  6.856420e+01         369.955556
# off_Avg             0.057469  5.400000e-01  5.039506e-01           2.097361
# fd_Pass             1.311111 -4.050000e+00  8.652778e-01           1.450000
# fd_Rush            -0.448302 -1.112500e+00  2.070216e+00          12.401389
# fd_Pen              0.064352  1.375000e-01  2.762963e+00          28.920833
# fd_Tot              0.927160 -5.025000e+00  5.698457e+00          42.772222
# pen_No.             4.015895  6.575000e+00  1.529321e-01           2.577778
# pen_Yds            44.175926  7.141250e+01  4.189815e-01           6.291667
# off_Fum            -0.142284 -3.250000e-01  2.748457e-01           1.634722
# off_Int            -0.205710 -9.750000e-01  2.433642e-01           2.668056
# off_turnovers      -0.347994 -1.300000e+00  5.182099e-01           4.302778
# def_pass_Cmp        3.796296  2.042500e+01  3.124074e+00          18.833333
# def_pass_Att        5.043519  1.873750e+01  5.417130e+00          33.620833
# def_pass_Pct        2.815926  3.087500e+01 -1.758519e+00         -22.673333
# def_pass_yrds      44.445679  3.546500e+02  2.682809e+01          54.880556
# def_pass_TD         0.430710  3.750000e+00 -8.086420e-02          -0.118056
# def_rush_Att       -1.772531  2.148750e+01 -4.378549e+00         -17.101389
# def_rush_Yds      -25.380401  2.208750e+02 -9.783642e+00         168.544444
# def_rush_Avg       -0.580972  3.475000e+00  1.144444e-01           5.378750
# def_TD             -0.306019  3.712500e+00 -2.046296e-01           0.054167
# def_Plays           3.270988  4.022500e+01  1.038580e+00          16.519444
# def_total_yrds     19.065278  5.755250e+02  1.704444e+01         223.425000
# def_total_Avg       0.037593  5.257500e+00  1.931481e-01           2.359167
# def_fd_Pass         1.903549  1.696250e+01  1.145679e+00           1.872222
# def_fd_Rush        -0.152932  1.606250e+01 -1.099691e+00           2.693056
# def_Pen             3.424383  5.175000e+00 -4.598765e-02           0.547222
# def_pen_Tot         5.175000  3.820000e+01 -1.776357e-16           5.112500
# def_pen_No         -0.045988 -1.776357e-16  7.711420e+00          61.268056
# def_turnovers_Yds   0.547222  5.112500e+00  6.126806e+01         653.750000
# def_Fum             0.094290  5.750000e-01 -1.316358e-01          -0.119444
# def_Int            -0.253549 -8.375000e-01 -2.456790e-01          -2.234722
# def_Tot            -0.159259 -2.625000e-01 -3.773148e-01          -2.354167
#
#                      def_Fum   def_Int    def_Tot
# location            0.031327 -0.068364  -0.037037
# results            -0.004167  0.079167   0.075000
# pass_Cmp            0.802778  0.501389   1.304167
# pass_Att            1.497377 -0.213117   1.284259
# pass_Pct           -0.035108  1.250710   1.215602
# pass_Yds           17.162346 -6.688272  10.474074
# pass_TD             0.172840  0.164198   0.337037
# rush_Att           -0.927315  1.113426   0.186111
# rush_Yds           -4.728704  7.081481   2.352778
# rush_Avg            0.007083  0.055417   0.062500
# rush_TD             0.064815  0.074074   0.138889
# off_Plays           0.570062  0.900309   1.470370
# off_Yds            12.433642  0.393210  12.826852
# off_Avg             0.145340 -0.083302   0.062037
# fd_Pass             0.640278 -0.136111   0.504167
# fd_Rush            -0.293673  0.519136   0.225463
# fd_Pen              0.042130  0.110648   0.152778
# fd_Tot              0.388735  0.493673   0.882407
# pen_No.             0.275154 -0.111728   0.163426
# pen_Yds             3.552315 -0.275926   3.276389
# off_Fum            -0.059877  0.063117   0.003241
# off_Int            -0.074691 -0.048457  -0.123148
# off_turnovers      -0.134568  0.014660  -0.119907
# def_pass_Cmp        0.653241 -0.658796  -0.005556
# def_pass_Att        0.421296  0.156481   0.577778
# def_pass_Pct        1.306065 -2.309676  -1.003611
# def_pass_yrds       5.435031 -6.112346  -0.677315
# def_pass_TD        -0.000309 -0.101543  -0.101852
# def_rush_Att        0.147840 -0.560802  -0.412963
# def_rush_Yds       -2.153086 -0.902932  -3.056019
# def_rush_Avg       -0.033056 -0.007778  -0.040833
# def_TD              0.003704 -0.056481  -0.052778
# def_Plays           0.569136 -0.404321   0.164815
# def_total_yrds      3.281944 -7.015278  -3.733333
# def_total_Avg       0.007731 -0.070093  -0.062361
# def_fd_Pass         0.235957 -0.432716  -0.196759
# def_fd_Rush         0.244753 -0.151235   0.093519
# def_Pen             0.094290 -0.253549  -0.159259
# def_pen_Tot         0.575000 -0.837500  -0.262500
# def_pen_No         -0.131636 -0.245679  -0.377315
# def_turnovers_Yds  -0.119444 -2.234722  -2.354167
# def_Fum             0.525309 -0.010957   0.514352
# def_Int            -0.010957  0.632716   0.621759
# def_Tot             0.514352  0.621759   1.136111
#
# [44 rows x 44 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
fig, ax = plt.subplots(figsize=(90,90))         
sns.heatmap(X.cov(), linewidth=.1, ax=ax)
# Out:
# <AxesSubplot:>

# %%
X_train.columns
# Out:
# Index(['location', 'pass_Cmp', 'pass_Att', 'pass_Pct', 'pass_Yds', 'pass_TD',
#        'rush_Att', 'rush_Yds', 'rush_Avg', 'rush_TD', 'off_Plays', 'off_Avg',
#        'fd_Pass', 'fd_Rush', 'fd_Pen', 'fd_Tot', 'pen_No.', 'pen_Yds',
#        'off_Fum', 'off_Int', 'off_turnovers ', 'def_pass_Cmp', 'def_pass_Att',
#        'def_pass_Pct', 'def_pass_yrds ', 'def_pass_TD', 'def_rush_Att',
#        'def_rush_Yds', 'def_rush_Avg', 'def_TD', 'def_Plays', 'def_total_Avg',
#        'def_fd_Pass', 'def_fd_Rush', 'def_Pen', 'def_pen_Tot', 'def_pen_No',
#        'def_turnovers_Yds', 'def_Fum', 'def_Int', 'def_Tot'],
#       dtype='object')

# %%
df2 = df1.copy()

# %%
df2 = df2.drop(columns=['Date', 'team', 'Opponent'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   location           81 non-null     int64
#  1   results            81 non-null     int64
#  2   pass_Cmp           81 non-null     int64
#  3   pass_Att           81 non-null     int64
#  4   pass_Pct           81 non-null     float64
#  5   pass_Yds           81 non-null     int64
#  6   pass_TD            81 non-null     int64
#  7   rush_Att           81 non-null     int64
#  8   rush_Yds           81 non-null     int64
#  9   rush_Avg           81 non-null     float64
#  10  rush_TD            81 non-null     int64
#  11  off_Plays          81 non-null     int64
#  12  off_Yds            81 non-null     int64
#  13  off_Avg            81 non-null     float64
#  14  fd_Pass            81 non-null     int64
#  15  fd_Rush            81 non-null     int64
#  16  fd_Pen             81 non-null     int64
#  17  fd_Tot             81 non-null     int64
#  18  pen_No.            81 non-null     int64
#  19  pen_Yds            81 non-null     int64
#  20  off_Fum            81 non-null     int64
#  21  off_Int            81 non-null     int64
#  22  off_turnovers      81 non-null     int64
#  23  def_pass_Cmp       81 non-null     int64
#  24  def_pass_Att       81 non-null     int64
#  25  def_pass_Pct       81 non-null     float64
#  26  def_pass_yrds      81 non-null     int64
#  27  def_pass_TD        81 non-null     int64
#  28  def_rush_Att       81 non-null     int64
#  29  def_rush_Yds       81 non-null     int64
#  30  def_rush_Avg       81 non-null     float64
#  31  def_TD             81 non-null     int64
#  32  def_Plays          81 non-null     int64
#  33  def_total_yrds     81 non-null     int64
#  34  def_total_Avg      81 non-null     float64
#  35  def_fd_Pass        81 non-null     int64
#  36  def_fd_Rush        81 non-null     int64
#  37  def_Pen            81 non-null     int64
#  38  def_pen_Tot        81 non-null     int64
#  39  def_pen_No         81 non-null     int64
#  40  def_turnovers_Yds  81 non-null     int64
#  41  def_Fum            81 non-null     int64
#  42  def_Int            81 non-null     int64
#  43  def_Tot            81 non-null     int64
# dtypes: float64(6), int64(38)
# memory usage: 28.0 KB

# %%
y = df2['results']
X = df2.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.10, random_state=2)

# %%
# X_train = X_train.drop(columns=['def_total_yrds', 'off_Yds'])
lr2 = LinearRegression()
lr2.fit(X_train, y_train)
y_hat_train = lr2.predict(X_train)
r2_score(y_train, y_hat_train)
# Out:
# 0.659623174518511

# %%
column_list = df2.columns

# %%
X_train.columns
# Out:
# Index(['location', 'pass_Cmp', 'pass_Att', 'pass_Pct', 'pass_Yds', 'pass_TD',
#        'rush_Att', 'rush_Yds', 'rush_Avg', 'rush_TD', 'off_Plays', 'off_Yds',
#        'off_Avg', 'fd_Pass', 'fd_Rush', 'fd_Pen', 'fd_Tot', 'pen_No.',
#        'pen_Yds', 'off_Fum', 'off_Int', 'off_turnovers ', 'def_pass_Cmp',
#        'def_pass_Att', 'def_pass_Pct', 'def_pass_yrds ', 'def_pass_TD',
#        'def_rush_Att', 'def_rush_Yds', 'def_rush_Avg', 'def_TD', 'def_Plays',
#        'def_total_yrds', 'def_total_Avg', 'def_fd_Pass', 'def_fd_Rush',
#        'def_Pen', 'def_pen_Tot', 'def_pen_No', 'def_turnovers_Yds', 'def_Fum',
#        'def_Int', 'def_Tot'],
#       dtype='object')

# %%
from itertools import combinations
columns_list = X_train.columns
interactions = list(combinations(column_list, 2))

# %%
len(interactions)
# Out:
# 946

# %%
X_train
# Out:
#     location  pass_Cmp  pass_Att  pass_Pct  pass_Yds  pass_TD  rush_Att  \
# 14         0        26        37      70.3       495        5        46
# 21         0        12        19      63.2       111        3        51
# 36         0        15        29      51.7       213        0        39
# 58         1        13        24      54.2       202        1        38
# 13         0        21        31      67.7       385        5        39
# ..       ...       ...       ...       ...       ...      ...       ...
# 43         0        21        38      55.3       296        1        36
# 22         1        35        52      67.3       455        2        31
# 72         1        16        24      66.7       234        1        48
# 15         0        19        25      76.0       245        3        40
# 40         1        13        20      65.0       140        3        63
#
#     rush_Yds  rush_Avg  rush_TD  ...  def_total_Avg  def_fd_Pass  def_fd_Rush  \
# 14       201       4.4        4  ...            5.2           16            4
# 21       286       5.6        0  ...            4.5           11            4
# 36       186       4.8        2  ...            5.4            9            7
# 58        70       1.8        1  ...            4.3            7            5
# 13       182       4.7        2  ...            6.9           21            9
# ..       ...       ...      ...  ...            ...          ...          ...
# 43       119       3.3        0  ...            7.7           10            8
# 22       114       3.7        3  ...            8.1           13           12
# 72       286       6.0        4  ...            6.6           11            9
# 15       177       4.4        3  ...            3.3            6            8
# 40       390       6.2        1  ...            6.6           15            8
#
#     def_Pen  def_pen_Tot  def_pen_No  def_turnovers_Yds  def_Fum  def_Int  \
# 14        5           25           5                 39        1        1
# 21        3           18           8                 59        0        1
# 36        1           17           4                 15        2        0
# 58        0           12           3                 28        0        2
# 13        2           32          17                130        1        0
# ..      ...          ...         ...                ...      ...      ...
# 43        1           19           9                 80        0        0
# 22        4           29           6                 39        1        1
# 72        0           20           7                 55        0        0
# 15        0           14           5                 31        0        3
# 40        3           26           9                 51        0        0
#
#     def_Tot
# 14        2
# 21        1
# 36        2
# 58        2
# 13        1
# ..      ...
# 43        0
# 22        2
# 72        0
# 15        3
# 40        0
#
# [72 rows x 43 columns]

# %%
new_interactions = []
for i in interactions:
    if (i[0] == 'results'):
        continue
    elif (i[1] == 'results'):
        continue
    else:
        new_interactions.append(i)

# %%
len(new_interactions)
# Out:
# 903

# %%
interaction_dict = {}

for interaction in new_interactions:
    X_train_int = X_train
    X_train_int['int'] = X_train_int[interaction[0]] * X_train_int[interaction[1]]
    lr3 = LinearRegression()
    lr3.fit(X_train_int, y_train)
    interaction_dict[lr3.score(X_train_int, y_train)] = interaction

# %%
top_5 = sorted(interaction_dict.keys(), reverse = True)[:5]
for interaction in top_5:
    print(interaction_dict[interaction])
# Out:
# ('location', 'def_total_Avg')
# ('location', 'def_rush_Avg')
# ('pass_Pct', 'def_pass_Att')
# ('pass_Pct', 'def_Pen')
# ('location', 'def_total_yrds')

# %%
X_train_int = X_train
X_train_int['lo_def'] = X_train_int['location'] * X_train_int['def_total_Avg']

# %%
lr4 = LinearRegression()
lr4.fit(X_train_int, y_train)
lr4.score(X_train_int, y_train)
# Out:
# 0.7236101328261957

# %%
X_train_int = X_train
X_train_int['pass_def'] = X_train_int['pass_Pct'] * X_train_int['def_Pen']

# %%
lr4 = LinearRegression()
lr4.fit(X_train_int, y_train)
lr4.score(X_train_int, y_train)
# Out:
# 0.7757348836119854

# %%
X_train_int = X_train
X_train_int['def_pass_att'] = X_train_int['pass_Pct'] * X_train_int['def_pass_Att']

# %%
lr4 = LinearRegression()
lr4.fit(X_train_int, y_train)
lr4.score(X_train_int, y_train)
# Out:
# 0.7823917516904865

# %%
X_train_int = X_train
X_train_int['loc_def_rush'] = X_train_int['location'] * X_train_int['def_rush_Avg']

# %%
lr4 = LinearRegression()
lr4.fit(X_train_int, y_train)
lr4.score(X_train_int, y_train)
# Out:
# 0.8060386986316537

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_dict = {}

for feature in X_train_int.columns:
    for p in range(2, 5):
        X_train_poly = X_train_int
        X_train_poly['sq'] = X_train_poly[feature] ** p
        lr = LinearRegression()
        lr.fit(X_train_poly, y_train)
        poly_dict[lr.score(X_train_poly, y_train)] = [feature, p]
                  
poly_dict[max(poly_dict.keys())]
# Out:
# ['rush_TD', 4]

# %%
#  0.8325329923245015: ['rush_TD', 4],

# %% [markdown]
# X_train = X_train_int
# y_train = y_train
#
# need to change the features for the whole df, not just the training sets
