# %%
import numpy as np
import pandas as pd
from numpy import mean
from numpy import std
import statistics

# %%
df = pd.read_csv('wk12.csv')

# %%
df
# Out:
#      Wk      Time            Winner  Pts             Loser  Pts.1  \
# 0     1   7:00 PM  Florida Atlantic   43         Charlotte     13
# 1     1   5:00 PM     Florida State   47          Duquesne      7
# 2     1   4:00 PM          Illinois   38           Wyoming      6
# 3     1  10:00 PM            Nevada   23  New Mexico State     12
# 4     1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21
# ..   ..       ...               ...  ...               ...    ...
# 709  12   7:00 PM   (24) Washington   37        (6) Oregon     34
# 710  12   3:30 PM  Washington State   28     Arizona State     18
# 711  12  12:00 PM     West Virginia   23          Oklahoma     20
# 712  12   2:00 PM  Western Kentucky   45              Rice     10
# 713  12   7:00 PM           Wyoming   14    Colorado State     13
#
#               winners            losers  home_rank  away_rank  home_team_code  \
# 0    Florida Atlantic         Charlotte         99         99              32
# ...

# %%
df.shape
# Out:
# (714, 17)

# %%
df['Time'].value_counts()
# Out:
# 3:30 PM     130
# 12:00 PM    116
# 7:00 PM     102
# 7:30 PM      86
# 8:00 PM      54
# 4:00 PM      47
# 10:30 PM     28
# 6:00 PM      27
# 2:00 PM      25
# 5:00 PM      13
# 3:00 PM      10
# 1:00 PM      10
# 9:00 PM       9
# 11:00 PM      7
# 2:30 PM       7
# 12:30 PM      7
# 9:30 PM       6
# 10:00 PM      6
# 5:30 PM       5
# 12:00 AM      3
# 10:15 PM      2
# 8:30 PM       2
# 1:30 PM       2
# 9:45 PM       2
# 11:00 AM      1
# 10:45 PM      1
# 11:59 PM      1
# 6:30 PM       1
# 11:30 AM      1
# 3:35 PM       1
# Name: Time, dtype: int64

# %%
times = df['Time']

# %%
nums = []

for i in times:
    i = str(i)
    nums.append(i[:-2])

# %%
nums
# Out:
# ['7:00 ',
#  '5:00 ',
#  '4:00 ',
#  '10:00 ',
#  '3:30 ',
#  '8:00 ',
#  '9:00 ',
#  '12:30 ',
#  '4:00 ',
#  '10:30 ',
#  '12:00 ',
#  '6:00 ',
#  '8:00 ',
#  '10:00 ',
#  '7:00 ',
#  '7:00 ',
#  '10:30 ',
#  '9:00 ',
#  '8:00 ',
#  '8:00 ',
#  '7:00 ',
#  '8:00 ',
#  '7:00 ',
#  '10:30 ',
#  '7:00 ',
#  '7:00 ',
#  '7:30 ',
#  '7:30 ',
#  '7:00 ',
#  '8:00 ',
#  '8:00 ',
#  '7:00 ',
#  '7:00 ',
#  '10:00 ',
#  '7:00 ',
#  '1:00 ',
#  '7:30 ',
#  '3:30 ',
#  '3:30 ',
#  '7:00 ',
#  '7:00 ',
#  '7:00 ',
#  '4:00 ',
#  '4:00 ',
#  '7:00 ',
#  '12:00 ',
#  '12:00 ',
#  '7:00 ',
#  '3:30 ',
#  '6:00 ',
#  '3:30 ',
#  '12:00 ',
#  '2:00 ',
#  '6:00 ',
#  '7:00 ',
#  '7:00 ',
#  '7:00 ',
#  '7:00 ',
#  '3:30 ',
#  '12:00 ',
#  '3:30 ',
#  '12:00 ',
#  '4:00 ',
#  '7:30 ',
#  '3:30 ',
#  '5:30 ',
#  '8:00 ',
#  '12:00 ',
#  '12:00 ',
#  '6:00 ',
#  '7:30 ',
#  '3:30 ',
#  '10:30 ',
#  '12:00 ',
#  '5:00 ',
#  '7:30 ',
#  '6:00 ',
#  '7:30 ',
#  '8:00 ',
#  '8:00 ',
#  '8:00 ',
# ...

# %%
hours = []
mins = []

for i in nums:
    if(len(i) == 5):
        hours.append(i[0])
        mins.append(i[2:4])        
    else:
        hours.append(i[0:2])
        mins.append(i[3:5])

# %%
len(hours)
# Out:
# 714

# %%
len(mins)
# Out:
# 714

# %%
df.shape
# Out:
# (714, 17)

# %%
df['hour'] = hours

# %%
df['minutes'] = mins

# %%
df
# Out:
#      Wk      Time            Winner  Pts             Loser  Pts.1  \
# 0     1   7:00 PM  Florida Atlantic   43         Charlotte     13
# 1     1   5:00 PM     Florida State   47          Duquesne      7
# 2     1   4:00 PM          Illinois   38           Wyoming      6
# 3     1  10:00 PM            Nevada   23  New Mexico State     12
# 4     1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21
# ..   ..       ...               ...  ...               ...    ...
# 709  12   7:00 PM   (24) Washington   37        (6) Oregon     34
# 710  12   3:30 PM  Washington State   28     Arizona State     18
# 711  12  12:00 PM     West Virginia   23          Oklahoma     20
# 712  12   2:00 PM  Western Kentucky   45              Rice     10
# 713  12   7:00 PM           Wyoming   14    Colorado State     13
#
#               winners            losers  home_rank  away_rank  home_team_code  \
# 0    Florida Atlantic         Charlotte         99         99              32
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wk              714 non-null    int64
#  1   Time            712 non-null    object
#  2   Winner          714 non-null    object
#  3   Pts             714 non-null    int64
#  4   Loser           714 non-null    object
#  5   Pts.1           714 non-null    int64
#  6   winners         714 non-null    object
#  7   losers          714 non-null    object
#  8   home_rank       714 non-null    int64
#  9   away_rank       714 non-null    int64
#  10  home_team_code  714 non-null    int64
#  11  away_team_code  714 non-null    int64
#  12  home_results    714 non-null    int64
#  13  win_rank        714 non-null    int64
#  14  lose_rank       714 non-null    int64
#  15  dates           714 non-null    object
#  16  day_code        714 non-null    int64
# ...

# %%
new_hour= []
for index, row in df.iterrows():
    if(row['hour'] == 'n'):
        new_hour.append(5)
    else:
        new_hour.append(row['hour'])

# %%
df['hours'] = new_hour

# %%
df['hours'].value_counts()
# Out:
# 7     188
# 3     141
# 12    126
# 8      56
# 4      47
# 10     37
# 2      32
# 6      28
# 5      18
# 9      17
# 1      12
# 11     10
# 5       2
# Name: hours, dtype: int64

# %%
hour = (df['hours'])
hours = []

for x in hour:
    if (x == '12'):
        hours.append('12')
    elif(x == '1'):
        hours.append('13')
    elif(x == '2'):
        hours.append('14')
    elif(x == '3'):
        hours.append('15')
    elif(x == '4'):
        hours.append('16')
    elif(x == '5'):
        hours.append('17')
    elif(x == '6'):
        hours.append('18')
    elif(x == '7'):
        hours.append('19')
    elif(x == '8'):
        hours.append('20')
    elif(x == '9'):
        hours.append('21')
    elif(x == '10'):
        hours.append('22')
    elif(x == '11'):
        hours.append('11')
    else:
        hours.append('5')

# %%
len(hours)
# Out:
# 714

# %%
df['hours'] = hours

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wk              714 non-null    int64
#  1   Time            712 non-null    object
#  2   Winner          714 non-null    object
#  3   Pts             714 non-null    int64
#  4   Loser           714 non-null    object
#  5   Pts.1           714 non-null    int64
#  6   winners         714 non-null    object
#  7   losers          714 non-null    object
#  8   home_rank       714 non-null    int64
#  9   away_rank       714 non-null    int64
#  10  home_team_code  714 non-null    int64
#  11  away_team_code  714 non-null    int64
#  12  home_results    714 non-null    int64
#  13  win_rank        714 non-null    int64
#  14  lose_rank       714 non-null    int64
#  15  dates           714 non-null    object
#  16  day_code        714 non-null    int64
# ...

# %%
df['minutes'].value_counts()
# Out:
# 00    430
# 30    275
# 45      3
# 15      2
#         2
# 59      1
# 35      1
# Name: minutes, dtype: int64

# %%
mins = df['minutes']
minute = []

for i in mins:
    if(i == '00'):
        minute.append('00')
    elif(i == '30'):
        minute.append('30')
    elif(i == '45'):
        minute.append('45')
    elif(i == '15'):
        minute.append('15')
    elif(i == '59'):
        minute.append('00')
    elif(i == '35'):
        minute.append('30')
    else:
        minute.append('00')

# %%
df['minutes'] = minute

# %%
df['hours'].value_counts()
# Out:
# 19    188
# 15    141
# 12    126
# 20     56
# 16     47
# 22     37
# 14     32
# 18     28
# 17     18
# 21     17
# 13     12
# 11     10
# 5       2
# Name: hours, dtype: int64

# %%
df = df.drop(columns=['hour', 'Time'])

# %%
df
# Out:
#      Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0     1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1     1     Florida State   47          Duquesne      7     Florida State
# 2     1          Illinois   38           Wyoming      6          Illinois
# 3     1            Nevada   23  New Mexico State     12            Nevada
# 4     1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
# ..   ..               ...  ...               ...    ...               ...
# 709  12   (24) Washington   37        (6) Oregon     34        Washington
# 710  12  Washington State   28     Arizona State     18  Washington State
# 711  12     West Virginia   23          Oklahoma     20     West Virginia
# 712  12  Western Kentucky   45              Rice     10  Western Kentucky
# 713  12           Wyoming   14    Colorado State     13           Wyoming
#
#                losers  home_rank  away_rank  home_team_code  away_team_code  \
# ...

# %%
df = df.drop(columns=['dates'])

# %%
df.cov()
# Out:
#                        Wk         Pts       Pts.1    home_rank   away_rank  \
# Wk              11.041278   -8.572065    3.296950     2.015235  -13.111212
# Pts             -8.572065  152.934600   20.806711   -51.309428    8.574340
# Pts.1            3.296950   20.806711  107.778765     4.178152  -44.205818
# home_rank        2.015235  -51.309428    4.178152  1202.153492  178.629309
# away_rank      -13.111212    8.574340  -44.205818   178.629309  908.602520
# home_team_code   0.432995   21.460488    5.116172  -120.673581  -38.024491
# away_team_code   1.663724  -30.326352  -19.642138   -67.185675  -71.692635
# home_results     0.253499   -0.886183    0.705342     3.553683   -2.326116
# win_rank        -2.017463  -61.740050    4.489956   984.725844  619.298632
# lose_rank       -8.710392   19.349653  -43.305304   381.309329  457.475397
# day_code        -0.127052    0.278914   -0.049183    -2.116857   -1.345151
#
# ...

# %%
points = df['Pts']

# %%
points1 = df['Pts.1']

# %%
print(statistics.stdev(points))
print(statistics.stdev(points1))
# Out:
# 12.366672953018822
# 10.38165519179077

# %%
print(points.mean())
print(points1.mean())
# Out:
# 36.554621848739494
# 18.110644257703083

# %%
 12.366672953018822 * 2
# Out:
# 24.733345906037645

# %%
36.554621848739494 + 24.733345906037645
# Out:
# 61.28796775477714

# %%
36.554621848739494 - 24.733345906037645
# Out:
# 11.821275942701849

# %%
for index, row in df.iterrows():
    if(int(row["Pts"]) > 61 or int(row["Pts"]) < 12):
        df.drop(index, inplace=True)

# %%
df.shape
# Out:
# (680, 17)

# %%
df.head()
# Out:
#    Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0   1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1   1     Florida State   47          Duquesne      7     Florida State
# 2   1          Illinois   38           Wyoming      6          Illinois
# 3   1            Nevada   23  New Mexico State     12            Nevada
# 4   1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
#
#              losers  home_rank  away_rank  home_team_code  away_team_code  \
# 0         Charlotte         99         99              32              37
# 1          Duquesne         99         99              34              49
# 2           Wyoming         99         99              42             221
# 3  New Mexico State         99         99              76             121
# 4       Idaho State         99         99              74              76
#
#    home_results  win_rank  lose_rank  day_code minutes hours
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 680 entries, 0 to 713
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wk              680 non-null    int64
#  1   Winner          680 non-null    object
#  2   Pts             680 non-null    int64
#  3   Loser           680 non-null    object
#  4   Pts.1           680 non-null    int64
#  5   winners         680 non-null    object
#  6   losers          680 non-null    object
#  7   home_rank       680 non-null    int64
#  8   away_rank       680 non-null    int64
#  9   home_team_code  680 non-null    int64
#  10  away_team_code  680 non-null    int64
#  11  home_results    680 non-null    int64
#  12  win_rank        680 non-null    int64
#  13  lose_rank       680 non-null    int64
#  14  day_code        680 non-null    int64
#  15  minutes         680 non-null    object
#  16  hours           680 non-null    object
# ...

# %%
hr = df['hours']
hour = []

for i in hr:
    i = int(i)
    hour.append(i)

# %%
df['hours'] = hour

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 680 entries, 0 to 713
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wk              680 non-null    int64
#  1   Winner          680 non-null    object
#  2   Pts             680 non-null    int64
#  3   Loser           680 non-null    object
#  4   Pts.1           680 non-null    int64
#  5   winners         680 non-null    object
#  6   losers          680 non-null    object
#  7   home_rank       680 non-null    int64
#  8   away_rank       680 non-null    int64
#  9   home_team_code  680 non-null    int64
#  10  away_team_code  680 non-null    int64
#  11  home_results    680 non-null    int64
#  12  win_rank        680 non-null    int64
#  13  lose_rank       680 non-null    int64
#  14  day_code        680 non-null    int64
#  15  minutes         680 non-null    object
#  16  hours           680 non-null    int64
# ...

# %%
df['minutes'].value_counts()
# Out:
# 00    411
# 30    264
# 45      3
# 15      2
# Name: minutes, dtype: int64

# %%
mins = df['minutes']
null = []
half = []
quart = []
three_quart = []

for i in mins:
    if (i == '00'):
        null.append(1)
        half.append(0)
        quart.append(0)
        three_quart.append(0)
    elif(i == '30'):
        null.append(0)
        half.append(1)
        quart.append(0)
        three_quart.append(0)
    elif(i == '45'):
        null.append(0)
        half.append(0)
        quart.append(1)
        three_quart.append(0)
    elif(i == '15'):
        null.append(0)
        half.append(0)
        quart.append(0)
        three_quart.append(1)

# %%
len(null)
# Out:
# 680

# %%
df.shape
# Out:
# (680, 17)

# %%
df2 =df.copy()

# %%
df2['null'] = null
df2['half'] = half
df2['quart'] = quart
df2['three_quart'] = three_quart

# %%
df2.shape
# Out:
# (680, 21)

# %%
df2
# Out:
#      Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0     1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1     1     Florida State   47          Duquesne      7     Florida State
# 2     1          Illinois   38           Wyoming      6          Illinois
# 3     1            Nevada   23  New Mexico State     12            Nevada
# 4     1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
# ..   ..               ...  ...               ...    ...               ...
# 709  12   (24) Washington   37        (6) Oregon     34        Washington
# 710  12  Washington State   28     Arizona State     18  Washington State
# 711  12     West Virginia   23          Oklahoma     20     West Virginia
# 712  12  Western Kentucky   45              Rice     10  Western Kentucky
# 713  12           Wyoming   14    Colorado State     13           Wyoming
#
#                losers  home_rank  away_rank  home_team_code  ...  \
# ...

# %%
df2 = df2.drop(columns=['minutes'])

# %% [markdown]
# ## getting nan for last severl one hot encoded columns / fix in excel

# %%
df2
# Out:
#      Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0     1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1     1     Florida State   47          Duquesne      7     Florida State
# 2     1          Illinois   38           Wyoming      6          Illinois
# 3     1            Nevada   23  New Mexico State     12            Nevada
# 4     1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
# ..   ..               ...  ...               ...    ...               ...
# 709  12   (24) Washington   37        (6) Oregon     34        Washington
# 710  12  Washington State   28     Arizona State     18  Washington State
# 711  12     West Virginia   23          Oklahoma     20     West Virginia
# 712  12  Western Kentucky   45              Rice     10  Western Kentucky
# 713  12           Wyoming   14    Colorado State     13           Wyoming
#
#                losers  home_rank  away_rank  home_team_code  away_team_code  \
# ...

# %%
# df2.to_csv('encoded_df.csv', index=False)
