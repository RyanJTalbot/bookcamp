# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('wk12.csv')

# %%
df
# Out:
#      Wk      Time            Winner  Pts             Loser  Pts.1  \
# 0     1   7:00 PM  Florida Atlantic   43         Charlotte     13
# 1     1   5:00 PM     Florida State   47          Duquesne      7
# 2     1   4:00 PM          Illinois   38           Wyoming      6
# 3     1  10:00 PM            Nevada   23  New Mexico State     12
# 4     1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21
# ..   ..       ...               ...  ...               ...    ...
# 709  12   7:00 PM   (24) Washington   37        (6) Oregon     34
# 710  12   3:30 PM  Washington State   28     Arizona State     18
# 711  12  12:00 PM     West Virginia   23          Oklahoma     20
# 712  12   2:00 PM  Western Kentucky   45              Rice     10
# 713  12   7:00 PM           Wyoming   14    Colorado State     13
#
#               winners            losers  home_rank  away_rank  home_team_code  \
# 0    Florida Atlantic         Charlotte         99         99              32
# 1       Florida State          Duquesne         99         99              34
# 2            Illinois           Wyoming         99         99              42
# 3              Nevada  New Mexico State         99         99              76
# 4    Nevada-Las Vegas       Idaho State         99         99              74
# ..                ...               ...        ...        ...             ...
# 709        Washington            Oregon          6         24              88
# 710  Washington State     Arizona State         99         99             126
# 711     West Virginia          Oklahoma         99         99             127
# 712  Western Kentucky              Rice         99         99             128
# 713           Wyoming    Colorado State         99         99              26
#
#      away_team_code  home_results  win_rank  lose_rank       dates  day_code
# 0                37             0        99         99  2022-08-27         5
# 1                49             0        99         99  2022-08-27         5
# 2               221             0        99         99  2022-08-27         5
# 3               121             1        99         99  2022-08-27         5
# 4                76             0        99         99  2022-08-27         5
# ..              ...           ...       ...        ...         ...       ...
# 709             210             1        24          6  2022-11-12         5
# 710              11             0        99         99  2022-11-12         5
# 711             143             0        99         99  2022-11-12         5
# 712             153             0        99         99  2022-11-12         5
# 713             221             1        99         99  2022-11-12         5
#
# [714 rows x 17 columns]

# %%
df.corr()
# Out:
#                       Wk       Pts     Pts.1  home_rank  away_rank  \
# Wk              1.000000 -0.208604  0.095573   0.017492  -0.130902
# Pts            -0.208604  1.000000  0.162063  -0.119664   0.023002
# Pts.1           0.095573  0.162063  1.000000   0.011607  -0.141262
# home_rank       0.017492 -0.119664  0.011607   1.000000   0.170917
# away_rank      -0.130902  0.023002 -0.141262   0.170917   1.000000
# home_team_code  0.003420  0.045547  0.012935  -0.091350  -0.033110
# away_team_code  0.007694 -0.037684 -0.029074  -0.029777  -0.036549
# home_results    0.130839 -0.122897  0.116521   0.175779  -0.132347
# win_rank       -0.016071 -0.132144  0.011447   0.751744   0.543810
# lose_rank      -0.101917  0.060833 -0.162179   0.427580   0.590066
# day_code       -0.057348  0.033827 -0.007105  -0.091570  -0.066931
#
#                 home_team_code  away_team_code  home_results  win_rank  \
# Wk                    0.003420        0.007694      0.130839 -0.016071
# Pts                   0.045547       -0.037684     -0.122897 -0.132144
# Pts.1                 0.012935       -0.029074      0.116521  0.011447
# home_rank            -0.091350       -0.029777      0.175779  0.751744
# away_rank            -0.033110       -0.036549     -0.132347  0.543810
# home_team_code        1.000000        0.004461     -0.035658 -0.070783
# away_team_code        0.004461        1.000000      0.162338 -0.052671
# home_results         -0.035658        0.162338      1.000000 -0.003972
# win_rank             -0.070783       -0.052671     -0.003972  1.000000
# lose_rank            -0.063356       -0.061501     -0.060757  0.229245
# day_code              0.038084        0.043094      0.020464 -0.083272
#
#                 lose_rank  day_code
# Wk              -0.101917 -0.057348
# Pts              0.060833  0.033827
# Pts.1           -0.162179 -0.007105
# home_rank        0.427580 -0.091570
# away_rank        0.590066 -0.066931
# home_team_code  -0.063356  0.038084
# away_team_code  -0.061501  0.043094
# home_results    -0.060757  0.020464
# win_rank         0.229245 -0.083272
# lose_rank        1.000000 -0.089608
# day_code        -0.089608  1.000000

# %%
df.cov()
# Out:
#                        Wk         Pts       Pts.1    home_rank   away_rank  \
# Wk              11.041278   -8.572065    3.296950     2.015235  -13.111212
# Pts             -8.572065  152.934600   20.806711   -51.309428    8.574340
# Pts.1            3.296950   20.806711  107.778765     4.178152  -44.205818
# home_rank        2.015235  -51.309428    4.178152  1202.153492  178.629309
# away_rank      -13.111212    8.574340  -44.205818   178.629309  908.602520
# home_team_code   0.432995   21.460488    5.116172  -120.673581  -38.024491
# away_team_code   1.663724  -30.326352  -19.642138   -67.185675  -71.692635
# home_results     0.253499   -0.886183    0.705342     3.553683   -2.326116
# win_rank        -2.017463  -61.740050    4.489956   984.725844  619.298632
# lose_rank       -8.710392   19.349653  -43.305304   381.309329  457.475397
# day_code        -0.127052    0.278914   -0.049183    -2.116857   -1.345151
#
#                 home_team_code  away_team_code  home_results     win_rank  \
# Wk                    0.432995        1.663724      0.253499    -2.017463
# Pts                  21.460488      -30.326352     -0.886183   -61.740050
# Pts.1                 5.116172      -19.642138      0.705342     4.489956
# home_rank          -120.673581      -67.185675      3.553683   984.725844
# away_rank           -38.024491      -71.692635     -2.326116   619.298632
# home_team_code     1451.597638       11.059324     -0.792153  -101.886722
# away_team_code       11.059324     4234.776568      6.159811  -129.495928
# home_results         -0.792153        6.159811      0.339986    -0.087503
# win_rank           -101.886722     -129.495928     -0.087503  1427.352686
# lose_rank           -62.085709     -102.939143     -0.911191   222.764686
# day_code              0.967447        1.869789      0.007955    -2.097587
#
#                  lose_rank  day_code
# Wk               -8.710392 -0.127052
# Pts              19.349653  0.278914
# Pts.1           -43.305304 -0.049183
# home_rank       381.309329 -2.116857
# away_rank       457.475397 -1.345151
# home_team_code  -62.085709  0.967447
# away_team_code -102.939143  1.869789
# home_results     -0.911191  0.007955
# win_rank        222.764686 -2.097587
# lose_rank       661.545780 -1.536684
# day_code         -1.536684  0.444541

# %%
covar = df.cov()
covar.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ea909_row0_col0, #T_ea909_row1_col1, #T_ea909_row2_col2, #T_ea909_row3_col3, #T_ea909_row4_col4, #T_ea909_row5_col5, #T_ea909_row6_col6, #T_ea909_row6_col7, #T_ea909_row6_col10, #T_ea909_row8_col8, #T_ea909_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ea909_row0_col2, #T_ea909_row7_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ea909_row0_col3, #T_ea909_row1_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col5, #T_ea909_row2_col9, #T_ea909_row7_col5, #T_ea909_row10_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col6, #T_ea909_row2_col4, #T_ea909_row7_col6, #T_ea909_row10_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ea909_row0_col8, #T_ea909_row1_col4, #T_ea909_row2_col5, #T_ea909_row10_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ea909_row0_col10 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ea909_row1_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ea909_row1_col2, #T_ea909_row8_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ea909_row1_col3, #T_ea909_row4_col5, #T_ea909_row5_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ea909_row1_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ea909_row1_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_ea909_row1_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ea909_row1_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ea909_row1_col10 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_ea909_row2_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_ea909_row2_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ea909_row2_col3, #T_ea909_row7_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ea909_row2_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ea909_row2_col7 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ea909_row2_col8, #T_ea909_row10_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ea909_row2_col10 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ea909_row3_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ea909_row3_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ea909_row3_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ea909_row3_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ea909_row3_col5, #T_ea909_row3_col10, #T_ea909_row4_col0, #T_ea909_row4_col2, #T_ea909_row4_col7, #T_ea909_row5_col3, #T_ea909_row6_col4, #T_ea909_row6_col8, #T_ea909_row6_col9, #T_ea909_row8_col1, #T_ea909_row8_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ea909_row3_col6, #T_ea909_row4_col6, #T_ea909_row8_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ea909_row3_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_ea909_row3_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ea909_row3_col9 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ea909_row4_col1, #T_ea909_row5_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ea909_row4_col3, #T_ea909_row9_col8 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ea909_row4_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_ea909_row4_col9 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_ea909_row4_col10 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ea909_row5_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_ea909_row5_col1 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_ea909_row5_col4, #T_ea909_row5_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ea909_row5_col7, #T_ea909_row9_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ea909_row5_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ea909_row5_col10 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_ea909_row6_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ea909_row6_col1, #T_ea909_row9_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ea909_row6_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ea909_row6_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ea909_row6_col5, #T_ea909_row7_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ea909_row7_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ea909_row7_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ea909_row7_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ea909_row7_col4, #T_ea909_row10_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ea909_row7_col9 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ea909_row7_col10 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_ea909_row8_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_ea909_row8_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ea909_row8_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_ea909_row8_col4 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_ea909_row8_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ea909_row8_col10, #T_ea909_row9_col2, #T_ea909_row9_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ea909_row9_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ea909_row9_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ea909_row9_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_ea909_row9_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ea909_row9_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ea909_row10_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_ea909_row10_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ea909_row10_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ea909_row10_col7 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ea909_row10_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ea909_row10_col10 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# </style>
# <table id="T_ea909_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Wk</th>
#       <th class="col_heading level0 col1" >Pts</th>
#       <th class="col_heading level0 col2" >Pts.1</th>
#       <th class="col_heading level0 col3" >home_rank</th>
#       <th class="col_heading level0 col4" >away_rank</th>
#       <th class="col_heading level0 col5" >home_team_code</th>
#       <th class="col_heading level0 col6" >away_team_code</th>
#       <th class="col_heading level0 col7" >home_results</th>
#       <th class="col_heading level0 col8" >win_rank</th>
#       <th class="col_heading level0 col9" >lose_rank</th>
#       <th class="col_heading level0 col10" >day_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea909_level0_row0" class="row_heading level0 row0" >Wk</th>
#       <td id="T_ea909_row0_col0" class="data row0 col0" >11.041278</td>
#       <td id="T_ea909_row0_col1" class="data row0 col1" >-8.572065</td>
#       <td id="T_ea909_row0_col2" class="data row0 col2" >3.296950</td>
#       <td id="T_ea909_row0_col3" class="data row0 col3" >2.015235</td>
#       <td id="T_ea909_row0_col4" class="data row0 col4" >-13.111212</td>
#       <td id="T_ea909_row0_col5" class="data row0 col5" >0.432995</td>
#       <td id="T_ea909_row0_col6" class="data row0 col6" >1.663724</td>
#       <td id="T_ea909_row0_col7" class="data row0 col7" >0.253499</td>
#       <td id="T_ea909_row0_col8" class="data row0 col8" >-2.017463</td>
#       <td id="T_ea909_row0_col9" class="data row0 col9" >-8.710392</td>
#       <td id="T_ea909_row0_col10" class="data row0 col10" >-0.127052</td>
#     </tr>
#     <tr>
#       <th id="T_ea909_level0_row1" class="row_heading level0 row1" >Pts</th>
#       <td id="T_ea909_row1_col0" class="data row1 col0" >-8.572065</td>
#       <td id="T_ea909_row1_col1"

# %%
df = df.drop(columns=['Time', 'Winner', 'Loser', 'dates'])

# %%
df
# Out:
#      Wk  Pts  Pts.1           winners            losers  home_rank  away_rank  \
# 0     1   43     13  Florida Atlantic         Charlotte         99         99
# 1     1   47      7     Florida State          Duquesne         99         99
# 2     1   38      6          Illinois           Wyoming         99         99
# 3     1   23     12            Nevada  New Mexico State         99         99
# 4     1   52     21  Nevada-Las Vegas       Idaho State         99         99
# ..   ..  ...    ...               ...               ...        ...        ...
# 709  12   37     34        Washington            Oregon          6         24
# 710  12   28     18  Washington State     Arizona State         99         99
# 711  12   23     20     West Virginia          Oklahoma         99         99
# 712  12   45     10  Western Kentucky              Rice         99         99
# 713  12   14     13           Wyoming    Colorado State         99         99
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 0                32              37             0        99         99
# 1                34              49             0        99         99
# 2                42             221             0        99         99
# 3                76             121             1        99         99
# 4                74              76             0        99         99
# ..              ...             ...           ...       ...        ...
# 709              88             210             1        24          6
# 710             126              11             0        99         99
# 711             127             143             0        99         99
# 712             128             153             0        99         99
# 713              26             221             1        99         99
#
#      day_code
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5
# ..        ...
# 709         5
# 710         5
# 711         5
# 712         5
# 713         5
#
# [714 rows x 13 columns]

# %%
df[df['winners'] == 'Oregon']
# Out:
#      Wk  Pts  Pts.1 winners              losers  home_rank  away_rank  \
# 144   3   70     14  Oregon  Eastern Washington         99         99
# 222   4   41     20  Oregon       Brigham Young         25         12
# 291   5   44     41  Oregon    Washington State         99         15
# 359   6   45     27  Oregon            Stanford         13         99
# 414   7   49     22  Oregon             Arizona         99         12
# 520   9   45     30  Oregon                UCLA         10          9
# 579  10   42     24  Oregon          California         99          8
# 628  11   49     10  Oregon            Colorado         99          8
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 144              88              54             0        99         99
# 222              88              24             0        25         12
# 291             126             146             1        15         99
# 359              88             177             0        13         99
# 414               5             146             1        12         99
# 520              88             200             0        10          9
# 579              18             146             1         8         99
# 628              25             146             1         8         99
#
#      day_code
# 144         5
# 222         5
# 291         5
# 359         5
# 414         5
# 520         5
# 579         5
# 628         5

# %%
df[df['winners'] == 'Utah']
# Out:
#      Wk  Pts  Pts.1 winners               losers  home_rank  away_rank  \
# 168   3   73      7    Utah        Southern Utah         13         99
# 238   4   35      7    Utah      San Diego State         14         99
# 311   5   34     13    Utah        Arizona State         99         13
# 372   6   42     16    Utah         Oregon State         12         99
# 483   8   43     42    Utah  Southern California         20          7
# 543  10   21     17    Utah     Washington State         99         14
# 644  11   45     20    Utah              Arizona         12         99
# 706  12   42      7    Utah             Stanford         13         99
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 168             119             175             0        13         99
# 238             119             160             0        14         99
# 311               6             201             1        13         99
# 372             119             147             0        12         99
# 483             119             171             0        20          7
# 543             126             201             1        14         99
# 644             119              10             0        12         99
# 706             119             177             0        13         99
#
#      day_code
# 168         5
# 238         5
# 311         5
# 372         5
# 483         5
# 543         3
# 644         5
# 706         5

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as se
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest,f_regression,f_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.ensemble import GradientBoostingRegressor

# %%
df.head()
# Out:
#    Wk  Pts  Pts.1           winners            losers  home_rank  away_rank  \
# 0   1   43     13  Florida Atlantic         Charlotte         99         99
# 1   1   47      7     Florida State          Duquesne         99         99
# 2   1   38      6          Illinois           Wyoming         99         99
# 3   1   23     12            Nevada  New Mexico State         99         99
# 4   1   52     21  Nevada-Las Vegas       Idaho State         99         99
#
#    home_team_code  away_team_code  home_results  win_rank  lose_rank  day_code
# 0              32              37             0        99         99         5
# 1              34              49             0        99         99         5
# 2              42             221             0        99         99         5
# 3              76             121             1        99         99         5
# 4              74              76             0        99         99         5

# %%
X = df.drop(columns=['winners', 'losers', 'Pts.1'])

# %%
y = df['Pts.1']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
regr = RandomForestRegressor(max_depth=50000, random_state=0)
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=50000, random_state=0)

# %%
test_pred = regr.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))
# Out:
# RMSE: 10.476451749458938
# R Squared: -0.06409468924887585
# MSE TEST: 109.75604125874126
# MAE TEST: 8.266923076923074
# MAPE: 3347150827950604.0

# %%
df[df['winners'] == 'Southern California']
# Out:
#      Wk  Pts  Pts.1              winners            losers  home_rank  \
# 76    2   66     14  Southern California              Rice         14
# 153   3   41     28  Southern California          Stanford         99
# 228   4   45     17  Southern California      Fresno State          7
# 300   5   17     14  Southern California      Oregon State         99
# 365   6   42     25  Southern California     Arizona State          6
# 420   7   30     14  Southern California  Washington State          6
# 582  10   45     37  Southern California           Arizona         99
# 635  11   41     35  Southern California        California          9
# 659  12   55     17  Southern California          Colorado          8
#
#      away_rank  home_team_code  away_team_code  home_results  win_rank  \
# 76          99             100             153             0        14
# 153         10             103             171             1        10
# 228         99             100              62             0         7
# 300          7              89             171             1         7
# 365         99             100              11             0         6
# 420         99             100             211             0         6
# 582         10               5             171             1        10
# 635         99             100              29             0         9
# 659         99             100              44             0         8
#
#      lose_rank  day_code
# 76          99         5
# 153         99         5
# 228         99         5
# 300         99         5
# 365         99         5
# 420         99         5
# 582         99         5
# 635         99         5
# 659         99         4

# %% [markdown]
# utah 10 at oregeon 12
# utah away code = 201
# oregon home code = 146

# %%
df[df['winners'] == 'UCLA']
# Out:
#      Wk  Pts  Pts.1 winners         losers  home_rank  away_rank  \
# 84    2   45     17    UCLA  Bowling Green         99         99
# 167   3   45      7    UCLA  Alabama State         99         99
# 237   4   32     31    UCLA  South Alabama         99         99
# 310   5   45     17    UCLA       Colorado         99         99
# 320   6   40     32    UCLA     Washington         99         15
# 429   7   42     32    UCLA           Utah         18         11
# 587  10   38     13    UCLA       Stanford         12         99
# 643  11   50     36    UCLA  Arizona State         99         10
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 84              118              23             0        99         99
# 167             118               5             0        99         99
# 237             118             162             0        99         99
# 310              25             200             1        99         99
# 320             118             210             0        99         15
# 429             118             201             0        18         11
# 587             118             177             0        12         99
# 643               6             200             1        10         99
#
#      day_code
# 84          5
# 167         5
# 237         5
# 310         5
# 320         4
# 429         5
# 587         5
# 643         5

# %%
X.head()
# Out:
#    Wk  Pts  home_rank  away_rank  home_team_code  away_team_code  \
# 0   1   43         99         99              32              37
# 1   1   47         99         99              34              49
# 2   1   38         99         99              42             221
# 3   1   23         99         99              76             121
# 4   1   52         99         99              74              76
#
#    home_results  win_rank  lose_rank  day_code
# 0             0        99         99         5
# 1             0        99         99         5
# 2             0        99         99         5
# 3             1        99         99         5
# 4             0        99         99         5

# %% [markdown]
# USC away team = 171 / rank 7
#
# UCLA home team = 118 / rank 16

# %%
sc = [[13, 42, 16, 7, 118, 171, 1, 7, 16, 5]]
usc = pd.DataFrame(sc, columns=['Wk', 'Pts', 'home_rank', 'away_rank',
                                'home_team_code', 'away_team_code', 'home_results', 
                               'win_rank', 'lose_rank', 'day_code'])
usc

# sc = [[13, 16, 7, 118, 171, 5]]
# usc = pd.DataFrame(sc, columns=['Wk', 'home_rank', 'away_rank',
#                                 'home_team_code', 'away_team_code', 'day_code'])
# usc
# Out:
#    Wk  Pts  home_rank  away_rank  home_team_code  away_team_code  \
# 0  13   42         16          7             118             171
#
#    home_results  win_rank  lose_rank  day_code
# 0             1         7         16         5

# %%
test_pred = regr.predict(usc)
test_pred
# Out:
# array([31.27])

# %% [markdown]
# ## USC wins 0.64
#
# #### USC 42.08 - UCLA 31.27

# %% [markdown]
# ## Oddshark prediction
# #### USC   43.8 - UCLA 40.6
#
# #### USC spread -2.5
# -------

# %% [markdown]
# # oregon wins 0.45
#
# ## Oregon 40.6 - Utah 31.27

# %% [markdown]
# ## Oddshark prediction
# oregon 41.2 -  Utah 36.8
#
# spread is oregon -3
# over/under is 61.5

# %% [markdown]
# ###  R-Squared reading can be much higher, such as 0.9 or above. In finance, an R-Squared above 0.7 would generally be seen as showing a high level of correlation, whereas a measure below 0.4 would show a low correlation.

# %% [markdown]
# ### The lower the MAE score the better. This is because MAE is a measure of the average error between the predictions and intended targets, thus we want to minimise this value.

# %% [markdown]
# ### The lower the MSE value there more accurate the model is.
