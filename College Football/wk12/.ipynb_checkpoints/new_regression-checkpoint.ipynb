# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('encoded_df.csv')

# %%
df.head()
# Out:
#    Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0   1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1   1     Florida State   47          Duquesne      7     Florida State
# 2   1          Illinois   38           Wyoming      6          Illinois
# 3   1            Nevada   23  New Mexico State     12            Nevada
# 4   1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
#
#              losers  home_rank  away_rank  home_team_code  away_team_code  \
# 0         Charlotte         99         99              32              37
# 1          Duquesne         99         99              34              49
# 2           Wyoming         99         99              42             221
# 3  New Mexico State         99         99              76             121
# 4       Idaho State         99         99              74              76
#
#    home_results  win_rank  lose_rank  day_code  hours  null  half  quart  \
# 0             0        99         99         5     19     1     0      0
# 1             0        99         99         5     17     1     0      0
# 2             0        99         99         5     16     1     0      0
# 3             1        99         99         5     22     1     0      0
# 4             0        99         99         5     15     0     1      0
#
#    three_quart
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df = df.drop(columns=['Winner', 'Loser', 'hours', 'null', 'half', 'quart', 'three_quart'])

# %%
df[df['winners'] == 'Louisiana State']
# Out:
#      Wk  Pts  Pts.1          winners             losers  home_rank  away_rank  \
# 124   3   65     17  Louisiana State           Southern         99         99
# 206   4   31     16  Louisiana State  Mississippi State         99         99
# 273   5   38      0  Louisiana State         New Mexico         99         99
# 347   6   21     17  Louisiana State             Auburn         99         99
# 458   8   45     35  Louisiana State            Florida         99         99
# 511   9   45     20  Louisiana State        Mississippi         99          7
# 614  11   32     31  Louisiana State            Alabama         15          6
# 681  12   13     10  Louisiana State           Arkansas         99          7
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 124              53             170             0        99         99
# 206              53             114             0        99         99
# 273              53             124             0        99         99
# 347              10              96             1        99         99
# 458              31              96             1        99         99
# 511              53             113             0        99          7
# 614              53               3             0        15          6
# 681               7              96             1         7         99
#
#      day_code
# 124         5
# 206         5
# 273         5
# 347         5
# 458         5
# 511         5
# 614         5
# 681         5

# %%
df[df['losers'] == 'Alabama-Birmingham']
# Out:
#      Wk  Pts  Pts.1            winners              losers  home_rank  \
# 122   3   21     14            Liberty  Alabama-Birmingham         99
# 362   6   28     24               Rice  Alabama-Birmingham         99
# 491   9   20     17   Western Kentucky  Alabama-Birmingham         99
# 555  10   24     17   Florida Atlantic  Alabama-Birmingham         99
# 640  11   44     38  Texas-San Antonio  Alabama-Birmingham         99
#
#      away_rank  home_team_code  away_team_code  home_results  win_rank  \
# 122         99              51               6             0        99
# 362         99              93               6             0        99
# 491         99             128               6             0        99
# 555         99              32               6             0        99
# 640         99               3             194             1        99
#
#      lose_rank  day_code
# 122         99         5
# 362         99         5
# 491         99         4
# 555         99         5
# 640         99         5

# %%
X = df.drop(columns=['winners', 'losers', 'Pts.1'])

# %%
y = df['Pts.1']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
regr = RandomForestRegressor(max_depth=50000, random_state=0)
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=50000, random_state=0)

# %%
test_pred = regr.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))
# Out:
# RMSE: 10.476451749458938
# R Squared: -0.06409468924887585
# MSE TEST: 109.75604125874126
# MAE TEST: 8.266923076923074
# MAPE: 3347150827950604.0

# %%
X
# Out:
#      Wk  Pts  home_rank  away_rank  home_team_code  away_team_code  \
# 0     1   43         99         99              32              37
# 1     1   47         99         99              34              49
# 2     1   38         99         99              42             221
# 3     1   23         99         99              76             121
# 4     1   52         99         99              74              76
# ..   ..  ...        ...        ...             ...             ...
# 709  12   37          6         24              88             210
# 710  12   28         99         99             126              11
# 711  12   23         99         99             127             143
# 712  12   45         99         99             128             153
# 713  12   14         99         99              26             221
#
#      home_results  win_rank  lose_rank  day_code
# 0               0        99         99         5
# 1               0        99         99         5
# 2               0        99         99         5
# 3               1        99         99         5
# 4               0        99         99         5
# ..            ...       ...        ...       ...
# 709             1        24          6         5
# 710             0        99         99         5
# 711             0        99         99         5
# 712             0        99         99         5
# 713             1        99         99         5
#
# [714 rows x 10 columns]

# %%
# lsu homecode = 53
# uab awaycode = 6

# %%
# og = [[13, 39, 12, 10, 146, 201, 0, 12, 110, 5, 10]]
# uo = pd.DataFrame(og, columns=['Wk', 'Pts', 'home_rank', 'away_rank',
#                                 'home_team_code', 'away_team_code', 'home_results', 
#                                'win_rank', 'lose_rank', 'day_code', 'hours'])
# uo

la = [[13, 37, 6, 99, 53, 6, 0, 6, 99, 5]]
lsu = pd.DataFrame(la, columns=['Wk', 'Pts', 'home_rank', 'away_rank',
                                'home_team_code', 'away_team_code', 'home_results', 
                               'win_rank', 'lose_rank', 'day_code'])
lsu

# oregon home code = 146 - 12

# utah away code = 201 - 10

# sc = [[13, 16, 7, 118, 171, 5]]
# usc = pd.DataFrame(sc, columns=['Wk', 'home_rank', 'away_rank',
#                                 'home_team_code', 'away_team_code', 'day_code'])
# usc
# Out:
#    Wk  Pts  home_rank  away_rank  home_team_code  away_team_code  \
# 0  13   37          6         99              53               6
#
#    home_results  win_rank  lose_rank  day_code
# 0             0         6         99         5

# %%
test_pred = regr.predict(lsu)
test_pred
# Out:
# array([21.8])

# %%
37.13-21.8
# Out:
# 15.330000000000002

# %% [markdown]
# # lsu 37.13 - uab 21.8
# ##### difference 15.3
#
# # wire shark prediction
# ### lsu 39.4 - uab 29.0
#
# ### lsu -14.5
# ### over/under 52.5

# %%
# with minutes and hours
# oregon 37.72
# utah 20.38

# %%
# with hours and not minutes
# oregon 38.72 
# urtah 21.12

# %%
# with ouliers and hours but without minutes
# oregon 38.83
# Utah 24.15

# with outliers and without hours
# Oregon 40.49
# Utah 21.12
