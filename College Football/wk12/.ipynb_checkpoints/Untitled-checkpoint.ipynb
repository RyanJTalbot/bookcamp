# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('encoded_df.csv')

# %%
df.head()
# Out:
#    Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0   1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1   1     Florida State   47          Duquesne      7     Florida State
# 2   1          Illinois   38           Wyoming      6          Illinois
# 3   1            Nevada   23  New Mexico State     12            Nevada
# 4   1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
#
#              losers  home_rank  away_rank  home_team_code  away_team_code  \
# 0         Charlotte         99         99              32              37
# 1          Duquesne         99         99              34              49
# 2           Wyoming         99         99              42             221
# 3  New Mexico State         99         99              76             121
# 4       Idaho State         99         99              74              76
#
#    home_results  win_rank  lose_rank  day_code  hours  null  half  quart  \
# 0             0        99         99         5     19     1     0      0
# 1             0        99         99         5     17     1     0      0
# 2             0        99         99         5     16     1     0      0
# 3             1        99         99         5     22     1     0      0
# 4             0        99         99         5     15     0     1      0
#
#    three_quart
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df = df.drop(columns=['Winner', 'Loser', 'null', 'half', 'quart', 'three_quart'])

# %%
df[df['winners'] == 'Oregon']
# Out:
#      Wk  Pts  Pts.1 winners            losers  home_rank  away_rank  \
# 203   4   41     20  Oregon     Brigham Young         25         12
# 267   5   44     41  Oregon  Washington State         99         15
# 334   6   45     27  Oregon          Stanford         13         99
# 387   7   49     22  Oregon           Arizona         99         12
# 491   9   45     30  Oregon              UCLA         10          9
# 548  10   42     24  Oregon        California         99          8
# 597  11   49     10  Oregon          Colorado         99          8
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 203              88              24             0        25         12
# 267             126             146             1        15         99
# 334              88             177             0        13         99
# 387               5             146             1        12         99
# 491              88             200             0        10          9
# 548              18             146             1         8         99
# 597              25             146             1         8         99
#
#      day_code  hours
# 203         5     15
# 267         5     16
# 334         5     11
# 387         5     20
# 491         5     15
# 548         5     15
# 597         5     15

# %%
df[df['winners'] == 'Utah']
# Out:
#      Wk  Pts  Pts.1 winners               losers  home_rank  away_rank  \
# 216   4   35      7    Utah      San Diego State         14         99
# 287   5   34     13    Utah        Arizona State         99         13
# 347   6   42     16    Utah         Oregon State         12         99
# 455   8   43     42    Utah  Southern California         20          7
# 512  10   21     17    Utah     Washington State         99         14
# 612  11   45     20    Utah              Arizona         12         99
# 672  12   42      7    Utah             Stanford         13         99
#
#      home_team_code  away_team_code  home_results  win_rank  lose_rank  \
# 216             119             160             0        14         99
# 287               6             201             1        13         99
# 347             119             147             0        12         99
# 455             119             171             0        20          7
# 512             126             201             1        14         99
# 612             119              10             0        12         99
# 672             119             177             0        13         99
#
#      day_code  hours
# 216         5     22
# 287         5     22
# 347         5     14
# 455         5     20
# 512         3     22
# 612         5     19
# 672         5     22

# %%
X = df.drop(columns=['winners', 'losers', 'Pts.1'])

# %%
y = df['Pts.1']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
regr = RandomForestRegressor(max_depth=50000, random_state=0)
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=50000, random_state=0)

# %%
test_pred = regr.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))
# Out:
# RMSE: 9.97114384405438
# R Squared: 0.1996085694687214
# MSE TEST: 99.42370955882355
# MAE TEST: 8.033455882352941
# MAPE: 4511878303156104.0

# %%
X
# Out:
#      Wk  Pts  home_rank  away_rank  home_team_code  away_team_code  \
# 0     1   43         99         99              32              37
# 1     1   47         99         99              34              49
# 2     1   38         99         99              42             221
# 3     1   23         99         99              76             121
# 4     1   52         99         99              74              76
# ..   ..  ...        ...        ...             ...             ...
# 675  12   37          6         24              88             210
# 676  12   28         99         99             126              11
# 677  12   23         99         99             127             143
# 678  12   45         99         99             128             153
# 679  12   14         99         99              26             221
#
#      home_results  win_rank  lose_rank  day_code  hours
# 0               0        99         99         5     19
# 1               0        99         99         5     17
# 2               0        99         99         5     16
# 3               1        99         99         5     22
# 4               0        99         99         5     15
# ..            ...       ...        ...       ...    ...
# 675             1        24          6         5     19
# 676             0        99         99         5     15
# 677             0        99         99         5     12
# 678             0        99         99         5     14
# 679             1        99         99         5     19
#
# [680 rows x 11 columns]

# %%
og = [[13, 39, 12, 10, 146, 201, 0, 12, 110, 5, 10]]
uo = pd.DataFrame(og, columns=['Wk', 'Pts', 'home_rank', 'away_rank',
                                'home_team_code', 'away_team_code', 'home_results', 
                               'win_rank', 'lose_rank', 'day_code', 'hours'])
uo

# oregon home code = 146 - 12

# utah away code = 201 - 10

# sc = [[13, 16, 7, 118, 171, 5]]
# usc = pd.DataFrame(sc, columns=['Wk', 'home_rank', 'away_rank',
#                                 'home_team_code', 'away_team_code', 'day_code'])
# usc
# Out:
#    Wk  Pts  home_rank  away_rank  home_team_code  away_team_code  \
# 0  13   39         12         10             146             201
#
#    home_results  win_rank  lose_rank  day_code  hours
# 0             0        12        110         5     10

# %%
test_pred = regr.predict(uo)
test_pred
# Out:
# array([21.12])

# %%
# with minutes and hours
# oregon 37.72
# utah 20.38

# %%
# with hours and not minutes
# oregon 38.72 
# urtah 21.12
