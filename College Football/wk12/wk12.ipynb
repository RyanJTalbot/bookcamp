# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

df["home_team_code"] = df["home_team"].astype("category").cat.codes

# %%
df = pd.read_csv('sportsref_download.csv')

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 709  12  12-Nov-22   7:00 PM  Sat   (24) Washington   37          @
# 710  12  12-Nov-22   3:30 PM  Sat  Washington State   28        NaN
# 711  12  12-Nov-22  12:00 PM  Sat     West Virginia   23        NaN
# 712  12  12-Nov-22   2:00 PM  Sat  Western Kentucky   45        NaN
# 713  12  12-Nov-22   7:00 PM  Sat           Wyoming   14          @
#
#                 Loser  Pts.1
# 0           Charlotte     13
# 1            Duquesne      7
# 2             Wyoming      6
# 3    New Mexico State     12
# 4         Idaho State     21
# ..                ...    ...
# 709        (6) Oregon     34
# 710     Arizona State     18
# 711          Oklahoma     20
# 712              Rice     10
# 713    Colorado State     13
#
# [714 rows x 9 columns]

# %%
won = df['Winner']
new_winner = []

for i in won:
    if(i[2] == ")"):
        new_winner.append(i[4:])
#         if(i[1] == "("):
#             new_winner.append(i[5:])
    elif(i[3] == ")"):
        new_winner.append(i[5:])
    else:
        new_winner.append(i)

# %%
df.shape
# Out:
# (714, 9)

# %%
len(new_winner)
# Out:
# 714

# %%
df['winners'] = new_winner

# %%
lost = df['Loser']
new_lose = []

for i in lost:
    if(i[2] == ")"):
        new_lose.append(i[4:])
#         if(i[1] == "("):
#             new_winner.append(i[5:])
    elif(i[3] == ")"):
        new_lose.append(i[5:])
    else:
        new_lose.append(i)

# %%
df['losers'] = new_lose

# %%
location = df['Unnamed: 6']
home = []

for index, row in df.iterrows():
    location = (row['Unnamed: 6'])
    if (location == 'N'):
        home.append('Neutral')
    elif (location == '@'):
        home.append(row['Loser'])
    else:
        home.append(row['Winner'])

# %%
df['home_team'] = home

# %%
away = []
for index, row in df.iterrows():
    if (row['home_team'] == row['Winner']):
        away.append(row['Loser'])
    elif (row['home_team'] == row['Loser']):
        away.append(row['Winner'])
    else:
        away.append('neutral')

# %%
df['away'] = away

# %%
df.away.value_counts()
# Out:
# neutral               12
# Buffalo                7
# Charlotte              6
# Louisiana Tech         6
# Northern Illinois      6
#                       ..
# Northern Colorado      1
# North Dakota State     1
# Missouri State         1
# Villanova              1
# (24) Washington        1
# Name: away, Length: 301, dtype: int64

# %%
df['winners'].value_counts()
# Out:
# Ohio State             10
# Georgia                10
# Michigan               10
# Texas Christian        10
# Southern California     9
#                        ..
# Incarnate Word          1
# Holy Cross              1
# Eastern Kentucky        1
# Delaware                1
# Colorado                1
# Name: winners, Length: 139, dtype: int64

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 709  12  12-Nov-22   7:00 PM  Sat   (24) Washington   37          @
# 710  12  12-Nov-22   3:30 PM  Sat  Washington State   28        NaN
# 711  12  12-Nov-22  12:00 PM  Sat     West Virginia   23        NaN
# 712  12  12-Nov-22   2:00 PM  Sat  Western Kentucky   45        NaN
# 713  12  12-Nov-22   7:00 PM  Sat           Wyoming   14          @
#
#                 Loser  Pts.1           winners            losers  \
# 0           Charlotte     13  Florida Atlantic         Charlotte
# 1            Duquesne      7     Florida State          Duquesne
# 2             Wyoming      6          Illinois           Wyoming
# 3    New Mexico State     12            Nevada  New Mexico State
# 4         Idaho State     21  Nevada-Las Vegas       Idaho State
# ..                ...    ...               ...               ...
# 709        (6) Oregon     34        Washington            Oregon
# 710     Arizona State     18  Washington State     Arizona State
# 711          Oklahoma     20     West Virginia          Oklahoma
# 712              Rice     10  Western Kentucky              Rice
# 713    Colorado State     13           Wyoming    Colorado State
#
#             home_team             away
# 0    Florida Atlantic        Charlotte
# 1       Florida State         Duquesne
# 2            Illinois          Wyoming
# 3    New Mexico State           Nevada
# 4    Nevada-Las Vegas      Idaho State
# ..                ...              ...
# 709        (6) Oregon  (24) Washington
# 710  Washington State    Arizona State
# 711     West Virginia         Oklahoma
# 712  Western Kentucky             Rice
# 713    Colorado State          Wyoming
#
# [714 rows x 13 columns]

# %%
home = df['home_team']

home_rank = []

for i in home:
    if (i[2] == ")"):
        home_rank.append(i[1:2])
    elif(i[3] == ")"):
        home_rank.append(i[1:3])
    else:
        home_rank.append(99)

# %%
away = df['away']

away_rank = []

for i in away:
    if (i[2] == ")"):
        away_rank.append(i[1:2])
    elif(i[3] == ")"):
        away_rank.append(i[1:3])
    else:
        away_rank.append(99)

# %%
df['home_rank'] = home_rank

# %%
df['away_rank'] = away_rank

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 709  12  12-Nov-22   7:00 PM  Sat   (24) Washington   37          @
# 710  12  12-Nov-22   3:30 PM  Sat  Washington State   28        NaN
# 711  12  12-Nov-22  12:00 PM  Sat     West Virginia   23        NaN
# 712  12  12-Nov-22   2:00 PM  Sat  Western Kentucky   45        NaN
# 713  12  12-Nov-22   7:00 PM  Sat           Wyoming   14          @
#
#                 Loser  Pts.1           winners            losers  \
# 0           Charlotte     13  Florida Atlantic         Charlotte
# 1            Duquesne      7     Florida State          Duquesne
# 2             Wyoming      6          Illinois           Wyoming
# 3    New Mexico State     12            Nevada  New Mexico State
# 4         Idaho State     21  Nevada-Las Vegas       Idaho State
# ..                ...    ...               ...               ...
# 709        (6) Oregon     34        Washington            Oregon
# 710     Arizona State     18  Washington State     Arizona State
# 711          Oklahoma     20     West Virginia          Oklahoma
# 712              Rice     10  Western Kentucky              Rice
# 713    Colorado State     13           Wyoming    Colorado State
#
#             home_team             away home_rank away_rank
# 0    Florida Atlantic        Charlotte        99        99
# 1       Florida State         Duquesne        99        99
# 2            Illinois          Wyoming        99        99
# 3    New Mexico State           Nevada        99        99
# 4    Nevada-Las Vegas      Idaho State        99        99
# ..                ...              ...       ...       ...
# 709        (6) Oregon  (24) Washington         6        24
# 710  Washington State    Arizona State        99        99
# 711     West Virginia         Oklahoma        99        99
# 712  Western Kentucky             Rice        99        99
# 713    Colorado State          Wyoming        99        99
#
# [714 rows x 15 columns]

# %%
home = df['home_team']
home_team = []

for i in home:
    if(i[2] == ")"):
        home_team.append(i[4:])
#         if(i[1] == "("):
#             new_winner.append(i[5:])
    elif(i[3] == ")"):
        home_team.append(i[5:])
    else:
        home_team.append(i)

# %%
df['home_team'] = home_team

# %%
aways = df['away']
away_team = []

for i in aways:
    if(i[2] == ")"):
        away_team.append(i[4:])
#         if(i[1] == "("):
#             new_winner.append(i[5:])
    elif(i[3] == ")"):
        away_team.append(i[5:])
    else:
        away_team.append(i)

# %%
df['away'] = away_team

# %%
df
# Out:
#      Wk       Date      Time  Day            Winner  Pts Unnamed: 6  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43        NaN
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47        NaN
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38        NaN
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23          @
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52        NaN
# ..   ..        ...       ...  ...               ...  ...        ...
# 709  12  12-Nov-22   7:00 PM  Sat   (24) Washington   37          @
# 710  12  12-Nov-22   3:30 PM  Sat  Washington State   28        NaN
# 711  12  12-Nov-22  12:00 PM  Sat     West Virginia   23        NaN
# 712  12  12-Nov-22   2:00 PM  Sat  Western Kentucky   45        NaN
# 713  12  12-Nov-22   7:00 PM  Sat           Wyoming   14          @
#
#                 Loser  Pts.1           winners            losers  \
# 0           Charlotte     13  Florida Atlantic         Charlotte
# 1            Duquesne      7     Florida State          Duquesne
# 2             Wyoming      6          Illinois           Wyoming
# 3    New Mexico State     12            Nevada  New Mexico State
# 4         Idaho State     21  Nevada-Las Vegas       Idaho State
# ..                ...    ...               ...               ...
# 709        (6) Oregon     34        Washington            Oregon
# 710     Arizona State     18  Washington State     Arizona State
# 711          Oklahoma     20     West Virginia          Oklahoma
# 712              Rice     10  Western Kentucky              Rice
# 713    Colorado State     13           Wyoming    Colorado State
#
#             home_team           away home_rank away_rank
# 0    Florida Atlantic      Charlotte        99        99
# 1       Florida State       Duquesne        99        99
# 2            Illinois        Wyoming        99        99
# 3    New Mexico State         Nevada        99        99
# 4    Nevada-Las Vegas    Idaho State        99        99
# ..                ...            ...       ...       ...
# 709            Oregon     Washington         6        24
# 710  Washington State  Arizona State        99        99
# 711     West Virginia       Oklahoma        99        99
# 712  Western Kentucky           Rice        99        99
# 713    Colorado State        Wyoming        99        99
#
# [714 rows x 15 columns]

# %%
df["home_team_code"] = df["home_team"].astype("category").cat.codes

# %%
df["away_team_code"] = df["away"].astype("category").cat.codes

# %%
homes = df['home_team']

# %%
df1 = df.copy()

# %%
df1[df1['away'] == 'Utah']
# Out:
#      Wk       Date      Time  Day     Winner  Pts Unnamed: 6  \
# 47    2   3-Sep-22   7:00 PM  Sat    Florida   29        NaN
# 311   5  24-Sep-22  10:30 PM  Sat  (13) Utah   34          @
# 429   7   8-Oct-22   3:30 PM  Sat  (18) UCLA   42        NaN
# 543  10  27-Oct-22  10:00 PM  Thu  (14) Utah   21          @
#
#                 Loser  Pts.1  winners            losers         home_team  \
# 47           (7) Utah     26  Florida              Utah           Florida
# 311     Arizona State     13     Utah     Arizona State     Arizona State
# 429         (11) Utah     32     UCLA              Utah              UCLA
# 543  Washington State     17     Utah  Washington State  Washington State
#
#      away home_rank away_rank  home_team_code  away_team_code
# 47   Utah        99         7              31             201
# 311  Utah        99        13               6             201
# 429  Utah        18        11             118             201
# 543  Utah        99        14             126             201

# %%
df1[df1['home_team'] == 'Oregon']
# Out:
#      Wk       Date      Time  Day           Winner  Pts Unnamed: 6  \
# 144   3  10-Sep-22   8:30 PM  Sat           Oregon   70        NaN
# 222   4  17-Sep-22   3:30 PM  Sat      (25) Oregon   41        NaN
# 359   6   1-Oct-22  11:00 PM  Sat      (13) Oregon   45        NaN
# 520   9  22-Oct-22   3:30 PM  Sat      (10) Oregon   45        NaN
# 709  12  12-Nov-22   7:00 PM  Sat  (24) Washington   37          @
#
#                   Loser  Pts.1     winners              losers home_team  \
# 144  Eastern Washington     14      Oregon  Eastern Washington    Oregon
# 222  (12) Brigham Young     20      Oregon       Brigham Young    Oregon
# 359            Stanford     27      Oregon            Stanford    Oregon
# 520            (9) UCLA     30      Oregon                UCLA    Oregon
# 709          (6) Oregon     34  Washington              Oregon    Oregon
#
#                    away home_rank away_rank  home_team_code  away_team_code
# 144  Eastern Washington        99        99              88              54
# 222       Brigham Young        25        12              88              24
# 359            Stanford        13        99              88             177
# 520                UCLA        10         9              88             200
# 709          Washington         6        24              88             210

# %%
home_results = []
for index, row in df1.iterrows():
    if (row['home_team'] == row['winners']):
        home_results.append(0)
    elif (row['home_team'] == row['losers']):
        home_results.append(1)
    else:
        home_results.append(3)

# %%
df1['home_results'] = home_results

# %%
wins = df1['Winner']

# %%
winners = []
for i in wins:
    if (i[2] == ")"):
        winners.append(i[1:2])
    elif(i[3] == ")"):
        winners.append(i[1:3])
    else:
        winners.append(99)

# %%
df1['win_rank'] = winners

# %%
lose = df1['Loser']

# %%
losers = []
for i in lose:
    if (i[2] == ")"):
        losers.append(i[1:2])
    elif(i[3] == ")"):
        losers.append(i[1:3])
    else:
        losers.append(99)

# %%
len(losers)
# Out:
# 714

# %%
df1['lose_rank'] = losers

# %%
df1 = df1.drop(columns=['Unnamed: 6'])

# %%
df1
# Out:
#      Wk       Date      Time  Day            Winner  Pts             Loser  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43         Charlotte
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47          Duquesne
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38           Wyoming
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23  New Mexico State
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52       Idaho State
# ..   ..        ...       ...  ...               ...  ...               ...
# 709  12  12-Nov-22   7:00 PM  Sat   (24) Washington   37        (6) Oregon
# 710  12  12-Nov-22   3:30 PM  Sat  Washington State   28     Arizona State
# 711  12  12-Nov-22  12:00 PM  Sat     West Virginia   23          Oklahoma
# 712  12  12-Nov-22   2:00 PM  Sat  Western Kentucky   45              Rice
# 713  12  12-Nov-22   7:00 PM  Sat           Wyoming   14    Colorado State
#
#      Pts.1           winners            losers         home_team  \
# 0       13  Florida Atlantic         Charlotte  Florida Atlantic
# 1        7     Florida State          Duquesne     Florida State
# 2        6          Illinois           Wyoming          Illinois
# 3       12            Nevada  New Mexico State  New Mexico State
# 4       21  Nevada-Las Vegas       Idaho State  Nevada-Las Vegas
# ..     ...               ...               ...               ...
# 709     34        Washington            Oregon            Oregon
# 710     18  Washington State     Arizona State  Washington State
# 711     20     West Virginia          Oklahoma     West Virginia
# 712     10  Western Kentucky              Rice  Western Kentucky
# 713     13           Wyoming    Colorado State    Colorado State
#
#               away home_rank away_rank  home_team_code  away_team_code  \
# 0        Charlotte        99        99              32              37
# 1         Duquesne        99        99              34              49
# 2          Wyoming        99        99              42             221
# 3           Nevada        99        99              76             121
# 4      Idaho State        99        99              74              76
# ..             ...       ...       ...             ...             ...
# 709     Washington         6        24              88             210
# 710  Arizona State        99        99             126              11
# 711       Oklahoma        99        99             127             143
# 712           Rice        99        99             128             153
# 713        Wyoming        99        99              26             221
#
#      home_results win_rank lose_rank
# 0               0       99        99
# 1               0       99        99
# 2               0       99        99
# 3               1       99        99
# 4               0       99        99
# ..            ...      ...       ...
# 709             1       24         6
# 710             0       99        99
# 711             0       99        99
# 712             0       99        99
# 713             1       99        99
#
# [714 rows x 19 columns]

# %%
df1 = df1.drop(columns=['home_team', 'away'])

# %%
df1
# Out:
#      Wk       Date      Time  Day            Winner  Pts             Loser  \
# 0     1  27-Aug-22   7:00 PM  Sat  Florida Atlantic   43         Charlotte
# 1     1  27-Aug-22   5:00 PM  Sat     Florida State   47          Duquesne
# 2     1  27-Aug-22   4:00 PM  Sat          Illinois   38           Wyoming
# 3     1  27-Aug-22  10:00 PM  Sat            Nevada   23  New Mexico State
# 4     1  27-Aug-22   3:30 PM  Sat  Nevada-Las Vegas   52       Idaho State
# ..   ..        ...       ...  ...               ...  ...               ...
# 709  12  12-Nov-22   7:00 PM  Sat   (24) Washington   37        (6) Oregon
# 710  12  12-Nov-22   3:30 PM  Sat  Washington State   28     Arizona State
# 711  12  12-Nov-22  12:00 PM  Sat     West Virginia   23          Oklahoma
# 712  12  12-Nov-22   2:00 PM  Sat  Western Kentucky   45              Rice
# 713  12  12-Nov-22   7:00 PM  Sat           Wyoming   14    Colorado State
#
#      Pts.1           winners            losers home_rank away_rank  \
# 0       13  Florida Atlantic         Charlotte        99        99
# 1        7     Florida State          Duquesne        99        99
# 2        6          Illinois           Wyoming        99        99
# 3       12            Nevada  New Mexico State        99        99
# 4       21  Nevada-Las Vegas       Idaho State        99        99
# ..     ...               ...               ...       ...       ...
# 709     34        Washington            Oregon         6        24
# 710     18  Washington State     Arizona State        99        99
# 711     20     West Virginia          Oklahoma        99        99
# 712     10  Western Kentucky              Rice        99        99
# 713     13           Wyoming    Colorado State        99        99
#
#      home_team_code  away_team_code  home_results win_rank lose_rank
# 0                32              37             0       99        99
# 1                34              49             0       99        99
# 2                42             221             0       99        99
# 3                76             121             1       99        99
# 4                74              76             0       99        99
# ..              ...             ...           ...      ...       ...
# 709              88             210             1       24         6
# 710             126              11             0       99        99
# 711             127             143             0       99        99
# 712             128             153             0       99        99
# 713              26             221             1       99        99
#
# [714 rows x 17 columns]

# %%
dates = df1["Date"]

# %%
month_num = []

for i in dates:
    if(i[1] =='-'):
        if(i[2:5] == 'Sep'):
            month_num.append('9')
        elif(i[2:5] == 'Oct'):
            month_num.append('10')
        elif(i[2:5] == 'Nov'):
            month_num.append('11')
        elif(i[2:5] == 'Aug'):
            month_num.append('8')
    elif(i[2] =='-'):
        if(i[3:6] == 'Aug'):
            month_num.append('8')
        elif(i[3:6] == 'Sep'):
            month_num.append('9')
        elif(i[3:6] == 'Oct'):
            month_num.append('10')
        elif(i[3:6] == 'Nov'):
            month_num.append('11')

# %%
days = []

for i in dates: 
    if(i[1] == '-'):
        days.append(i[0])
    if(i[2] == "-"):
        days.append(i[0:2])

# %%
years = []

for i in dates: 
    years.append('2022')

# %%
df1['months']= month_num
df1['years'] = years
df1['days'] = days

# %%
df1["dates"] = df1[
    'years'].astype(str) +"-"+ df1['months'].astype(str) + "-" + df1['days'].astype(str)

# %%
df1 = df1.drop(columns=['Date'])

# %%
df1 = df1.drop(columns=['months', 'years', 'days', 'Day'])

# %%
df1["dates"].value_counts()
# Out:
# 2022-9-10     80
# 2022-9-17     69
# 2022-9-24     60
# 2022-9-3      56
# 2022-10-1     55
# 2022-11-12    54
# 2022-10-8     52
# 2022-11-5     51
# 2022-10-22    49
# 2022-10-15    48
# 2022-10-29    42
# 2022-9-1      16
# 2022-8-27     11
# 2022-9-2       8
# 2022-9-30      5
# 2022-10-7      4
# 2022-9-23      3
# 2022-9-22      3
# 2022-11-11     3
# 2022-11-9      3
# 2022-11-4      3
# 2022-11-8      3
# 2022-10-27     3
# 2022-9-29      2
# 2022-11-2      2
# 2022-11-1      2
# 2022-9-4       2
# 2022-10-28     2
# 2022-9-9       2
# 2022-10-21     2
# 2022-10-20     2
# 2022-10-14     2
# 2022-10-13     2
# 2022-9-16      2
# 2022-11-10     2
# 2022-11-3      2
# 2022-9-5       1
# 2022-10-30     1
# 2022-10-19     1
# 2022-9-18      1
# 2022-10-5      1
# 2022-10-2      1
# 2022-10-12     1
# Name: dates, dtype: int64

# %%
df1['dates'] = pd.to_datetime(df1['dates'])

# %%
df1["day_code"] = df1["dates"].dt.dayofweek

# %%
df1
# Out:
#      Wk      Time            Winner  Pts             Loser  Pts.1  \
# 0     1   7:00 PM  Florida Atlantic   43         Charlotte     13
# 1     1   5:00 PM     Florida State   47          Duquesne      7
# 2     1   4:00 PM          Illinois   38           Wyoming      6
# 3     1  10:00 PM            Nevada   23  New Mexico State     12
# 4     1   3:30 PM  Nevada-Las Vegas   52       Idaho State     21
# ..   ..       ...               ...  ...               ...    ...
# 709  12   7:00 PM   (24) Washington   37        (6) Oregon     34
# 710  12   3:30 PM  Washington State   28     Arizona State     18
# 711  12  12:00 PM     West Virginia   23          Oklahoma     20
# 712  12   2:00 PM  Western Kentucky   45              Rice     10
# 713  12   7:00 PM           Wyoming   14    Colorado State     13
#
#               winners            losers home_rank away_rank  home_team_code  \
# 0    Florida Atlantic         Charlotte        99        99              32
# 1       Florida State          Duquesne        99        99              34
# 2            Illinois           Wyoming        99        99              42
# 3              Nevada  New Mexico State        99        99              76
# 4    Nevada-Las Vegas       Idaho State        99        99              74
# ..                ...               ...       ...       ...             ...
# 709        Washington            Oregon         6        24              88
# 710  Washington State     Arizona State        99        99             126
# 711     West Virginia          Oklahoma        99        99             127
# 712  Western Kentucky              Rice        99        99             128
# 713           Wyoming    Colorado State        99        99              26
#
#      away_team_code  home_results win_rank lose_rank      dates  day_code
# 0                37             0       99        99 2022-08-27         5
# 1                49             0       99        99 2022-08-27         5
# 2               221             0       99        99 2022-08-27         5
# 3               121             1       99        99 2022-08-27         5
# 4                76             0       99        99 2022-08-27         5
# ..              ...           ...      ...       ...        ...       ...
# 709             210             1       24         6 2022-11-12         5
# 710              11             0       99        99 2022-11-12         5
# 711             143             0       99        99 2022-11-12         5
# 712             153             0       99        99 2022-11-12         5
# 713             221             1       99        99 2022-11-12         5
#
# [714 rows x 17 columns]

# %%
# df1.to_csv('wk12.csv', index=False)
