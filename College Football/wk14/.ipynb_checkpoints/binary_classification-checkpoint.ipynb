# %%
import pandas as pd
import seaborn as sns

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.inspection import DecisionBoundaryDisplay

# %%
df = pd.read_csv('encoded_df.csv')

# %%
df.head()
# Out:
#    Wk            Winner  Pts             Loser  Pts.1           winners  \
# 0   1  Florida Atlantic   43         Charlotte     13  Florida Atlantic
# 1   1     Florida State   47          Duquesne      7     Florida State
# 2   1          Illinois   38           Wyoming      6          Illinois
# 3   1            Nevada   23  New Mexico State     12            Nevada
# 4   1  Nevada-Las Vegas   52       Idaho State     21  Nevada-Las Vegas
#
#              losers  home_rank  away_rank  home_team_code  away_team_code  \
# 0         Charlotte         99         99              32              37
# 1          Duquesne         99         99              34              49
# 2           Wyoming         99         99              42             224
# 3  New Mexico State         99         99              76             122
# 4       Idaho State         99         99              74              77
#
#    home_results  win_rank  lose_rank  day_code  hours  null  half  quart  \
# 0             0        99         99         5     19     1     0      0
# 1             0        99         99         5     17     1     0      0
# 2             0        99         99         5     16     1     0      0
# 3             1        99         99         5     22     1     0      0
# 4             0        99         99         5     15     0     1      0
#
#    three_quart
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df.shape
# Out:
# (841, 20)

# %%
df = df.drop(df[df.home_results > 2].index)

# %%
df.shape
# Out:
# (829, 20)

# %%
print(df['home_results'].value_counts())
# Out:
# 0    525
# 1    304
# Name: home_results, dtype: int64

# %%
df = df.drop(columns=['Winner', 'Pts', 'Loser', 'Pts.1', 'winners', 
                      'losers', 'win_rank', 'lose_rank', 
                      'null', 'half', 'quart', 'three_quart'])

# %%
X = df.drop(columns=['home_results'])
y = df['home_results']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=80)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=80)

# %%
predictions = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# cm = confusion_matrix(y_test, predictions)

TN, FP, FN, TP = confusion_matrix(y_test, predictions).ravel()

print('True Positive(TP)  = ', TP)
print('True Negative(TN)  = ', TN)
print('False Positive(FP) = ', FP)
print('False Negative(FN) = ', FN)
# Out:
# True Positive(TP)  =  19
# True Negative(TN)  =  92
# False Positive(FP) =  19
# False Negative(FN) =  36

# %%
19+92
# Out:
# 111

# %%
19+36
# Out:
# 55

# %%
accuracy =  (TP + TN) / (TP + FP + TN + FN)

print('Accuracy of the binary classifier = {:0.3f}'.format(accuracy))
# Out:
# Accuracy of the binary classifier = 0.669

# %%
models = {}

# Logistic Regression
from sklearn.linear_model import LogisticRegression
models['Logistic Regression'] = LogisticRegression()

# Support Vector Machines
from sklearn.svm import LinearSVC
models['Support Vector Machines'] = LinearSVC(max_iter=100000)

# Decision Trees
from sklearn.tree import DecisionTreeClassifier
models['Decision Trees'] = DecisionTreeClassifier()

# Random Forest
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()

# Naive Bayes
from sklearn.naive_bayes import GaussianNB
models['Naive Bayes'] = GaussianNB()

# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
models['K-Nearest Neighbor'] = KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier
    models[key].fit(X_train, y_train)
    
    # Make predictions
    predictions = models[key].predict(X_test)
    
    # Calculate metrics
    accuracy[key] = accuracy_score(predictions, y_test)
    precision[key] = precision_score(predictions, y_test)
    recall[key] = recall_score(predictions, y_test)
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
import pandas as pd

df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
df_model['Precision'] = precision.values()
df_model['Recall'] = recall.values()

df_model
# Out:
#                          Accuracy  Precision    Recall
# Logistic Regression      0.668675   0.345455  0.500000
# Support Vector Machines  0.704819   0.218182  0.666667
# Decision Trees           0.542169   0.454545  0.352113
# Random Forest            0.674699   0.454545  0.510204
# Naive Bayes              0.680723   0.436364  0.521739
# K-Nearest Neighbor       0.686747   0.454545  0.531915

# %%
ax = df_model.plot.barh()
ax.legend(
    ncol=len(models.keys()), 
    bbox_to_anchor=(0, 1), 
    loc='lower left', 
    prop={'size': 14}
)
plt.tight_layout()

# %%
from pycaret.classification import *

# %%
dataset = df.copy()

# %%
data = dataset.sample(frac=0.90)
data_unseen = dataset.drop(data.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (746, 8)
# Unseen Data For Predictions: (83, 8)

# %%
exp_clf101=setup(data=data, target='home_results', fold_shuffle=True, 
                 imputation_type='iterative', session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_28cae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28cae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28cae_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_28cae_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28cae_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_28cae_row1_col1" class="data row1 col1" >home_results</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28cae_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_28cae_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28cae_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_28cae_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28cae_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_28cae_row4_col1" class="data row4 col1" >(746, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_28cae_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_28cae_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_28cae_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_28cae_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_28cae_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_28cae_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_28cae_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_28cae_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_28cae_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_28cae_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_28cae_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_28cae_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_28cae_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_28cae_row11_col1" class="data row11 col1" >(522, 38)</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_28cae_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_28cae_row12_col1" class="data row12 col1" >(224, 38)</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_28cae_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_28cae_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_28cae_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_28cae_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_28cae_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_28cae_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_28cae_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_28cae_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_28cae_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_28cae_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_28cae_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_28cae_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_28cae_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_28cae_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_28cae_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_28cae_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_28cae_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_28cae_row21_col1" class="data row21 col1" >22ea</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_28cae_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_28cae_row22_col1" class="data row22 col1" >iterative</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_28cae_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_28cae_row23_col1" class="data row23 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_28cae_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_28cae_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_28cae_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_28cae_row25_col1" class="data row25 col1" >Light Gradient Boosting Machine</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_28cae_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_28cae_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_28cae_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_28cae_row27_col1" class="data row27 col1" >Light Gradient Boosting Machine</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_28cae_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_28cae_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_28cae_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_28cae_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_28cae_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_28cae_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_28cae_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_35300/917196831.py in <cell line: 1>()
# ----> 1 exp_clf101=setup(data=data, target='home_results', fold_shuffle=True,
#       2                  imputation_type='iterative', session_id=123)
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pycaret/classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pycaret/internal/tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1743     logger.info(f"display_container: {len(display_container)}")
#    1744
# -> 1745     logger.info(str(prep_pipe))
#    1746     logger.info("setup() succesfully completed......................................")
#    1747
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     417         level += 1
#     418         for o in object:
# --> 419             orepr, oreadable, orecur = _safe_repr(
#     420                 o, context, maxlevels, level, changed_only=changed_only
#     421             )
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     440             params = _changed_params(object)
#     441         else:
# --> 442             params = object.get_params(deep=False)
#     443         components = []
#     444         append = components.append
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/base.py in get_params(self, deep)
#     209         out = dict()
#     210         for key in self._get_param_names():
# --> 211             value = getattr(self, key)
#     212             if deep and hasattr(value, "get_params") and not isinstance(value, type):
#     213                 deep_items = value.get_params().items()
#
# AttributeError: 'Make_Time_Features' object has no attribute 'list_of_features'

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2e771_ th {
#   text-align: left;
# }
# #T_2e771_row0_col0, #T_2e771_row0_col2, #T_2e771_row0_col3, #T_2e771_row0_col4, #T_2e771_row0_col5, #T_2e771_row0_col6, #T_2e771_row0_col7, #T_2e771_row1_col0, #T_2e771_row1_col1, #T_2e771_row1_col2, #T_2e771_row1_col3, #T_2e771_row1_col4, #T_2e771_row2_col0, #T_2e771_row2_col1, #T_2e771_row2_col3, #T_2e771_row2_col5, #T_2e771_row2_col6, #T_2e771_row2_col7, #T_2e771_row3_col0, #T_2e771_row3_col1, #T_2e771_row3_col2, #T_2e771_row3_col3, #T_2e771_row3_col4, #T_2e771_row3_col5, #T_2e771_row3_col6, #T_2e771_row3_col7, #T_2e771_row4_col0, #T_2e771_row4_col1, #T_2e771_row4_col2, #T_2e771_row4_col3, #T_2e771_row4_col4, #T_2e771_row4_col5, #T_2e771_row4_col6, #T_2e771_row4_col7, #T_2e771_row5_col0, #T_2e771_row5_col1, #T_2e771_row5_col2, #T_2e771_row5_col3, #T_2e771_row5_col4, #T_2e771_row5_col5, #T_2e771_row5_col6, #T_2e771_row5_col7, #T_2e771_row6_col0, #T_2e771_row6_col1, #T_2e771_row6_col2, #T_2e771_row6_col3, #T_2e771_row6_col4, #T_2e771_row6_col5, #T_2e771_row6_col6, #T_2e771_row6_col7, #T_2e771_row7_col0, #T_2e771_row7_col1, #T_2e771_row7_col2, #T_2e771_row7_col3, #T_2e771_row7_col4, #T_2e771_row7_col5, #T_2e771_row7_col6, #T_2e771_row7_col7, #T_2e771_row8_col0, #T_2e771_row8_col1, #T_2e771_row8_col2, #T_2e771_row8_col3, #T_2e771_row8_col4, #T_2e771_row8_col5, #T_2e771_row8_col6, #T_2e771_row8_col7, #T_2e771_row9_col0, #T_2e771_row9_col1, #T_2e771_row9_col2, #T_2e771_row9_col3, #T_2e771_row9_col4, #T_2e771_row9_col5, #T_2e771_row9_col6, #T_2e771_row9_col7, #T_2e771_row10_col0, #T_2e771_row10_col1, #T_2e771_row10_col2, #T_2e771_row10_col3, #T_2e771_row10_col4, #T_2e771_row10_col5, #T_2e771_row10_col6, #T_2e771_row10_col7, #T_2e771_row11_col0, #T_2e771_row11_col1, #T_2e771_row11_col2, #T_2e771_row11_col3, #T_2e771_row11_col4, #T_2e771_row11_col5, #T_2e771_row11_col6, #T_2e771_row11_col7, #T_2e771_row12_col0, #T_2e771_row12_col1, #T_2e771_row12_col2, #T_2e771_row12_col3, #T_2e771_row12_col4, #T_2e771_row12_col5, #T_2e771_row12_col6, #T_2e771_row12_col7, #T_2e771_row13_col0, #T_2e771_row13_col1, #T_2e771_row13_col2, #T_2e771_row13_col3, #T_2e771_row13_col4, #T_2e771_row13_col5, #T_2e771_row13_col6, #T_2e771_row13_col7, #T_2e771_row14_col0, #T_2e771_row14_col1, #T_2e771_row14_col2, #T_2e771_row14_col4, #T_2e771_row14_col5, #T_2e771_row14_col6, #T_2e771_row14_col7 {
#   text-align: left;
# }
# #T_2e771_row0_col1, #T_2e771_row1_col5, #T_2e771_row1_col6, #T_2e771_row1_col7, #T_2e771_row2_col2, #T_2e771_row2_col4, #T_2e771_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
td>
#     </tr>
#     <tr>
#       <th id="T_84be6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84be6_row9_col0" class="data row9 col0" >0.7885</td>
#       <td id="T_84be6_row9_col1" class="data row9 col1" >0.7703</td>
#       <td id="T_84be6_row9_col2" class="data row9 col2" >0.5263</td>
#       <td id="T_84be6_row9_col3" class="data row9 col3" >0.8333</td>
#       <td id="T_84be6_row9_col4" class="data row9 col4" >0.6452</td>
#       <td id="T_84be6_row9_col5" class="data row9 col5" >0.5052</td>
#       <td id="T_84be6_row9_col6" class="data row9 col6" >0.5323</td>
#     </tr>
#     <tr>
#       <th id="T_84be6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_84be6_row10_col0" class="data row10 col0" >0.6842</td>
#       <td id="T_84be6_row10_col1" class="data row10 col1" >0.6465</td>
#       <td id="T_84be6_row10_col2" class="data row10 col2" >0.3947</td>
#       <td id="T_84be6_row10_col3" class="data row10 col3" >0.5933</td>
#       <td id="T_84be6_row10_col4" class="data row10 col4" >0.4698</td>
#       <td id="T_84be6_row10_col5" class="data row10 col5" >0.2586</td>
#       <td id="T_84be6_row10_col6" class="data row10 col6" >0.2716</td>
#     </tr>
#     <tr>
#       <th id="T_84be6_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_84be6_row11_col0" class="data row11 col0" >0.0655</td>
#       <td id="T_84be6_row11_col1" class="data row11 col1" >0.0680</td>
#       <td id="T_84be6_row11_col2" class="data row11 col2" >0.1059</td>
#       <td id="T_84be6_row11_col3" class="data row11 col3" >0.1381</td>
#       <td id="T_84be6_row11_col4" class="data row11 col4" >0.1144</td>
#       <td id="T_84be6_row11_col5" class="data row11 col5" >0.1534</td>
#       <td id="T_84be6_row11_col6" class="data row11 col6" >0.1586</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_qbc = tune_model(gbc)
# Out:
# <style type="text/css">
# #T_03871_row10_col0, #T_03871_row10_col1, #T_03871_row10_col2, #T_03871_row10_col3, #T_03871_row10_col4, #T_03871_row10_col5, #T_03871_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_03871_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03871_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03871_row0_col0" class="data row0 col0" >0.5849</td>
#       <td id="T_03871_row0_col1" class="data row0 col1" >0.5372</td>
#       <td id="T_03871_row0_col2" class="data row0 col2" >0.2105</td>
#       <td id="T_03871_row0_col3" class="data row0 col3" >0.3636</td>
#       <td id="T_03871_row0_col4" class="data row0 col4" >0.2667</td>
#       <td id="T_03871_row0_col5" class="data row0 col5" >0.0051</td>
#       <td id="T_03871_row0_col6" class="data row0 col6" >0.0055</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03871_row1_col0" class="data row1 col0" >0.6792</td>
#       <td id="T_03871_row1_col1" class="data row1 col1" >0.7136</td>
#       <td id="T_03871_row1_col2" class="data row1 col2" >0.2105</td>
#       <td id="T_03871_row1_col3" class="data row1 col3" >0.6667</td>
#       <td id="T_03871_row1_col4" class="data row1 col4" >0.3200</td>
#       <td id="T_03871_row1_col5" class="data row1 col5" >0.1787</td>
#       <td id="T_03871_row1_col6" class="data row1 col6" >0.2296</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03871_row2_col0" class="data row2 col0" >0.6923</td>
#       <td id="T_03871_row2_col1" class="data row2 col1" >0.5850</td>
#       <td id="T_03871_row2_col2" class="data row2 col2" >0.2222</td>
#       <td id="T_03871_row2_col3" class="data row2 col3" >0.6667</td>
#       <td id="T_03871_row2_col4" class="data row2 col4" >0.3333</td>
#       <td id="T_03871_row2_col5" class="data row2 col5" >0.1938</td>
#       <td id="T_03871_row2_col6" class="data row2 col6" >0.2433</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03871_row3_col0" class="data row3 col0" >0.6346</td>
#       <td id="T_03871_row3_col1" class="data row3 col1" >0.6552</td>
#       <td id="T_03871_row3_col2" class="data row3 col2" >0.2778</td>
#       <td id="T_03871_row3_col3" class="data row3 col3" >0.4545</td>
#       <td id="T_03871_row3_col4" class="data row3 col4" >0.3448</td>
#       <td id="T_03871_row3_col5" class="data row3 col5" >0.1115</td>
#       <td id="T_03871_row3_col6" class="data row3 col6" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03871_row4_col0" class="data row4 col0" >0.6731</td>
#       <td id="T_03871_row4_col1" class="data row4 col1" >0.5956</td>
#       <td id="T_03871_row4_col2" class="data row4 col2" >0.2222</td>
#       <td id="T_03871_row4_col3" class="data row4 col3" >0.5714</td>
#       <td id="T_03871_row4_col4" class="data row4 col4" >0.3200</td>
#       <td id="T_03871_row4_col5" class="data row4 col5" >0.1565</td>
#       <td id="T_03871_row4_col6" class="data row4 col6" >0.1868</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03871_row5_col0" class="data row5 col0" >0.6731</td>
#       <td id="T_03871_row5_col1" class="data row5 col1" >0.7018</td>
#       <td id="T_03871_row5_col2" class="data row5 col2" >0.1579</td>
#       <td id="T_03871_row5_col3" class="data row5 col3" >0.7500</td>
#       <td id="T_03871_row5_col4" class="data row5 col4" >0.2609</td>
#       <td id="T_03871_row5_col5" class="data row5 col5" >0.1533</td>
#       <td id="T_03871_row5_col6" class="data row5 col6" >0.2306</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03871_row6_col0" class="data row6 col0" >0.6731</td>
#       <td id="T_03871_row6_col1" class="data row6 col1" >0.6643</td>
#       <td id="T_03871_row6_col2" class="data row6 col2" >0.3684</td>
#       <td id="T_03871_row6_col3" class="data row6 col3" >0.5833</td>
#       <td id="T_03871_row6_col4" class="data row6 col4" >0.4516</td>
#       <td id="T_03871_row6_col5" class="data row6 col5" >0.2353</td>
#       <td id="T_03871_row6_col6" class="data row6 col6" >0.2479</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03871_row7_col0" class="data row7 col0" >0.5962</td>
#       <td id="T_03871_row7_col1" class="data row7 col1" >0.6284</td>
#       <td id="T_03871_row7_col2" class="data row7 col2" >0.2632</td>
#       <td id="T_03871_row7_col3" class="data row7 col3" >0.4167</td>
#       <td id="T_03871_row7_col4" class="data row7 col4" >0.3226</td>
#       <td id="T_03871_row7_col5" class="data row7 col5" >0.0554</td>
#       <td id="T_03871_row7_col6" class="data row7 col6" >0.0583</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03871_row8_col0" class="data row8 col0" >0.6923</td>
#       <td id="T_03871_row8_col1" class="data row8 col1" >0.6770</td>
#       <td id="T_03871_row8_col2" class="data row8 col2" >0.2105</td>
#       <td id="T_03871_row8_col3" class="data row8 col3" >0.8000</td>
#       <td id="T_03871_row8_col4" class="data row8 col4" >0.3333</td>
#       <td id="T_03871_row8_col5" class="data row8 col5" >0.2136</td>
#       <td id="T_03871_row8_col6" class="data row8 col6" >0.2944</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03871_row9_col0" class="data row9 col0" >0.7692</td>
#       <td id="T_03871_row9_col1" class="data row9 col1" >0.8262</td>
#       <td id="T_03871_row9_col2" class="data row9 col2" >0.4211</td>
#       <td id="T_03871_row9_col3" class="data row9 col3" >0.8889</td>
#       <td id="T_03871_row9_col4" class="data row9 col4" >0.5714</td>
#       <td id="T_03871_row9_col5" class="data row9 col5" >0.4399</td>
#       <td id="T_03871_row9_col6" class="data row9 col6" >0.4974</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_03871_row10_col0" class="data row10 col0" >0.6668</td>
#       <td id="T_03871_row10_col1" class="data row10 col1" >0.6584</td>
#       <td id="T_03871_row10_col2" class="data row10 col2" >0.2564</td>
#       <td id="T_03871_row10_col3" class="data row10 col3" >0.6162</td>
#       <td id="T_03871_row10_col4" class="data row10 col4" >0.3525</td>
#       <td id="T_03871_row10_col5" class="data row10 col5" >0.1743</td>
#       <td id="T_03871_row10_col6" class="data row10 col6" >0.2112</td>
#     </tr>
#     <tr>
#       <th id="T_03871_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_03871_row11_col0" class="data row11 col0" >0.0498</td>
#       <td id="T_03871_row11_col1" class="data row11 col1" >0.0764</td>
#       <td id="T_03871_row11_col2" class="data row11 col2" >0.0765</td>
#       <td id="T_03871_row11_col3" class="data row11 col3" >0.1625</td>
#       <td id="T_03871_row11_col4" class="data row11 col4" >0.0879</td>
#       <td id="T_03871_row11_col5" class="data row11 col5" >0.1112</td>
#       <td id="T_03871_row11_col6" class="data row11 col6" >0.1292</td>
#     </tr>
#   </tbody>
# </table>

# %%
#tuned model object is stored in the variable 'tuned_qbc'. 
print(tuned_qbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.163, loss='log_loss', max_depth=3,
#                            max_features='log2', max_leaf_nodes=None,
#                            min_impurity_decrease=0.5, min_samples_leaf=1,
#                            min_samples_split=7, min_weight_fraction_leaf=0.0,
#                            n_estimators=220, n_iter_no_change=None,
#                            random_state=123, subsample=0.95, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
plot_model(tuned_qbc, plot = 'auc')

# %%
plot_model(tuned_qbc, plot = 'pr')

# %%
plot_model(tuned_qbc, plot='feature')

# %%
plot_model(tuned_qbc, plot = 'confusion_matrix')

# %%
evaluate_model(tuned_qbc)
# Out:
#                             Parameters
# ccp_alpha                          0.0
# criterion                 friedman_mse
# init                              None
# learning_rate                    0.163
# loss                          log_loss
# max_depth                            3
# max_features                      log2
# max_leaf_nodes                    None
# min_impurity_decrease              0.5
# min_samples_leaf                     1
# min_samples_split                    7
# min_weight_fraction_leaf           0.0
# n_estimators                       220
# n_iter_no_change                  None
# random_state                       123
# subsample                         0.95
# tol                             0.0001
# validation_fraction                0.1
# verbose                              0
# warm_start                       False

# %%
predict_model(tuned_qbc);
# Out:
# <style type="text/css">
# </style>
# <table id="T_6cf46_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cf46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6cf46_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6cf46_row0_col1" class="data row0 col1" >0.6205</td>
#       <td id="T_6cf46_row0_col2" class="data row0 col2" >0.6583</td>
#       <td id="T_6cf46_row0_col3" class="data row0 col3" >0.2022</td>
#       <td id="T_6cf46_row0_col4" class="data row0 col4" >0.5625</td>
#       <td id="T_6cf46_row0_col5" class="data row0 col5" >0.2975</td>
#       <td id="T_6cf46_row0_col6" class="data row0 col6" >0.1106</td>
#       <td id="T_6cf46_row0_col7" class="data row0 col7" >0.1378</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_qbc = finalize_model(tuned_qbc)
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Final Random Forest model parameters for deployment
print(final_qbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.163, loss='log_loss', max_depth=3,
#                            max_features='log2', max_leaf_nodes=None,
#                            min_impurity_decrease=0.5, min_samples_leaf=1,
#                            min_samples_split=7, min_weight_fraction_leaf=0.0,
#                            n_estimators=220, n_iter_no_change=None,
#                            random_state=123, subsample=0.95, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
