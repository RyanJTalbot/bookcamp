# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('IndeedScraper_30_jobs_2023-02-04.csv')

# %%
df
# Out:
#                                         Position Name  \
# 0               Business Analyst III - Open to Remote
# 1                                        Data Analyst
# 2                             e-Commerce Data Analyst
# 3                                        Data Analyst
# 4                                   HRIS Data Analyst
# 5           Remote Digital Platforms Business Analyst
# 6                           Business Analyst (Non IT)
# 7                                        Data Analyst
# 8                            Entry Level Data Analyst
# 9                                    Jr. Data Analyst
# 10                                       Data Analyst
# 11                Client Data Analyst -Work from home
# 12                                       Data Analyst
# 13                                       Data Analyst
# 14                              Data Analyst (Remote)
# 15  Business Data Analyst II - Free Healthcare Ben...
# ...

# %%
desc = df['Short Description']

# %%
words = []

for i in desc:
    print(f'{i}\n\n-----')
# Out:
#
#  Solid knowledge and understanding of forecasting techniques or statistical analysis or data modeling or data mining.
#  Experience with Category Spend Analytics.
#
#
# -----
#
#  Detailed understanding of data governance and data profiling concepts.
#  Actively involves in troubleshooting data / data process anomalies and works with the…
#
#
# -----
#
#  1-2+ years of experience as a Data Analyst in enterprise organizations working with very large data sets; Retail or e-Commerce data analysis experience is…
#
#
# -----
#
#  This position will play a vital role providing important data to our management + executive team, assisting our publishers with their data needs, and crafting…
#
#
# -----
#
#  Provide a proactive approach to data governance to ensure data accuracy.
#  Responsible for the creation, implementation, maintenance, and training of the…
#
#
# -----
#
#  5-8 years of experience in configuration, coding and application development.
# ...
