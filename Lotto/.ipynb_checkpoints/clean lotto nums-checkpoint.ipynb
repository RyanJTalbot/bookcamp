# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('clean_lottory.csv')

# %%
df
# Out:
#                  numbers  power_ball
# 0     28, 45, 53, 56, 69          10
# 1      2, 11, 22, 35, 60          20
# 2     13, 19, 36, 39, 59          23
# 3     19, 31, 40, 46, 57          13
# 4     19, 36, 37, 46, 56          23
# ...                  ...         ...
# 2436    1, 6, 21, 33, 40          34
# 2437   9, 32, 38, 41, 44          28
# 2438   7, 28, 35, 40, 48          27
# 2439   5, 15, 16, 28, 32          14
# 2440   9, 13, 23, 36, 45          39
#
# [2441 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2441 entries, 0 to 2440
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   numbers     2441 non-null   object
#  1   power_ball  2441 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 38.3+ KB

# %%
nums = df['numbers']

# %%
first = []
remain = []

for i in nums:
    if (i[1] == ','):
        first.append(i[0])
        remain.append(i[3:])
    if (i[2] == ','):
        first.append(i[0:2])
        remain.append(i[4:])

# %%
# first

# %%
remain
# Out:
# ['45, 53, 56, 69',
#  '11, 22, 35, 60',
#  '19, 36, 39, 59',
#  '31, 40, 46, 57',
#  '36, 37, 46, 56',
#  '23, 35, 45, 54',
#  '25, 48, 55, 60',
#  '8, 15, 27, 42',
#  '30, 36, 46, 60',
#  '37, 40, 58, 62',
#  '30, 41, 42, 59',
#  '6, 11, 17, 22',
#  '43, 53, 60, 68',
#  '30, 33, 37, 62',
#  '16, 22, 55, 63',
#  '21, 22, 65, 69',
#  '10, 24, 33, 67',
#  '20, 31, 33, 59',
#  '9, 21, 24, 29',
#  '33, 34, 45, 54',
#  '15, 36, 46, 67',
#  '25, 36, 51, 61',
#  '10, 20, 22, 52',
#  '14, 16, 34, 66',
#  '42, 56, 68, 69',
#  '16, 30, 33, 36',
#  '7, 32, 55, 64',
#  '27, 49, 65, 69',
#  '8, 19, 24, 28',
#  '36, 43, 61, 69',
#  '18, 56, 60, 65',
#  '24, 35, 37, 44',
#  '27, 34, 55, 67',
#  '9, 11, 16, 66',
#  '28, 41, 50, 55',
#  '24, 47, 50, 63',
#  '24, 35, 43, 62',
#  '44, 59, 61, 68',
#  '45, 51, 57, 58',
#  '15, 46, 56, 68',
#  '21, 56, 57, 66',
#  '21, 31, 36, 65',
#  '17, 57, 58, 68',
#  '25, 44, 55, 57',
#  '37, 38, 39, 65',
#  '41, 54, 59, 62',
#  '20, 23, 49, 65',
# ...

# %%
second = []
remain2 = []

for i in remain:
    if (i[1] == ','):
        second.append(i[0])
        remain2.append(i[3:])
    if (i[2] == ','):
        second.append(i[0:2])
        remain2.append(i[4:])

# %%
# second

# %%
third = []
remain3 = []

for i in remain2:
    if (i[1] == ','):
        third.append(i[0])
        remain3.append(i[3:])
    if (i[2] == ','):
        third.append(i[0:2])
        remain3.append(i[4:])

# %%
# third

# %%
fourth = []
remain4 = []

for i in remain3:
    if (i[1] == ','):
        fourth.append(i[0])
        remain4.append(i[3:])
    if (i[2] == ','):
        fourth.append(i[0:2])
        remain4.append(i[4:])

# %%
# fourth

# %%
remain4
# Out:
# ['69',
#  '60',
#  '59',
#  '57',
#  '56',
#  '54',
#  '60',
#  '42',
#  '60',
#  '62',
#  '59',
#  '22',
#  '68',
#  '62',
#  '63',
#  '69',
#  '67',
#  '59',
#  '29',
#  '54',
#  '67',
#  '61',
#  '52',
#  '66',
#  '69',
#  '36',
#  '64',
#  '69',
#  '28',
#  '69',
#  '65',
#  '44',
#  '67',
#  '66',
#  '55',
#  '63',
#  '62',
#  '68',
#  '58',
#  '68',
#  '66',
#  '65',
#  '68',
#  '57',
#  '65',
#  '62',
#  '65',
#  '58',
#  '57',
#  '63',
#  '52',
#  '52',
#  '69',
#  '56',
#  '62',
#  '63',
#  '37',
#  '32',
#  '56',
#  '69',
#  '58',
#  '51',
#  '51',
#  '69',
#  '64',
#  '46',
#  '60',
#  '63',
#  '69',
#  '66',
#  '57',
#  '42',
#  '58',
#  '65',
#  '64',
#  '52',
#  '69',
#  '56',
#  '67',
#  '69',
#  '44',
#  '63',
#  '68',
#  '61',
#  '56',
#  '56',
#  '62',
#  '65',
#  '68',
#  '34',
#  '66',
#  '64',
#  '69',
#  '59',
#  '37',
#  '62',
#  '61',
#  '48',
#  '65',
#  '52',
#  '58',
#  '49',
#  '61',
#  '67',
#  '67',
#  '63',
#  '63',
#  '55',
#  '64',
#  '64',
#  '69',
# ...

# %%
d = {'first':first,'second':second, 'third':third, 'fourth':fourth, 'fifth':remain4}

# %%
df2 = pd.DataFrame(d)

# %%
df2
# Out:
#      first second third fourth fifth
# 0       28     45    53     56    69
# 1        2     11    22     35    60
# 2       13     19    36     39    59
# 3       19     31    40     46    57
# 4       19     36    37     46    56
# ...    ...    ...   ...    ...   ...
# 2425     1      6    21     33    40
# 2426     9     32    38     41    44
# 2427     7     28    35     40    48
# 2428     5     15    16     28    32
# 2429     9     13    23     36    45
#
# [2430 rows x 5 columns]

# %%
df2['powerball'] = df['power_ball']

# %%
df2
# Out:
#      first second third fourth fifth  powerball
# 0       28     45    53     56    69         10
# 1        2     11    22     35    60         20
# 2       13     19    36     39    59         23
# 3       19     31    40     46    57         13
# 4       19     36    37     46    56         23
# ...    ...    ...   ...    ...   ...        ...
# 2425     1      6    21     33    40          7
# 2426     9     32    38     41    44         35
# 2427     7     28    35     40    48         21
# 2428     5     15    16     28    32         37
# 2429     9     13    23     36    45         24
#
# [2430 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   first      2430 non-null   int64
#  1   second     2430 non-null   int64
#  2   third      2430 non-null   int64
#  3   fourth     2430 non-null   int64
#  4   fifth      2430 non-null   int64
#  5   powerball  2430 non-null   int64
# dtypes: int64(6)
# memory usage: 114.0 KB

# %%
df2 = df2.apply(pd.to_numeric) # convert all columns of DataFrame

# %%
# df2.to_csv('final_lotto.csv', index=False)
