# %%
import pandas as pd

# %%
matches = pd.read_csv('WorldCupMatches.csv')
players = pd.read_csv('WorldCupPlayers.csv')
world_cups = pd.read_csv('WorldCups.csv')

# %%
matches.head()
# Out:
#    Year              Datetime           Stage                    Stadium  \
# 0  1990  26 Jun 1990 - 17:00      Round of 16     Marc Antonio Bentegodi
# 1  2002  16 Jun 2002 - 15:30      Round of 16       Oita Stadium Big Eye
# 2  2002  18 Jun 2002 - 20:30      Round of 16  Daejeon World Cup Stadium
# 3  2002  22 Jun 2002 - 20:30   Quarter-finals        Osaka Nagai Stadium
# 4  2010  02 Jul 2010 - 20:30   Quarter-finals        Soccer City Stadium
#
#             City  Home Team Name  Home Team Goals  Away Team Goals  \
# 0        Verona            Spain                1                2
# 1          Oita           Sweden                1                2
# 2       Daejeon   Korea Republic                2                1
# 3         Osaka          Senegal                0                1
# 4  Johannesburg          Uruguay                1                1
#
#   Away Team Name Win conditions  Attendance  Half-time Home Goals  \
# ...

# %%
matches.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals
# count            852.000000            852.000000
# mean               0.708920              0.428404
# std                0.937414              0.691252
# min                0.000000              0.000000
# 25%                0.000000              0.000000
# 50%                0.000000              0.000000
# ...

# %% [markdown]
# Matches have no null

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Home Team Initials    852 non-null    object
#  14  Away Team Initials    852 non-null    object
# ...

# %%
attendances = pd.isnull(matches["Attendance"]).sum()

# %%
attendances
# Out:
# 2

# %%
matches_objs=matches.select_dtypes(include='object')

# %%
matches_objs
# Out:
#                  Datetime                     Stage  \
# 0    26 Jun 1990 - 17:00                Round of 16
# 1    16 Jun 2002 - 15:30                Round of 16
# 2    18 Jun 2002 - 20:30                Round of 16
# 3    22 Jun 2002 - 20:30             Quarter-finals
# 4    02 Jul 2010 - 20:30             Quarter-finals
# ..                    ...                       ...
# 847  04 Jul 2014 - 13:00             Quarter-finals
# 848  04 Jul 2014 - 17:00             Quarter-finals
# 849  05 Jul 2014 - 13:00             Quarter-finals
# 850  08 Jul 2014 - 17:00                Semi-finals
# 851  12 Jul 2014 - 17:00   Play-off for third place
#
#                        Stadium             City  Home Team Name  \
# 0       Marc Antonio Bentegodi          Verona            Spain
# 1         Oita Stadium Big Eye            Oita           Sweden
# 2    Daejeon World Cup Stadium         Daejeon   Korea Republic
# 3          Osaka Nagai Stadium           Osaka          Senegal
# ...

# %%
matches.shape
# Out:
# (852, 15)

# %%
world_cups.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17        363
# 2           84              15             18      375.7
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
world_cups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            21 non-null     int64
#  1   Country         21 non-null     object
#  2   Winner          21 non-null     object
#  3   Runners-Up      21 non-null     object
#  4   Third           21 non-null     object
#  5   Fourth          21 non-null     object
#  6   GoalsScored     21 non-null     int64
#  7   QualifiedTeams  21 non-null     int64
#  8   MatchesPlayed   21 non-null     int64
#  9   Attendance      21 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.8+ KB

# %%
wc_objs=world_cups.select_dtypes(include='object')

# %%
wc_objs
# Out:
#          Country      Winner      Runners-Up        Third          Fourth  \
# 0        Uruguay     Uruguay       Argentina          USA      Yugoslavia
# 1          Italy       Italy  Czechoslovakia      Germany         Austria
# 2         France       Italy         Hungary       Brazil          Sweden
# 3         Brazil     Uruguay          Brazil       Sweden           Spain
# 4    Switzerland  Germany FR         Hungary      Austria         Uruguay
# 5         Sweden      Brazil          Sweden       France      Germany FR
# 6          Chile      Brazil  Czechoslovakia        Chile      Yugoslavia
# 7        England     England      Germany FR     Portugal    Soviet Union
# 8         Mexico      Brazil           Italy   Germany FR         Uruguay
# 9        Germany  Germany FR     Netherlands       Poland          Brazil
# 10     Argentina   Argentina     Netherlands       Brazil           Italy
# 11         Spain       Italy      Germany FR       Poland          France
# ...

# %%
world_cups.describe()
# Out:
#               Year  GoalsScored  QualifiedTeams  MatchesPlayed
# count    21.000000    21.000000       21.000000      21.000000
# mean   1976.857143   121.333333       21.761905      42.857143
# std      26.657618    33.943090        7.462605      17.467930
# min    1930.000000    70.000000       13.000000      17.000000
# 25%    1958.000000    89.000000       16.000000      32.000000
# 50%    1978.000000   126.000000       16.000000      38.000000
# 75%    1998.000000   146.000000       32.000000      64.000000
# max    2018.000000   171.000000       32.000000      64.000000

# %%
world_cups.describe()
# Out:
#               Year  GoalsScored  QualifiedTeams  MatchesPlayed
# count    21.000000    21.000000       21.000000      21.000000
# mean   1976.857143   121.333333       21.761905      42.857143
# std      26.657618    33.943090        7.462605      17.467930
# min    1930.000000    70.000000       13.000000      17.000000
# 25%    1958.000000    89.000000       16.000000      32.000000
# 50%    1978.000000   126.000000       16.000000      38.000000
# 75%    1998.000000   146.000000       32.000000      64.000000
# max    2018.000000   171.000000       32.000000      64.000000

# %%
world_cups.shape
# Out:
# (21, 10)
