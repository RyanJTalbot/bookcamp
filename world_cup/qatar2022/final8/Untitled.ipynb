# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('fourfinal.csv')

# %%
df.head()
# Out:
#           Squad  # Pl   Age  Poss  MP▼  Starts    Min  90s   Gls   Ast  ...  \
# 0  ar Argentina  24.0  28.4  58.0  6.0    66.0  570.0  6.3  12.0   7.0  ...
# 1    hr Croatia  18.0  29.4  55.0  6.0    66.0  600.0  6.7   6.0   6.0  ...
# 2     fr France  24.0  27.3  52.2  6.0    66.0  540.0  6.0  13.0  11.0  ...
# 3    ma Morocco  22.0  27.3  37.2  6.0    66.0  570.0  6.3   5.0   4.0  ...
# 4     br Brazil  26.0  28.5  56.2  5.0    55.0  480.0  5.3   8.0   6.0  ...
#
#    G+A-PK    xG  npxG  xAG  npxG+xAG  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1
# 0    2.53  11.8   8.9  6.2      15.0  1.87   0.98    2.84    1.40        2.37
# 1    1.80   6.4   6.4  5.0      11.4  0.95   0.75    1.71    0.95        1.71
# 2    4.00  11.6  11.6  9.7      21.2  1.93   1.61    3.54    1.93        3.54
# 3    1.42   5.4   5.4  4.3       9.7  0.86   0.68    1.54    0.86        1.54
# 4    2.44  12.0  11.2  8.2      19.4  2.24   1.54    3.79    2.09        3.64
#
# [5 rows x 29 columns]

# %%
df = df.drop(columns=['Age', 'Starts', 'Min', '90s'])

# %%
df["Squad_code"] = df["Squad"].astype("category").cat.codes

# %%
df1 = df.copy()

# %%
df1
# Out:
#                 Squad  # Pl  Poss  MP▼   Gls   Ast  G-PK   PK  PKatt  CrdY  \
# 0        ar Argentina  24.0  58.0  6.0  12.0   7.0   9.0  3.0    4.0  12.0
# 1          hr Croatia  18.0  55.0  6.0   6.0   6.0   6.0  0.0    0.0   8.0
# 2           fr France  24.0  52.2  6.0  13.0  11.0  13.0  0.0    0.0   5.0
# 3          ma Morocco  22.0  37.2  6.0   5.0   4.0   5.0  0.0    0.0   7.0
# 4           br Brazil  26.0  56.2  5.0   8.0   6.0   7.0  1.0    1.0   6.0
# 5         eng England  20.0  62.8  5.0  13.0  11.0  12.0  1.0    2.0   1.0
# 6      nl Netherlands  21.0  53.0  5.0  10.0   8.0  10.0  0.0    0.0  12.0
# 7         pt Portugal  24.0  60.4  5.0  12.0  10.0  10.0  2.0    2.0   6.0
# 8        au Australia  20.0  37.8  4.0   3.0   3.0   3.0  0.0    0.0   7.0
# 9            jp Japan  22.0  35.8  4.0   5.0   4.0   5.0  0.0    0.0   6.0
# 10  kr Korea Republic  21.0  48.3  4.0   5.0   3.0   5.0  0.0    0.0   6.0
# ...

# %%
df1 = df1.drop(columns=['Squad'])

# %%
goals = df1['Gls']

# %%
gls_gm = []

for index, row in df1.iterrows():
    gls = (row["Gls"]) 
    games = (row['MP▼'])
    gls_gm.append(gls/games)

# %%
df1['gls_gm'] = gls_gm

# %%
df1.head()
# Out:
#    # Pl  Poss  MP▼   Gls   Ast  G-PK   PK  PKatt  CrdY  CrdR  ...  npxG  xAG  \
# 0  24.0  58.0  6.0  12.0   7.0   9.0  3.0    4.0  12.0   0.0  ...   8.9  6.2
# 1  18.0  55.0  6.0   6.0   6.0   6.0  0.0    0.0   8.0   0.0  ...   6.4  5.0
# 2  24.0  52.2  6.0  13.0  11.0  13.0  0.0    0.0   5.0   0.0  ...  11.6  9.7
# 3  22.0  37.2  6.0   5.0   4.0   5.0  0.0    0.0   7.0   1.0  ...   5.4  4.3
# 4  26.0  56.2  5.0   8.0   6.0   7.0  1.0    1.0   6.0   0.0  ...  11.2  8.2
#
#    npxG+xAG  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Squad_code    gls_gm
# 0      15.0  1.87   0.98    2.84    1.40        2.37           0  2.000000
# 1      11.4  0.95   0.75    1.71    0.95        1.71          15  1.000000
# 2      21.2  1.93   1.61    3.54    1.93        3.54          13  2.166667
# 3       9.7  0.86   0.68    1.54    0.86        1.54          19  0.833333
# 4      19.4  2.24   1.54    3.79    2.09        3.64           3  1.600000
#
# [5 rows x 26 columns]

# %%
df1 = df1.drop(columns=['Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Pl'])

# %%
df1['poss'] = df1['Poss']

# %%
df1 = df1.drop(columns=['Poss'])

# %%
df1.head()

# %%
# df1.to_csv('final4.csv', index=False)
