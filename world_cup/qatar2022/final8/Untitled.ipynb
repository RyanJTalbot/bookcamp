# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('eight_teams.csv')

# %%
df.cov()
# Out:
#                   Age        Poss         MP      Starts          Min  \
# Age          1.386845   -3.935948  -0.134677   -1.481452   -11.177419
# Poss        -3.935948   98.735766   2.095161   23.046774   214.741935
# MP          -0.134677    2.095161   0.709677    7.806452    71.612903
# Starts      -1.481452   23.046774   7.806452   85.870968   787.741935
# Min        -11.177419  214.741935  71.612903  787.741935  7374.193548
# 90s         -0.121260    2.371552   0.791129    8.702419    81.435484
# Gls         -1.120565   15.754032   2.225806   24.483871   218.709677
# Ast         -0.868145   13.491129   2.000000   22.000000   195.483871
# G-PK        -1.015625   13.373185   2.056452   22.620968   202.741935
# PK          -0.104940    2.380847   0.169355    1.862903    15.967742
# PKatt       -0.153125    2.496573   0.185484    2.040323    16.935484
# CrdY         0.653327   -8.477621  -0.169355   -1.862903   -14.032258
# ...

# %%
df.corr()
# Out:
#                  Age      Poss        MP    Starts       Min       90s  \
# Age         1.000000 -0.336355 -0.135753 -0.135753 -0.110528 -0.108568
# Poss       -0.336355  1.000000  0.250294  0.250294  0.251665  0.251648
# MP         -0.135753  0.250294  1.000000  1.000000  0.989928  0.990181
# Starts     -0.135753  0.250294  1.000000  1.000000  0.989928  0.990181
# Min        -0.110528  0.251665  0.989928  0.989928  1.000000  0.999895
# 90s        -0.108568  0.251648  0.990181  0.990181  0.999895  1.000000
# Gls        -0.281779  0.469505  0.782426  0.782426  0.754218  0.753523
# Ast        -0.245510  0.452169  0.790659  0.790659  0.758130  0.759354
# G-PK       -0.276324  0.431219  0.782146  0.782146  0.756460  0.756064
# PK         -0.144932  0.389704  0.326970  0.326970  0.302431  0.300626
# PKatt      -0.163032  0.315027  0.276068  0.276068  0.247276  0.245880
# CrdY        0.205595 -0.316180 -0.074501 -0.074501 -0.060557 -0.062196
# ...

# %%
# xg, npxg, xag, npxg+xag, ast1

# %%
df.head()
# Out:
#           Squad   Age  Poss  MP  Starts  Min  90s  Gls  Ast  G-PK  ...  \
# 0  ar Argentina  28.5  61.6   5      55  480  5.3    9    6     7  ...
# 1     br Brazil  28.4  56.2   5      55  480  5.3    8    6     7  ...
# 2    hr Croatia  29.3  54.0   5      55  510  5.7    6    6     6  ...
# 3   eng England  27.0  62.8   5      55  450  5.0   13   11    12  ...
# 4     fr France  27.3  54.8   5      55  450  5.0   11   11    11  ...
#
#    G+A-PK    xG  npxG  xAG  npxG+xAG  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1
# 0    2.44   9.5   7.3  5.2      12.6  1.78   0.98    2.76    1.37        2.36
# 1    2.44  12.0  11.2  8.2      19.4  2.24   1.54    3.79    2.09        3.64
# 2    2.12   5.8   5.8  4.7      10.5  1.03   0.83    1.86    1.03        1.86
# 3    4.60   8.7   7.1  5.7      12.8  1.73   1.13    2.87    1.42        2.55
# 4    4.40   9.5   9.5  8.4      17.9  1.90   1.69    3.59    1.90        3.59
#
# [5 rows x 28 columns]

# %%
fran = df[df['Squad'] == 'fr France']

# %%
moro = df[df['Squad'] == 'ma Morocco']

# %%
fran.T
# Out:
#                     4
# Squad       fr France
# Age              27.3
# Poss             54.8
# MP                  5
# Starts             55
# Min               450
# 90s               5.0
# Gls                11
# Ast                11
# G-PK               11
# PK                  0
# PKatt               0
# CrdY                5
# CrdR                0
# Gls.1             2.2
# Ast.1             2.2
# G+A               4.4
# G-PK.1            2.2
# G+A-PK            4.4
# xG                9.5
# npxG              9.5
# xAG               8.4
# npxG+xAG         17.9
# xG.1              1.9
# xAG.1            1.69
# xG+xAG           3.59
# npxG.1            1.9
# npxG+xAG.1       3.59

# %%
# # xg, npxg, xag, npxg+xag, ast1
# morocco 
# xG 	4.5
# npxG 	4.5
# xAG 	4.0
# npxG+xAG 	8.5
# Ast.1 	0.75

# france
# xG 	9.5
# npxG 	9.5
# xAG 	8.4
# npxG+xAG 	17.9
# Ast.1 	2.2

# %%
9.5-4.5
# Out:
# 5.0

# %%
9.5 - 4.5
# Out:
# 5.0

# %%
8.4 - 4.0
# Out:
# 4.4

# %%
17.9 - 8.5
# Out:
# 9.399999999999999

# %%
2.2 - 0.75
# Out:
# 1.4500000000000002
