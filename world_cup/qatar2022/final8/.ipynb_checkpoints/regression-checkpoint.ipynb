# %%
import numpy as np
import pandas as pd
from sklearn import svm

# %%
df = pd.read_csv('final8.csv')

# %%
df.head()
# Out:
#    MP  Gls.1  Ast.1  G+A  G-PK.1  G+A-PK    xG  npxG  xAG  npxG+xAG  xG.1  \
# 0   5   1.69   1.13 2.81    1.31    2.44  9.50  7.30 5.20     12.60  1.78
# 1   5   1.50   1.13 2.62    1.31    2.44 12.00 11.20 8.20     19.40  2.24
# 2   5   1.06   1.06 2.12    1.06    2.12  5.80  5.80 4.70     10.50  1.03
# 3   5   2.60   2.20 4.80    2.40    4.60  8.70  7.10 5.70     12.80  1.73
# 4   5   2.20   2.20 4.40    2.20    4.40  9.50  9.50 8.40     17.90  1.90
#
#    xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Squad_code  gls_gm  poss
# 0   0.98    2.76    1.37        2.36           0    1.80 61.60
# 1   1.54    3.79    2.09        3.64           3    1.60 56.20
# 2   0.83    1.86    1.03        1.86          15    1.20 54.00
# 3   1.13    2.87    1.42        2.55          11    2.60 62.80
# 4   1.69    3.59    1.90        3.59          13    2.20 54.80

# %%
X = df.drop(columns=['MP'])
y = df['MP']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.13, random_state=42)

# %%
regr = svm.SVR()

# %%
regr.fit(X_train, y_train)
# Out:
# SVR()

# %%
pred = regr.predict(X_test)

# %%
data = {'y_test': y_test, 'y_pred': pred}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)
new_df
# Out:
#     y_test  y_pred  diff
# 29       3    3.21  0.21
# 24       3    3.44  0.44
# 15       4    3.47  0.53
# 8        4    3.46  0.54
# 17       3    3.56  0.56

# %%
df.corr()
# Out:
#               MP  Gls.1  Ast.1   G+A  G-PK.1  G+A-PK    xG  npxG   xAG  \
# MP          1.00   0.54   0.61  0.59    0.54    0.59  0.65  0.64  0.63
# Gls.1       0.54   1.00   0.90  0.98    0.97    0.96  0.67  0.63  0.60
# Ast.1       0.61   0.90   1.00  0.97    0.91    0.98  0.70  0.71  0.72
# G+A         0.59   0.98   0.97  1.00    0.97    0.99  0.71  0.69  0.67
# G-PK.1      0.54   0.97   0.91  0.97    1.00    0.98  0.62  0.61  0.57
# G+A-PK      0.59   0.96   0.98  0.99    0.98    1.00  0.67  0.67  0.66
# xG          0.65   0.67   0.70  0.71    0.62    0.67  1.00  0.97  0.94
# npxG        0.64   0.63   0.71  0.69    0.61    0.67  0.97  1.00  0.98
# xAG         0.63   0.60   0.72  0.67    0.57    0.66  0.94  0.98  1.00
# npxG+xAG    0.64   0.62   0.72  0.68    0.60    0.67  0.97  1.00  0.99
# xG.1        0.20   0.54   0.54  0.56    0.47    0.52  0.85  0.83  0.80
# xAG.1       0.21   0.44   0.56  0.51    0.41    0.49  0.79  0.83  0.87
# xG+xAG      0.21   0.51   0.56  0.55    0.46    0.52  0.84  0.85  0.85
# npxG.1      0.18   0.49   0.55  0.53    0.46    0.52  0.81  0.85  0.83
# npxG+xAG.1  0.20   0.47   0.56  0.53    0.44    0.51  0.81  0.85  0.86
# Squad_code -0.13  -0.17  -0.22 -0.20   -0.18   -0.20 -0.37 -0.38 -0.30
# gls_gm      0.57   1.00   0.89  0.97    0.97    0.95  0.69  0.65  0.61
# poss        0.25   0.42   0.44  0.44    0.38    0.42  0.56  0.53  0.53
#
#             npxG+xAG  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Squad_code  \
# MP              0.64  0.20   0.21    0.21    0.18        0.20       -0.13
# Gls.1           0.62  0.54   0.44    0.51    0.49        0.47       -0.17
# Ast.1           0.72  0.54   0.56    0.56    0.55        0.56       -0.22
# G+A             0.68  0.56   0.51    0.55    0.53        0.53       -0.20
# G-PK.1          0.60  0.47   0.41    0.46    0.46        0.44       -0.18
# G+A-PK          0.67  0.52   0.49    0.52    0.52        0.51       -0.20
# xG              0.97  0.85   0.79    0.84    0.81        0.81       -0.37
# npxG            1.00  0.83   0.83    0.85    0.85        0.85       -0.38
# xAG             0.99  0.80   0.87    0.85    0.83        0.86       -0.30
# npxG+xAG        1.00  0.82   0.85    0.85    0.85        0.86       -0.35
# xG.1            0.82  1.00   0.92    0.98    0.97        0.95       -0.37
# xAG.1           0.85  0.92   1.00    0.98    0.97        0.99       -0.28
# xG+xAG          0.85  0.98   0.98    1.00    0.99        0.99       -0.34
# npxG.1          0.85  0.97   0.97    0.99    1.00        0.99       -0.38
# npxG+xAG.1      0.86  0.95   0.99    0.99    0.99        1.00       -0.34
# Squad_code     -0.35 -0.37  -0.28   -0.34   -0.38       -0.34        1.00
# gls_gm          0.63  0.53   0.44    0.50    0.48        0.47       -0.18
# poss            0.53  0.53   0.51    0.54    0.51        0.52       -0.20
#
#             gls_gm  poss
# MP            0.57  0.25
# Gls.1         1.00  0.42
# Ast.1         0.89  0.44
# G+A           0.97  0.44
# G-PK.1        0.97  0.38
# G+A-PK        0.95  0.42
# xG            0.69  0.56
# npxG          0.65  0.53
# xAG           0.61  0.53
# npxG+xAG      0.63  0.53
# xG.1          0.53  0.53
# xAG.1         0.44  0.51
# xG+xAG        0.50  0.54
# npxG.1        0.48  0.51
# npxG+xAG.1    0.47  0.52
# Squad_code   -0.18 -0.20
# gls_gm        1.00  0.44
# poss          0.44  1.00

# %%
df.cov()
# Out:
#               MP  Gls.1  Ast.1   G+A  G-PK.1  G+A-PK    xG  npxG   xAG  \
# MP          0.71   0.29   0.30  0.59    0.27    0.57  1.43  1.27  1.03
# Gls.1       0.29   0.42   0.34  0.75    0.38    0.71  1.14  0.97  0.75
# Ast.1       0.30   0.34   0.33  0.67    0.32    0.65  1.06  0.97  0.81
# G+A         0.59   0.75   0.67  1.42    0.70    1.36  2.20  1.94  1.57
# G-PK.1      0.27   0.38   0.32  0.70    0.36    0.68  0.97  0.87  0.68
# G+A-PK      0.57   0.71   0.65  1.36    0.68    1.33  2.03  1.84  1.49
# xG          1.43   1.14   1.06  2.20    0.97    2.03  6.84  6.04  4.83
# npxG        1.27   0.97   0.97  1.94    0.87    1.84  6.04  5.62  4.53
# xAG         1.03   0.75   0.81  1.57    0.68    1.49  4.83  4.53  3.84
# npxG+xAG    2.32   1.73   1.79  3.51    1.55    3.34 10.89 10.17  8.38
# xG.1        0.09   0.19   0.17  0.36    0.16    0.33  1.22  1.08  0.87
# xAG.1       0.08   0.12   0.14  0.26    0.11    0.25  0.89  0.86  0.74
# xG+xAG      0.17   0.32   0.31  0.63    0.26    0.58  2.12  1.94  1.61
# npxG.1      0.08   0.16   0.16  0.32    0.14    0.30  1.08  1.02  0.83
# npxG+xAG.1  0.15   0.29   0.30  0.59    0.25    0.55  1.98  1.88  1.57
# Squad_code -1.00  -1.05  -1.17 -2.22   -1.01   -2.18 -9.04 -8.43 -5.52
# gls_gm      0.32   0.43   0.34  0.77    0.39    0.73  1.19  1.01  0.79
# poss        2.10   2.72   2.55  5.26    2.26    4.80 14.59 12.51 10.30
#
#             npxG+xAG  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Squad_code  \
# MP              2.32  0.09   0.08    0.17    0.08        0.15       -1.00
# Gls.1           1.73  0.19   0.12    0.32    0.16        0.29       -1.05
# Ast.1           1.79  0.17   0.14    0.31    0.16        0.30       -1.17
# G+A             3.51  0.36   0.26    0.63    0.32        0.59       -2.22
# G-PK.1          1.55  0.16   0.11    0.26    0.14        0.25       -1.01
# G+A-PK          3.34  0.33   0.25    0.58    0.30        0.55       -2.18
# xG             10.89  1.22   0.89    2.12    1.08        1.98       -9.04
# npxG           10.17  1.08   0.86    1.94    1.02        1.88       -8.43
# xAG             8.38  0.87   0.74    1.61    0.83        1.57       -5.52
# npxG+xAG       18.58  1.95   1.60    3.55    1.85        3.46      -14.12
# xG.1            1.95  0.30   0.22    0.52    0.27        0.49       -1.90
# xAG.1           1.60  0.22   0.19    0.41    0.21        0.40       -1.16
# xG+xAG          3.55  0.52   0.41    0.93    0.48        0.89       -3.06
# npxG.1          1.85  0.27   0.21    0.48    0.26        0.47       -1.82
# npxG+xAG.1      3.46  0.49   0.40    0.89    0.47        0.87       -2.99
# Squad_code    -14.12 -1.90  -1.16   -3.06   -1.82       -2.99       88.00
# gls_gm          1.80  0.19   0.13    0.32    0.16        0.29       -1.14
# poss           22.86  2.91   2.22    5.14    2.56        4.79      -18.70
#
#             gls_gm   poss
# MP            0.32   2.10
# Gls.1         0.43   2.72
# Ast.1         0.34   2.55
# G+A           0.77   5.26
# G-PK.1        0.39   2.26
# G+A-PK        0.73   4.80
# xG            1.19  14.59
# npxG          1.01  12.51
# xAG           0.79  10.30
# npxG+xAG      1.80  22.86
# xG.1          0.19   2.91
# xAG.1         0.13   2.22
# xG+xAG        0.32   5.14
# npxG.1        0.16   2.56
# npxG+xAG.1    0.29   4.79
# Squad_code   -1.14 -18.70
# gls_gm        0.44   2.88
# poss          2.88  98.74
