# %%
import pandas as pd
import numpy as np
from soccer_data_api import SoccerDataAPI

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_html('https://fbref.com/en/squads/c1e40422/2022/Germany-Men-Stats')

# %%
for idx,table in enumerate(df):
 print("***************************")
 print(idx)
 print(table)
# Out:
# ***************************
# 0
#        Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Player                Pos                Age
# 0              Leroy Sané              MF,FW               26.0
# 1          Joshua Kimmich                 MF               26.0
# 2           Leon Goretzka                 MF               26.0
# 3         Antonio Rüdiger                 DF               28.0
# 4            Thilo Kehrer                 DF               25.0
# 5          İlkay Gündoğan                 MF               31.0
# 6            Serge Gnabry              MF,FW               26.0
# 7            Manuel Neuer                 GK               35.0
# 8             Kai Havertz              FW,MF               22.0
# 9             Timo Werner                 FW               25.0
# 10            Niklas Süle                 DF               26.0
# 11          Jonas Hofmann              DF,MF               29.0
# ...

# %%
df[0]
# Out:
#        Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Player                Pos                Age
# 0              Leroy Sané              MF,FW               26.0
# 1          Joshua Kimmich                 MF               26.0
# 2           Leon Goretzka                 MF               26.0
# 3         Antonio Rüdiger                 DF               28.0
# 4            Thilo Kehrer                 DF               25.0
# 5          İlkay Gündoğan                 MF               31.0
# 6            Serge Gnabry              MF,FW               26.0
# 7            Manuel Neuer                 GK               35.0
# 8             Kai Havertz              FW,MF               22.0
# 9             Timo Werner                 FW               25.0
# 10            Niklas Süle                 DF               26.0
# 11          Jonas Hofmann              DF,MF               29.0
# 12        Matthias Ginter                 DF               28.0
# ...

# %%
df = df[0]

# %%
df.columns
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',  'Player'),
#             ( 'Unnamed: 1_level_0',     'Pos'),
#             ( 'Unnamed: 2_level_0',     'Age'),
#             ( 'Unnamed: 3_level_0',      'MP'),
#             (       'Playing Time',  'Starts'),
#             (       'Playing Time',     'Min'),
#             (       'Playing Time',     '90s'),
#             (        'Performance',     'Gls'),
#             (        'Performance',     'Ast'),
#             (        'Performance',    'G-PK'),
#             (        'Performance',      'PK'),
#             (        'Performance',   'PKatt'),
#             (        'Performance',    'CrdY'),
#             (        'Performance',    'CrdR'),
#             (     'Per 90 Minutes',     'Gls'),
#             (     'Per 90 Minutes',     'Ast'),
#             (     'Per 90 Minutes',     'G+A'),
#             (     'Per 90 Minutes',    'G-PK'),
#             (     'Per 90 Minutes',  'G+A-PK'),
# ...

# %%
df.rename(columns = {"('Unnamed: 0_level_0', 'Player')":"Player"}, inplace = True)

# %%
df.columns[0]
# Out:
# ('Unnamed: 0_level_0', 'Player')

# %%
df.columns = ['Player', 'Pos', 'Age', 'MP', 'Starts', 'Min', '90s', 'Gls',
             'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls',
             'Ast', 'G+A', 'G-PK', 'G+A-PK', 'Matches']

# %%
df = df.sort_values('Starts', ascending=False)

# %%
totals = df[:2]

# %%
df = df.reset_index()

# %%
df = df.drop(columns=['index'])

# %%
df = df.iloc[:2]

# %%
df = df.drop(columns=['Pos', 'Age', 'MP', 'Starts', 'Min', '90s', 'Matches'])

# %%
opp = df[:1]

# %%
opp
# Out:
#            Player  Gls  Ast  G-PK   PK  PKatt  CrdY  CrdR  Gls  Ast  G+A  \
# 0  Opponent Total  4.0  2.0   3.0  1.0    1.0  15.0   1.0  0.4  0.2  0.6
#
#    G-PK  G+A-PK
# 0   0.3     0.5

# %%
opp.Ast
# Out:
# Empty DataFrame
# Columns: [Ast, Ast]
# Index: []

# %%
df['opponent gls'] = 4.0
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/3303357533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['opponent gls'] = 4.0

# %%
df = df[1:]

# %%
df['opp ast'] = 2.0
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/918151038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['opp ast'] = 2.0

# %%
df['opp g-pk'] = 3.0
df['opp pk'] = 1.0
df['opp pkatt'] = 1.0
df['opp crdy'] = 15.0
df['opp crdr'] = 1.0
df['opp gls'] = 0.4
df['opp ast'] = 0.2
df['opp g+a'] = 0.6
df['opp g-pk'] = 0.3
df['opp g+a-pk'] = 0.5
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/1004943560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['opp g-pk'] = 3.0
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/1004943560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['opp pk'] = 1.0
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/1004943560.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['losses'] = 1
df['wins'] = 9
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/198995450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['losses'] = 1
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/198995450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wins'] = 9

# %%
df
# Out:
#         Player   Gls   Ast  G-PK   PK  PKatt  CrdY  CrdR  Gls  Ast  ...  \
# 1  Squad Total  34.0  27.0  31.0  3.0    3.0  12.0   0.0  3.4  2.7  ...
#
#    opp g-pk  opp pk  opp pkatt  opp crdy  opp crdr  opp gls  opp g+a  \
# 1       0.3     1.0        1.0      15.0       1.0      0.4      0.6
#
#    opp g+a-pk  losses  wins
# 1         0.5       1     9
#
# [1 rows x 25 columns]

# %%
df['Player'] = 'Germany22'
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_71216/1020214501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player'] = 'Germany22'

# %%
df
# Out:
#       Player   Gls   Ast  G-PK   PK  PKatt  CrdY  CrdR  Gls  Ast  ...  \
# 1  Germany22  34.0  27.0  31.0  3.0    3.0  12.0   0.0  3.4  2.7  ...
#
#    opp g-pk  opp pk  opp pkatt  opp crdy  opp crdr  opp gls  opp g+a  \
# 1       0.3     1.0        1.0      15.0       1.0      0.4      0.6
#
#    opp g+a-pk  losses  wins
# 1         0.5       1     9
#
# [1 rows x 25 columns]

# %%
# ['Player', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls',
#  'Ast', 'G+A', 'G-PK', 'G+A-PK', 'opponent gls', 'opp ast', 'opp g-pk',
#  'opp pk', 'opp pkatt', 'opp crdy', 'opp crdr', 'opp gls', 'opp g+a',
#  'opp g+a-pk', 'losses', 'wins']

# %%
# ['goals_z', 'xg_z', 'crosses_z', 'boxtouches_z', 'passes_z',
#  'progpasses_z', 'takeons_z', 'progruns_z', 'tackles_z',
#  'interceptions_z', 'clearances_z', 'blocks_z', 'aerials_z', 
#  'fouls_z','fouled_z', 'nsxg_z', 'results']
