# %%
import numpy as np 
import pandas as pd

# %%
df = pd.concat(map(pd.read_csv, ['Brazil.csv', 'germany.csv','germany1.csv', 
                                 'Portugal1.csv', 'Spain1.csv', 'Switzerland.csv',
                                'Switzerland1.csv', 'France1.csv',
                                'Brazil1.csv', 'Netherlands.csv', 
                                'Belgium.csv', 'USA.csv', 'England.csv',
                                'Argentina.csv', 'Uruguay.csv', 
                                'Senegal.csv', 'Ecuador.csv', 'CostaRica.csv',
                                'Mexico.csv', 'France.csv', 'Denmark.csv',
                                'Australia.csv', 'Serbia.csv',
                                'Cameroon.csv', 'Ghana.csv', 'Iran.csv',
                                'Poland.csv', 'SaudI.csv', 'Tunisia.csv', 
                                 'Japan.csv', 'Croatia.csv', 'Morocco.csv',
                                'USA1.csv']))

# %%
df.shape
# Out:
# (115, 17)

# %%
df
# Out:
#      goals_z      xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0   0.423077  0.146923  -0.136154     -0.030000  0.429231      0.037692
# 1   0.216923  0.348462   0.031538      0.158462  0.835385      0.626923
# 2   0.113846  0.392308   0.599231      0.513846  0.833077      0.405385
# 3   0.479231  0.609231   0.227692      0.450769  0.770769      0.042308
# 4   0.877692  0.773846   0.428462      0.659231  0.754615      0.335385
# ..       ...       ...        ...           ...       ...           ...
# 3   0.520000  0.379231   0.298462      0.375385  0.407692      0.074615
# 0  -0.243077  0.000769   0.207692      0.120769 -0.172308     -0.327692
# 0  -0.063077 -0.080769  -0.190769     -0.049231 -0.176154     -0.341538
# 1  -0.186923 -0.232308  -0.103846     -0.253846 -0.220769     -0.240000
# 2  -0.261538 -0.247692   0.028462      0.137692 -0.206923     -0.283077
#
#     takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  blocks_z  \
# ...

# %%
df.corr()
# Out:
#                   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# goals_z          1.000000  0.585493   0.054663      0.248932  0.298461
# xg_z             0.585493  1.000000   0.398390      0.659253  0.387879
# crosses_z        0.054663  0.398390   1.000000      0.644008  0.256583
# boxtouches_z     0.248932  0.659253   0.644008      1.000000  0.407707
# passes_z         0.298461  0.387879   0.256583      0.407707  1.000000
# progpasses_z     0.155753  0.184738   0.300881      0.254182  0.718822
# takeons_z        0.237338  0.309114   0.052133      0.183017  0.405944
# progruns_z       0.218104  0.437528   0.272081      0.481106  0.665386
# tackles_z        0.371657  0.397830   0.201907      0.391493  0.741805
# interceptions_z  0.289070  0.311220   0.259362      0.338852  0.692621
# clearances_z    -0.113795 -0.369458  -0.180750     -0.396161 -0.187100
# blocks_z         0.121577  0.140070   0.096508      0.277398  0.356612
# ...

# %%
df.shape
# Out:
# (115, 17)

# %%
df.to_csv('WC-stats.csv', index=False)
