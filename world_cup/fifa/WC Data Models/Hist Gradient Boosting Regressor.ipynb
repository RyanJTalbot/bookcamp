# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn import ensemble
from sklearn.inspection import permutation_importance
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
df = pd.read_csv('hotData.csv')

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.10, random_state=2)

# %%
est = HistGradientBoostingRegressor(learning_rate=.086, max_iter=90)

# %%
est.fit(X_train, y_train)
# Out:
# HistGradientBoostingRegressor(learning_rate=0.086, max_iter=90)

# %%
test_pred = est.predict(X_test)

# %%
print('RMSE: '+str(np.sqrt(mean_squared_error(y_test, test_pred))))
print('R Squared: '+str(r2_score(y_test, test_pred)))
print('MSE TEST: '+str(mean_squared_error(y_test, test_pred)))
print('MAE TEST: '+str(mean_absolute_error(y_test, test_pred)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, test_pred)))
# Out:
# RMSE: 6.933787658525343
# R Squared: 0.39639472579570456
# MSE TEST: 48.07741129351836
# MAE TEST: 5.15057063392969
# MAPE: 0.662656835052735

# %%
# MAPE: 0.740133161144745
# learning_rate=.09 MAPE: 0.7189993276253182
# learning_rate=.085 MAPE: 0.6825727185474776
# learning_rate=.086 MAPE: 0.6744187545349198
# max_iter=90 MAPE: 0.662656835052735

# %%
data = {'y_test': y_test, 'y_pred': test_pred}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)

# %%
new_df
# Out:
#      y_test     y_pred       diff
# 144       4   4.137061   0.137061
# 66       17  17.201107   0.201107
# 141      14  13.664760   0.335240
# 11       12  12.370761   0.370761
# 106       9   8.232156   0.767844
# 130      10  11.186950   1.186950
# 151      22  19.909503   2.090497
# 77       18  15.631011   2.368989
# 7        19  21.840880   2.840880
# 244       6   9.349151   3.349151
# 267      26  22.529292   3.470708
# 101       1   4.546260   3.546260
# 3        32  28.091338   3.908662
# 29       23  19.017958   3.982042
# 234       7  11.080344   4.080344
# 159       5   9.120726   4.120726
# 13        7  11.278578   4.278578
# 202       6  10.394278   4.394278
# 259       1   5.750817   4.750817
# 89       22  17.185998   4.814002
# 164      11   6.147241   4.852759
# 253      28  22.401792   5.598208
# 120      17  10.192253   6.807747
# 232      15   7.437343   7.562657
# 254      17  26.519535   9.519535
# 230      29  16.353728  12.646272
# 35       18   5.232416  12.767584
# 175       6  20.245164  14.245164
# 214      31  10.628274  20.371726
