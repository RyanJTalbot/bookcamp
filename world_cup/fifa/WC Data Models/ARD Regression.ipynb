# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn import linear_model

# %%
# df = pd.read_csv('wc-wo-outliers.csv')
# df2 = pd.read_csv('wc-w-outliers.csv')
df = pd.read_csv('hotData.csv')

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.15, random_state=1)

# %%
clf = linear_model.ARDRegression()
# clf2 = linear_model.ARDRegression()

# %%
clf.fit(X_train, y_train)
# clf2.fit(X_train2, y_train2)
# Out:
# ARDRegression()

# %%
pred_train= clf.predict(X_train)
pred_test= clf.predict(X_test)

# %%
# pred_train= clf2.predict(X_train2)
# pred_test= clf2.predict(X_test2)

# %%
# print('RMSE : '+str(np.sqrt(mean_squared_error(y_test2,pred_test2)))) 
# print('R2 : '+str(r2_score(y_test2, pred_test2)))
# print('MSE: '+str(mean_squared_error(y_test2, pred_test2)))
# print('MAE: '+str(mean_absolute_error(y_test2, pred_test2)))
# print('MAPE: '+str(mean_absolute_percentage_error(y_test2, pred_test2)))

print('---------------------')

# pred_test= clf.predict(X_test)

print('RMSE : '+str(np.sqrt(mean_squared_error(y_test,pred_test)))) 
print('R2 : '+str(r2_score(y_test, pred_test)))
print('MSE: '+str(mean_squared_error(y_test, pred_test)))
print('MAE: '+str(mean_absolute_error(y_test, pred_test)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, pred_test)))
# Out:
# ---------------------
# RMSE : 5.622454981790602
# R2 : 0.5107672963057872
# MSE: 31.612000022261963
# MAE: 4.450318521309623
# MAPE: 0.8257441949206946

# %%
data = {'y_test': y_test, 'y_pred': pred_test}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)

# %%
new_df
# Out:
#      y_test     y_pred       diff
# 107       8   7.783962   0.216038
# 17        2   1.755355   0.244645
# 11       27  27.577064   0.577064
# 217      12  12.690470   0.690470
# 179       6   7.004749   1.004749
# 208      26  24.881816   1.118184
# 99        8   9.478390   1.478390
# 102      19  20.722849   1.722849
# 278      19  17.215065   1.784935
# 247       6   4.183649   1.816351
# 42       18  19.904596   1.904596
# 258       1   3.248482   2.248482
# 134       9   6.623770   2.376230
# 186      16  18.436617   2.436617
# 267       5   2.556671   2.443329
# 89       12  14.585125   2.585125
# 62        7   4.369916   2.630084
# 214      28  25.225450   2.774550
# 265      12  14.831146   2.831146
# 138       1   3.892433   2.892433
# 27       14  10.969865   3.030135
# 105       9  12.076164   3.076164
# 250      10  13.844352   3.844352
# 169      10   5.898211   4.101789
# 171      20  15.598937   4.401063
# 88        8  12.620438   4.620438
# 18       16  20.797446   4.797446
# 192      21  16.168407   4.831593
# 4        15   9.901656   5.098344
# 159      21  15.822203   5.177797
# 212      11  16.387345   5.387345
# 90        4   9.899763   5.899763
# 226      32  25.755156   6.244844
# 194       9  15.412288   6.412288
# 187       3   9.770432   6.770432
# 12        7  14.167799   7.167799
# 154      21  13.167111   7.832889
# 59       26  17.552950   8.447050
# 273       1   9.539293   8.539293
# 158       5  13.663705   8.663705
# 119      17   4.067674  12.932326
# 132       3  16.599362  13.599362
# 257       9  -5.711215  14.711215

# %%
new_df['diff'].mean()
# Out:
# 4.450318521309624

# %%
new_df['diff'].median()
# Out:
# 3.0761636174254683
