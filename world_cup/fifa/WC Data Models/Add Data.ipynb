# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
df = pd.read_csv('WC-stats.csv')

# %%
df.head()
# Out:
#     goals_z      xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0  0.423077  0.146923  -0.136154     -0.030000  0.429231      0.037692
# 1  0.216923  0.348462   0.031538      0.158462  0.835385      0.626923
# 2  0.113846  0.392308   0.599231      0.513846  0.833077      0.405385
# 3  0.479231  0.609231   0.227692      0.450769  0.770769      0.042308
# 4  0.877692  0.773846   0.428462      0.659231  0.754615      0.335385
#
#    takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  blocks_z  \
# 0   0.244615   -0.220000   0.216154         0.270000     -0.076923 -0.097692
# 1   0.270000    0.266923   1.143846         0.834615     -0.059231 -0.134615
# 2   0.521538    1.139231   1.109231         0.859231      0.084615  0.103077
# 3   0.337692    0.927692   0.506923         1.015385      0.020769  0.381538
# 4   0.023077    0.638462   0.493846         0.637692     -0.117692 -0.033846
#
#    aerials_z   fouls_z  fouled_z    nsxg_z  results
# ...

# %%
df = df.rename(columns={"Unnamed: 0": "country"}, errors="raise")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df = df.rename(columns={"Unnamed: 0": "country"}, errors="raise")
#
# File ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/util/_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/core/frame.py:5039, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4916 @rewrite_axis_style_signature(
#    4917     "mapper",
#    4918     [("copy", True), ("inplace", False), ("level", None), ("errors", "ignore")],
#    (...)
#    4930     errors: str = "ignore",
#    4931 ) -> DataFrame | None:
# ...

# %%
sers = df['country']

# %%
year = []
count = 0
for i in sers:
    num = (((i[-2]) + i[-1]))
    year.append(int(num))

# %%
len(year)

# %%
df['year'] = year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   goals_z          257 non-null    float64
#  1   xg_z             257 non-null    float64
#  2   crosses_z        257 non-null    float64
#  3   boxtouches_z     257 non-null    float64
#  4   passes_z         257 non-null    float64
#  5   progpasses_z     257 non-null    float64
#  6   takeons_z        257 non-null    float64
#  7   progruns_z       257 non-null    float64
#  8   tackles_z        257 non-null    float64
#  9   interceptions_z  257 non-null    float64
#  10  clearances_z     257 non-null    float64
#  11  blocks_z         257 non-null    float64
#  12  aerials_z        257 non-null    float64
#  13  fouls_z          257 non-null    float64
#  14  fouled_z         257 non-null    float64
#  15  nsxg_z           257 non-null    float64
# ...

# %%
df['year'].value_counts().sum()
# Out:
# 257

# %%
df
# Out:
#         country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 0      Brazil98  0.423077  0.146923  -0.136154     -0.030000  0.429231
# 1      Brazil94  0.216923  0.348462   0.031538      0.158462  0.835385
# 2      Brazil90  0.113846  0.392308   0.599231      0.513846  0.833077
# 3      Brazil86  0.479231  0.609231   0.227692      0.450769  0.770769
# 4      Brazil82  0.877692  0.773846   0.428462      0.659231  0.754615
# ..          ...       ...       ...        ...           ...       ...
# 252  Colombia90  0.073077  0.004615  -0.013077      0.047692  0.873846
# 253  Colombia94  0.013846  0.266923  -0.103846      0.443077  1.092308
# 254  Colombia98 -0.261538 -0.169231  -0.216923     -0.154615  0.068462
# 255  Colombia14  0.781538  0.256154   0.016923      0.298462 -0.303077
# 256  Colombia18  0.313077 -0.103077   0.029231     -0.319231 -0.093846
#
#      progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# ...

# %%
country = df['country']

# %%
country
# Out:
# 0        Brazil98
# 1        Brazil94
# 2        Brazil90
# 3        Brazil86
# 4        Brazil82
#           ...
# 252    Colombia90
# 253    Colombia94
# 254    Colombia98
# 255    Colombia14
# 256    Colombia18
# Name: country, Length: 257, dtype: object

# %%
country = []
for i in sers:
    land = (i[:-2])
    country.append(str(land))

# %%
df['country'] = country

# %%
df
# Out:
#       country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 0      Brazil  0.423077  0.146923  -0.136154     -0.030000  0.429231
# 1      Brazil  0.216923  0.348462   0.031538      0.158462  0.835385
# 2      Brazil  0.113846  0.392308   0.599231      0.513846  0.833077
# 3      Brazil  0.479231  0.609231   0.227692      0.450769  0.770769
# 4      Brazil  0.877692  0.773846   0.428462      0.659231  0.754615
# ..        ...       ...       ...        ...           ...       ...
# 252  Colombia  0.073077  0.004615  -0.013077      0.047692  0.873846
# 253  Colombia  0.013846  0.266923  -0.103846      0.443077  1.092308
# 254  Colombia -0.261538 -0.169231  -0.216923     -0.154615  0.068462
# 255  Colombia  0.781538  0.256154   0.016923      0.298462 -0.303077
# 256  Colombia  0.313077 -0.103077   0.029231     -0.319231 -0.093846
#
#      progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          257 non-null    object
#  1   goals_z          257 non-null    float64
#  2   xg_z             257 non-null    float64
#  3   crosses_z        257 non-null    float64
#  4   boxtouches_z     257 non-null    float64
#  5   passes_z         257 non-null    float64
#  6   progpasses_z     257 non-null    float64
#  7   takeons_z        257 non-null    float64
#  8   progruns_z       257 non-null    float64
#  9   tackles_z        257 non-null    float64
#  10  interceptions_z  257 non-null    float64
#  11  clearances_z     257 non-null    float64
#  12  blocks_z         257 non-null    float64
#  13  aerials_z        257 non-null    float64
#  14  fouls_z          257 non-null    float64
#  15  fouled_z         257 non-null    float64
# ...

# %% [markdown]
# ## Add: GDP per capita, Population, ODDSET probability, Rank, Continent, Confederation
#
# - ODDSET probability. We convert bookmaker odds provided by the German state betting agency ODDSET into winning probabilities. The variable hence reflects the probability for each team to win the respective World Cup1.
#
# - FIFA rank. The FIFA ranking system ranks all national teams based on their performance over the last four years (source: http://de.fifa.com/ worldranking/index.html).
#
# - Continent. A dummy variable indicating if a national team is from the same continent as the host of the World Cup (including the host itself).
#
# - Confederation. This categorical variable comprises the teams’ confederation with six possible values: Africa (CAF); Asia (AFC); Europe (UEFA); North, Central America and Caribbean (CONCACAF); Oceania (OFC); South America (CONMEBOL).

# %%
df = df.sort_values(by=['year'])

# %%
df['year'].value_counts()
# Out:
# 10    30
# 14    30
# 2     28
# 18    28
# 98    28
# 6     25
# 90    24
# 82    23
# 86    20
# 94    20
# 16     1
# Name: year, dtype: int64

# %%
df['country'].value_counts()
# Out:
# Spain         10
# Brazil        10
# Argentina     10
# Germany       10
# England        9
#               ..
# ElSalvador     1
# Slovakia       1
# Iceland        1
# Bosnia         1
# Jamaica        1
# Name: country, Length: 70, dtype: int64

# %%
df
# Out:
#        country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 58     Senegal  0.193077  0.087692  -0.180000      0.045385 -0.492308
# 41     Belgium  0.199231  0.210769   0.180769      0.360000 -0.336154
# 44     England  0.176154  0.186154   0.086154      0.163846  0.218462
# 167      Italy  0.153077  0.197692   0.030000      0.088462 -0.665385
# 49   Argentina -0.085385  0.673846   0.561538      0.820000  0.390000
# ..         ...       ...       ...        ...           ...       ...
# 130      Saudi -0.103077  0.056154  -0.315385     -0.459231 -0.072308
# 230     Norway  0.053846  0.193846   0.556154      0.261538 -0.200769
# 122    Belgium  0.055385 -0.119231  -0.020769      0.236154 -0.781538
# 166      Italy  0.293846  0.176154  -0.355385     -0.112308 -0.164615
# 0       Brazil  0.423077  0.146923  -0.136154     -0.030000  0.429231
#
#      progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# ...

# %%
df.to_csv('WC-new.csv', index=False)
