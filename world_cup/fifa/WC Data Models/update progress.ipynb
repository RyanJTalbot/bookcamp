# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('WC-almost-final.csv')

# %%
df.shape
# Out:
# (276, 20)

# %%
df = df.drop(columns= ['Unnamed: 0'])

# %%
df
# Out:
#        country     goals        xg   crosses  boxtouches    passes  \
# 0        italy  0.286154  0.069231  0.013846   -0.040000 -0.095385
# 1       brazil  0.216923  0.348462  0.031538    0.158462  0.835385
# 2       france  0.489231  0.231538 -0.124615    0.189231  0.123846
# 3    argentina  0.536154  0.170769  0.166154    0.190769 -0.167692
# 4      germany  0.673077  0.642308  0.502308    0.277692  0.310000
# ..         ...       ...       ...       ...         ...       ...
# 271      egypt -0.066923 -0.147692  0.028462   -0.050000 -0.076154
# 272        usa -0.261538 -0.247692  0.028462    0.137692 -0.206923
# 273   cameroon -0.261538 -0.067692  0.040000    0.203077 -0.335385
# 274      saudi -0.410000 -0.271538 -0.201538   -0.313077  0.321538
# 275     panama -0.420000 -0.230000 -0.150769   -0.435385 -0.687692
#
#      progpasses   takeons  progruns   tackles  interceptions  clearances  \
# 0      0.041538  0.054615 -0.230000 -0.101538      -0.220769    0.033846
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    276
# dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2     31
# 98    31
# 14    31
# 18    30
# 10    30
# 6     28
# 86    24
# 90    24
# 82    23
# 94    23
# 16     1
# Name: year, dtype: int64

# %%
# 98 - 18 => 32 teams
# 82 - 94 => 24 trams

# %% [markdown]
# # 18 / -2

# %%
wc18 = df[df['year'] == 18]

# %%
wc18.shape
# Out:
# (30, 19)

# %% [markdown]
# # 14 / -1

# %%
wc14 = df[df['year'] == 14]

# %%
wc14.shape
# Out:
# (31, 19)

# %% [markdown]
# # 10 / -2

# %%
wc10 = df[df['year'] == 10]

# %%
wc10.shape
# Out:
# (30, 19)

# %% [markdown]
# # 06 / -5

# %%
wc06 = df[df['year'] == 6]

# %%
wc06.shape
# Out:
# (28, 19)

# %%
wc06
# Out:
#            country     goals        xg   crosses  boxtouches    passes  \
# 9            italy  0.484615  0.213077 -0.103846    0.202308 -0.116154
# 10          france  0.288462  0.370769  0.124615    0.288462  0.166154
# 27         germany  0.560000  0.225385  0.015385    0.206923  0.061538
# 37        portugal  0.130000  0.343846 -0.145385   -0.004615  0.040769
# 48          brazil  0.619231  0.383846  0.065385    0.277692  0.701538
# 59       argentina  0.700000 -0.006923 -0.137692   -0.071538  0.443077
# 68         england  0.122308  0.330000  0.343077    0.552308 -0.055385
# 77          ukrain  0.122308  0.143846 -0.026923   -0.242308 -0.064615
# 82           spain  0.881538  1.015385  0.637692    0.533077  0.500769
# 90     switzerland  0.113077  0.003846 -0.050000   -0.033077  0.225385
# 104    netherlands  0.013846  0.156923 -0.199231    0.152308  0.206154
# 115        ecuador  0.303077  0.085385  0.030000   -0.054615  0.348462
# ...

# %%
# 15 Mexico
# 20 Czech Republic
# 27  Trinidad and Tobago
# 30 Togo
# 31  Costa Rica
# 32  Serbia and Montenegro

# %% [markdown]
# # 02 / -1

# %%
wc02 = df[df['year'] == 2]

# %%
wc02.shape
# Out:
# (31, 19)

# %% [markdown]
# # 98 / -1

# %%
wc98 = df[df['year'] == 98]

# %%
wc98.shape
# Out:
# (31, 19)

# %% [markdown]
#  # 94 / -1

# %%
wc94 = df[df['year'] == 94]

# %%
wc94.shape
# Out:
# (23, 19)

# %% [markdown]
# # 90 / 0

# %%
wc90 = df[df['year'] == 90]

# %%
wc90.shape
# Out:
# (24, 19)

# %% [markdown]
# # 86 / 0

# %%
wc86 = df[df['year'] == 86]

# %%
wc86.shape
# Out:
# (24, 19)

# %% [markdown]
# # 82 / -1

# %%
wc82 = df[df['year'] == 82]

# %%
wc82.shape
# Out:
# (23, 19)

# %%
wc06 = wc06.sort_values(by='results')

# %%
wc06
# Out:
#            country     goals      xg_z  crosses_z  boxtouches_z  passes_z  \
# 128          Italy  0.484615  0.213077  -0.103846      0.202308 -0.116154
# 95          France  0.288462  0.370769   0.124615      0.288462  0.166154
# 103        Germany  0.560000  0.225385   0.015385      0.206923  0.061538
# 185       Portugal  0.130000  0.343846  -0.145385     -0.004615  0.040769
# 33          Brazil  0.619231  0.383846   0.065385      0.277692  0.701538
# 6        Argentina  0.700000 -0.006923  -0.137692     -0.071538  0.443077
# 86         England  0.122308  0.330000   0.343077      0.552308 -0.055385
# 257         Ukrain  0.122308  0.143846  -0.026923     -0.242308 -0.064615
# 232          Spain  0.881538  1.015385   0.637692      0.533077  0.500769
# 246    Switzerland  0.113077  0.003846  -0.050000     -0.033077  0.225385
# 155    Netherlands  0.013846  0.156923  -0.199231      0.152308  0.206154
# 80         Ecuador  0.303077  0.085385   0.030000     -0.054615  0.348462
# ...

# %%
# 15 mexico
# 17 south korea
# 20 Czech Republic
# 23 Angola
# 27 Trinidad and Tobago
# 30  Togo
# 31 Costa Rica
# 32  Serbia and Montenegro

# %%
sp1 = pd.read_csv('../Spain1.csv')

# %%
sp2 = pd.read_csv('../Spain2.csv')

# %%
results = [sp1, sp2]

# %%
spa = pd.concat(results)

# %%
spa.iloc[1]['results'] = 9
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()

# %%
spa
# Out:
#   Unnamed: 0   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 0    Spain02  0.451538  0.495385  -0.012308      0.182308  0.003077
# 1    Spain06  0.881538  1.015385   0.637692      0.533077  0.500769
# 2    Spain10  0.180000  0.539231   0.383077      0.868462  1.156923
# 3    Spain14  0.243846  0.536154  -0.076154      0.596923  0.770769
# 4    Spain18  0.190769  0.680769   0.319231      0.763077  1.410769
# 0    Spain82 -0.133846  0.256154   0.170769      0.283077  0.134615
# 1    Spain86  0.566154  0.463077   0.130000      0.464615 -0.154615
# 2    Spain90  0.319231  0.181538   0.343077      0.478462  0.093077
# 3    Spain94  0.417692  0.250000   0.259231      0.076154 -0.371538
# 4    Spain98  0.689231  0.773846  -0.020769      0.551538 -0.054615
#
#    progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# 0     -0.222308   0.012308    0.130769   0.147692        -0.010000
# 1      0.266154   0.676923    0.080000   0.447692         1.215385
# ...

# %%
# 6 
# 14
# 21
# 25

# %%
#2018 - 4
# 1 italy
# 4 france
# 9 northern ireland
# 21 kuwait

#2014 - 4
# 6 mexico
# 14 poland
# 21 northern ireland

#2010 -3 
# 4 england
# 7 cameroon

#2006 - 3 
# 7 netherlands
# 13 saudi arabia

# 2002 - 4 
# 1 france
# 13 mexico
# 20 iran
# 30 south korea

# 1998 - 5 
# 5 spain
# 10 denmark
# 11 mexico
# 19 costa rica

# 1994 - 8
# 9 spain
# 15 mexico
# 23 angola
# 27 trinidad 
# 30 toga
# 31 costa rica
# 32 serbia

# 1990 - 6
# 9 japan
# 10 chile
# 14 mexico
# 20 south africa
# 32 north koreaf

# 1986 - 6
# 9 chile
# 13 greece
# 14 algeria
# 23 spain
# 31 honduras

# 1982 - 5
# 5 uruguay
# 10 spain
# 15 japan
# 23 germany

# missing 48 values
