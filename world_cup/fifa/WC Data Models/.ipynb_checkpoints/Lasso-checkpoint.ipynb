# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
df = pd.read_csv('wc-wo-outliers.csv')

# %%
df2 = pd.read_csv('wc-w-outliers.csv')

# %%
df
# Out:
#       goals_z      xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0    0.423077  0.146923  -0.136154     -0.030000  0.429231      0.037692
# 1    0.245385  0.097692   0.549231      0.490000  0.090769      0.071538
# 2    0.337692  0.270000   0.292308      0.281538  0.065385     -0.142308
# 3    0.673077  0.642308   0.502308      0.277692  0.310000      0.146923
# 4    0.114615  0.155385   0.271538      0.330769 -0.015385      0.028462
# ..        ...       ...        ...           ...       ...           ...
# 169 -0.193846  0.228462  -0.313846     -0.167692 -0.563077     -0.534615
# 170 -0.080769 -0.243846  -0.133846     -0.276154  0.096154      0.124615
# 171 -0.066923 -0.147692   0.028462     -0.050000 -0.076154      0.314615
# 172 -0.066154 -0.143846  -0.150769      0.256154  0.185385      0.366923
# 173 -0.193846 -0.290769  -0.075385     -0.372308 -0.380000     -0.211538
#
#      takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  \
# 0     0.244615   -0.220000   0.216154         0.270000     -0.076923
# 1    -0.473077   -0.150769   0.096923         0.277692     -0.153077
# 2    -0.076923    0.430000   0.688462         0.002308      0.020769
# 3     0.153077    0.081538   0.814615         0.464615     -0.150769
# 4     0.128462    0.109231   0.130769         0.056923     -0.232308
# ..         ...         ...        ...              ...           ...
# 169   0.062308   -0.100769  -0.315385        -0.446923     -0.064615
# 170  -0.200769    0.102308   0.060000        -0.073077      0.062308
# 171  -0.224615    0.122308  -0.207692         0.190769      0.413846
# 172  -0.002308    0.240000   0.542308         0.206154      0.380769
# 173  -0.340000   -0.636923  -0.611538        -0.588462      0.342308
#
#      blocks_z  aerials_z   fouls_z  fouled_z    nsxg_z  results
# 0   -0.097692  -0.020000 -0.224615  0.100769 -0.124615        2
# 1   -0.212308   0.033846 -0.145385 -0.036154  0.487692        7
# 2    0.165385  -0.075385  0.193077  0.087692  0.393846        5
# 3   -0.007692  -0.060769 -0.220000  0.006154  0.387692        1
# 4   -0.146923  -0.023077  0.078462  0.532308  0.140769        2
# ..        ...        ...       ...       ...       ...      ...
# 169 -0.349231  -0.193077 -0.331538 -0.135385 -0.362308       19
# 170 -0.343077  -0.007692 -0.325385 -0.152308 -0.331538       18
# 171 -0.044615  -0.035385 -0.173846 -0.323846 -0.006923       31
# 172  0.153077   0.009231 -0.100769  0.133077 -0.080769       20
# 173 -0.099231   0.266154 -0.360000 -0.209231 -0.310000       23
#
# [174 rows x 17 columns]

# %%
y2 = df2['results']
X2 = df2.drop(columns=['results'])

X_train2, X_test2, y_train2, y_test2 = train_test_split(
     X2, y2, test_size=0.20, random_state=1)

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.20, random_state=1)

# %%
from sklearn import linear_model

# %%
model_lasso = linear_model.Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)

# %%
model_lasso2 = linear_model.Lasso(alpha=0.01)
model_lasso2.fit(X_train2, y_train2) 
pred_train_lasso2= model_lasso2.predict(X_train2)
pred_test_lasso2= model_lasso2.predict(X_test2)

# %%
print('LASSO REGRESSION')
print('--------------------')
print('RMSE: '+str(np.sqrt(mean_squared_error(y_test2,pred_test_lasso2))))
print('R Squared: '+str(r2_score(y_test2, pred_test_lasso2)))
print('MSE: '+str(mean_squared_error(y_test2, pred_test_lasso2)))
print('MAE: '+str(mean_absolute_error(y_test2, pred_test_lasso2)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test2, pred_test_lasso2)))

print('--------------------')
pred_test_lasso= model_lasso.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test,pred_test_lasso)))) 
print('R Squared: '+str(r2_score(y_test, pred_test_lasso)))
print('MSE: '+str(mean_squared_error(y_test, pred_test_lasso)))
print('MAE: '+str(mean_absolute_error(y_test, pred_test_lasso)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, pred_test_lasso)))
# Out:
# LASSO REGRESSION
# --------------------
# RMSE: 6.440499189804283
# R Squared: 0.39797133225894255
# MSE: 41.48002981386963
# MAE: 5.237632171642442
# MAPE: 0.924987942704798
# --------------------
# RMSE: 8.323604903542176
# R Squared: 0.18850574385594254
# MSE: 69.28239859027136
# MAE: 6.959318178191603
# MAPE: 1.7667579305863281
