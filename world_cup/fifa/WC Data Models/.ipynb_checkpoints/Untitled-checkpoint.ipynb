# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('WC-new.csv')

# %%
df
# Out:
#        country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 0      Senegal  0.193077  0.087692  -0.180000      0.045385 -0.492308
# 1      Belgium  0.199231  0.210769   0.180769      0.360000 -0.336154
# 2      England  0.176154  0.186154   0.086154      0.163846  0.218462
# 3        Italy  0.153077  0.197692   0.030000      0.088462 -0.665385
# 4    Argentina -0.085385  0.673846   0.561538      0.820000  0.390000
# ..         ...       ...       ...        ...           ...       ...
# 252      Saudi -0.103077  0.056154  -0.315385     -0.459231 -0.072308
# 253     Norway  0.053846  0.193846   0.556154      0.261538 -0.200769
# 254    Belgium  0.055385 -0.119231  -0.020769      0.236154 -0.781538
# 255      Italy  0.293846  0.176154  -0.355385     -0.112308 -0.164615
# 256     Brazil  0.423077  0.146923  -0.136154     -0.030000  0.429231
#
#      progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# ...

# %%
df['year'].value_counts()
# Out:
# 10    30
# 14    30
# 18    29
# 2     28
# 98    28
# 6     25
# 90    24
# 82    23
# 86    20
# 94    20
# Name: year, dtype: int64

# %%
wc1994 = df[df['year'] == 94]

# %%
wc1994 = wc1994.sort_values('results')

# %%
wc1994
# Out:
#          country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 225       Brazil  0.216923  0.348462   0.031538      0.158462  0.835385
# 222        Italy  0.032308 -0.028462   0.046154      0.052308 -0.147692
# 224     Bulgaria  0.162308  0.212308  -0.172308     -0.227692 -0.071538
# 221      Germany  0.337692  0.270000   0.292308      0.281538  0.065385
# 228      Romania  0.368462 -0.026923  -0.383846     -0.043077  0.126154
# 211        Spain  0.417692  0.250000   0.259231      0.076154 -0.371538
# 220      Nigeria  0.263077  0.121538   0.236923      0.107692 -0.123077
# 223    Argentina  0.420000  0.659231   0.472308      0.616923  0.452308
# 218      Belgium  0.015385  0.321538   0.681538      0.588462  0.288462
# 213        Saudi  0.116923  0.238462  -0.021538     -0.071538 -0.500769
# 217          USA -0.186923 -0.232308  -0.103846     -0.253846 -0.220769
# 215  Switzerland  0.116923  0.051538   0.350000      0.203846  0.052308
# ...

# %% [markdown]
# # 1994
#  sweden num 3
#  netherlands num 7
#  13 mexico
#  south korea 20

# %%
wc1986 = df[df['year'] == 86]

# %%
wc1986 = wc1986.sort_values('results')

# %%
wc1986
# Out:
#        country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 180  Argentina  0.536154  0.170769   0.166154      0.190769 -0.167692
# 165    Germany  0.114615  0.155385   0.271538      0.330769 -0.015385
# 174     France  0.332308  0.362308  -0.043846      0.316923  0.060000
# 172    Belgium  0.303846 -0.037692   0.040000     -0.090000 -0.385385
# 175     Brazil  0.479231  0.609231   0.227692      0.450769  0.770769
# 171      Spain  0.566154  0.463077   0.130000      0.464615 -0.154615
# 166    England  0.258462  0.175385   0.285385      0.583077 -0.080000
# 176    Denmark  0.766923  0.643846  -0.265385      0.230000  0.353077
# 168     Russia  0.786154  0.946923   0.149231      0.242308 -0.258462
# 177    Morocco -0.043077 -0.164615  -0.090000     -0.200000  1.063077
# 178      Italy  0.073077  0.299231   0.304615      0.240000  0.406923
# 173   Paraguay  0.073077  0.086154  -0.002308      0.140000  0.296154
# ...

# %% [markdown]
# ## 1986
# number 6 mexico
# 14 is poland
# 20 south korea
# 21 northern ireland

# %%
wc1982 = df[df['year'] == 82]

# %%
wc1982 = wc1982.sort_values('results')

# %%
wc1982
# Out:
#             country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 145          France  0.500769  0.257692   0.080769      0.139231  0.031538
# 152           Italy  0.286154  0.069231   0.013846     -0.040000 -0.095385
# 147         Germany  0.250769  0.222308   0.003077      0.405385 -0.270000
# 160          Poland  0.220000  0.028462   0.177692      0.112308 -0.393077
# 149          Brazil  0.877692  0.773846   0.428462      0.659231  0.754615
# 155         England -0.040769  0.086154   0.800000      0.509231  0.105385
# 146          Russia  0.140769 -0.060769   0.028462      0.078462  0.086923
# 142         Austria -0.041538 -0.217692  -0.228462     -0.214615 -0.070000
# 144         Belgium -0.225385 -0.005385  -0.228462      0.187692 -0.058462
# 162       Argentina  0.234615  0.405385   0.200769      0.554615  0.370769
# 158           Spain -0.133846  0.256154   0.170769      0.283077  0.134615
# ...

# %% [markdown]
# # 1982
# france should be 4th and not 1st
# num 22 is duplicate
# number 9 is northern ireland
# kuwait is 21
# chilie is 22

# %% [markdown]
# # 2006

# %%
wc2006 = df[df['year'] == 6]
wc2006 = wc2006.sort_values('results')

# %%
wc2006
# Out:
#           country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 52          Italy  0.484615  0.213077  -0.103846      0.202308 -0.116154
# 37         France  0.288462  0.370769   0.124615      0.288462  0.166154
# 36        Germany  0.560000  0.225385   0.015385      0.206923  0.061538
# 35       Portugal  0.130000  0.343846  -0.145385     -0.004615  0.040769
# 47         Brazil  0.619231  0.383846   0.065385      0.277692  0.701538
# 28      Argentina  0.700000 -0.006923  -0.137692     -0.071538  0.443077
# 44        England  0.122308  0.330000   0.343077      0.552308 -0.055385
# 34         Ukrain  0.122308  0.143846  -0.026923     -0.242308 -0.064615
# 48          Spain  0.881538  1.015385   0.637692      0.533077  0.500769
# 49    Switzerland  0.113077  0.003846  -0.050000     -0.033077  0.225385
# 46    Netherlands  0.013846  0.156923  -0.199231      0.152308  0.206154
# 32        Ecuador  0.303077  0.085385   0.030000     -0.054615  0.348462
# ...

# %% [markdown]
# ## 2006 should be 32 teams
# missing 9, 14, 15, 17, 27, 30-32
# two 23's - spain should be 9 and not 23
# 14 - sweden
# 15 - mexico
# 17 - south korea
# 27 - trindad and tobego
# 30 - togo
# 31 - costa rica
# 32 - serbia montenegro

# %% [markdown]
# # 2002

# %%
wc2002 = df[df['year'] == 2]
wc2002 = wc2002.sort_values('results')

# %%
wc2002
# Out:
#         country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 20       Brazil  0.843846  0.712308   0.016923      0.245385  0.010769
# 27      Germany  0.563077  0.288462   0.093846      0.223846 -0.443846
# 8        Turkey  0.254615 -0.122308   0.118462      0.069231  0.006923
# 23        Spain  0.451538  0.495385  -0.012308      0.182308  0.003077
# 2       England  0.176154  0.186154   0.086154      0.163846  0.218462
# 0       Senegal  0.193077  0.087692  -0.180000      0.045385 -0.492308
# 22          usa  0.176154  0.100769   0.193846      0.226154 -0.153077
# 16        Japan  0.198462 -0.116154  -0.090000     -0.013077  0.193077
# 9       Denmark  0.200000  0.046154  -0.056154      0.129231  0.120769
# 18   RepIreland  0.264615  0.394615  -0.094615      0.217692  0.290769
# 1       Belgium  0.199231  0.210769   0.180769      0.360000 -0.336154
# 3         Italy  0.153077  0.197692   0.030000      0.088462 -0.665385
# ...

# %% [markdown]
# missing 4, 5, - 2 10s, 11, 13, 19,

# %% [markdown]
# 4- south korea
# 5 - spain
# 11 - mexico
# 13 - sweden
# 19 - costa rica

# %% [markdown]
# # 2018

# %%
wc2018 = df[df['year'] == 18]
wc2018 = wc2018.sort_values('results')

# %%
wc2018
# Out:
#          country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 136       France  0.489231  0.231538  -0.124615      0.189231  0.123846
# 122      Croatia  0.520000  0.379231   0.298462      0.375385  0.407692
# 126      Belgium  0.566154  0.560769   0.234615      0.446923  0.162308
# 125      England  0.446923  0.404615   0.126154      0.366923  0.234615
# 120      Uruguay  0.215385  0.316154   0.171538      0.174615  0.030769
# 127       Brazil  0.427692  0.864615   0.352308      1.153077  0.580769
# 115       Russia  0.572308  0.006154  -0.037692      0.076154 -0.416923
# 117     Colombia  0.313077 -0.103077   0.029231     -0.319231 -0.093846
# 130        Spain  0.190769  0.680769   0.319231      0.763077  1.410769
# 119      Denmark -0.053077 -0.192308  -0.136923      0.065385 -0.374615
# 133       Mexico -0.023077  0.194615   0.029231      0.341538  0.273846
# 131     Portugal  0.373846  0.166154   0.297692      0.044615  0.316923
# ...

# %% [markdown]
# 2 - 5's, 7, 10, 15, 19, 23 -2 32s

# %% [markdown]
# 7 - sweden
# 15 - japan
# 19 - south korea

# %% [markdown]
# # 2014

# %%
wc2014 = df[df['year'] == 14]
wc2014 = wc2014.sort_values('results')

# %%
wc2014
# Out:
#          country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 107      Germany  0.755385  0.614615   0.071538      0.436923  0.516923
# 100    Argentina  0.011538  0.152308   0.222308      0.289231  0.224615
# 96   Netherlands  0.493846  0.406923  -0.040769      0.096923  0.100769
# 95        Brazil  0.328462  0.376154   0.029231      0.475385 -0.003846
# 84      Colombia  0.781538  0.256154   0.016923      0.298462 -0.303077
# 97       Belgium  0.137692  0.210000   0.308462      0.536154  0.218462
# 106       France  0.376923  0.747692   0.608462      1.026154  0.353846
# 104    CostaRica  0.016154 -0.177692  -0.170769     -0.148462 -0.267692
# 83         Chile  0.270769 -0.093846  -0.138462      0.101538  0.434615
# 105       Mexico  0.200769 -0.043846   0.200769      0.064615 -0.004615
# 92   Switzerland  0.387692  0.550769   0.022308      0.138462  0.072308
# 112      Uruguay  0.074615  0.129231   0.111538      0.226923 -0.152308
# ...

# %% [markdown]
# 2 - 9s, 13, 2-14s, 23, 27, 31

# %%
# 13 - greece
# 27 - south korea

# %% [markdown]
# # 2010

# %%
wc2010 = df[df['year'] == 10]
wc2010 = wc2010.sort_values('results')

# %%
wc2010
# Out:
#         country   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# 68        Spain  0.180000  0.539231   0.383077      0.868462  1.156923
# 75  Netherlands  0.396923  0.126923  -0.092308      0.162308  0.374615
# 62      Germany  0.816923  0.433846  -0.024615      0.452308  0.194615
# 69      Uruguay  0.396923  0.130769  -0.069231      0.050000 -0.150769
# 71    Argentina  0.450769  0.496154   0.009231      0.553846  0.549231
# 80       Brazil  0.557692  0.186923   0.141538      0.398462  0.779231
# 60        Ghana  0.069231  0.626923  -0.023846      0.263846 -0.171538
# 66     Paraguay -0.100000 -0.140000  -0.302308      0.293846 -0.183077
# 82        Chile -0.000769  0.105385  -0.023846      0.478462 -0.329231
# 70     Portugal  0.531538  0.284615  -0.023846      0.100769  0.078462
# 59          usa  0.214615  0.523077  -0.176154      0.277692 -0.196923
# 67      England -0.000769  0.323077   0.388462      0.424615  0.255385
# ...

# %% [markdown]
# 9 , 2 -10s, 2-14s, 15, 20, 32

# %% [markdown]
# 9 - japan
# 10 - chile
# 14 - mexico
# 15 - south korea
# 20 - south africa
# 32 - north korea

# %%
# 10    30 - 32
# 14    30 - 32
# 18    29 - 32
# 2     28 - 32 
# 98    28 - 32
