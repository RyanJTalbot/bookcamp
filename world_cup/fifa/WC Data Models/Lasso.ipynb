# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
df = pd.read_csv('WC-stats.csv')

# %%
df
# Out:
#       goals_z      xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0    0.423077  0.146923  -0.136154     -0.030000  0.429231      0.037692
# 1    0.216923  0.348462   0.031538      0.158462  0.835385      0.626923
# 2    0.113846  0.392308   0.599231      0.513846  0.833077      0.405385
# 3    0.479231  0.609231   0.227692      0.450769  0.770769      0.042308
# 4    0.877692  0.773846   0.428462      0.659231  0.754615      0.335385
# ..        ...       ...        ...           ...       ...           ...
# 262  0.157692  0.022308   0.170000      0.022308  0.096923      0.046923
# 263  0.157692  0.022308   0.170000      0.022308  0.096923      0.046923
# 264 -0.227692 -0.166923  -0.387692     -0.362308 -0.344615     -0.163846
# 265 -0.063077 -0.180769  -0.305385     -0.201538 -0.146154     -0.009231
# 266 -0.066154  0.300000   0.147692      0.244615 -0.453846      0.003846
#
#      takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  \
# 0     0.244615   -0.220000   0.216154         0.270000     -0.076923
# 1     0.270000    0.266923   1.143846         0.834615     -0.059231
# 2     0.521538    1.139231   1.109231         0.859231      0.084615
# 3     0.337692    0.927692   0.506923         1.015385      0.020769
# 4     0.023077    0.638462   0.493846         0.637692     -0.117692
# ..         ...         ...        ...              ...           ...
# 262  -0.333846    0.280000   0.041538         0.373077     -0.199231
# 263  -0.333846    0.280000   0.041538         0.373077     -0.199231
# 264  -0.155385   -0.520769  -0.423846        -0.303077      0.367692
# 265  -0.426154   -0.299231  -0.556923        -0.299231     -0.013846
# 266   0.029231   -0.213846  -0.634615        -0.443077      0.395385
#
#      blocks_z  aerials_z   fouls_z  fouled_z    nsxg_z  results
# 0   -0.097692  -0.020000 -0.224615  0.100769 -0.124615        2
# 1   -0.134615   0.196923 -0.016923  0.033846  0.146923        1
# 2    0.103077   0.683846  0.213846  0.353846  0.786923        9
# 3    0.381538   0.038462  0.039231  0.022308  0.692308        5
# 4   -0.033846   0.572308 -0.016154 -0.096923  0.890769        5
# ..        ...        ...       ...       ...       ...      ...
# 262 -0.138462  -0.019231  0.062308  0.130000  0.022308       20
# 263 -0.138462  -0.019231  0.062308  0.130000  0.022308       20
# 264 -0.080000   0.397692  0.669231 -0.140769 -0.572308       23
# 265 -0.165385  -0.370769 -0.016154 -0.032308 -0.256923       24
# 266 -0.274615   0.235385  0.013846 -0.226154  0.127692       29
#
# [267 rows x 17 columns]

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.10, random_state=2)

# %%
from sklearn import linear_model

# %%
model_lasso = linear_model.Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)

# %%
print('LASSO REGRESSION')
# print('--------------------')
# print('RMSE: '+str(np.sqrt(mean_squared_error(y_test2,pred_test_lasso2))))
# print('R Squared: '+str(r2_score(y_test2, pred_test_lasso2)))
# print('MSE: '+str(mean_squared_error(y_test2, pred_test_lasso2)))
# print('MAE: '+str(mean_absolute_error(y_test2, pred_test_lasso2)))
# print('MAPE: '+str(mean_absolute_percentage_error(y_test2, pred_test_lasso2)))

print('--------------------')
pred_test_lasso= model_lasso.predict(X_test)

print('RMSE: '+str(np.sqrt(mean_squared_error(y_test,pred_test_lasso)))) 
print('R Squared: '+str(r2_score(y_test, pred_test_lasso)))
print('MSE: '+str(mean_squared_error(y_test, pred_test_lasso)))
print('MAE: '+str(mean_absolute_error(y_test, pred_test_lasso)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, pred_test_lasso)))
# Out:
# LASSO REGRESSION
# --------------------
# RMSE: 5.8398935403116585
# R Squared: 0.5424887576124411
# MSE: 34.10435656217384
# MAE: 4.341317193676123
# MAPE: 0.33875046036969986

# %%
data = {'y_test': y_test, 'y_pred': pred_test_lasso}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)

# %%
new_df['diff'].mean()
# Out:
# 4.341317193676122

# %%
new_df['diff'].median()
# Out:
# 2.6510346460731284
