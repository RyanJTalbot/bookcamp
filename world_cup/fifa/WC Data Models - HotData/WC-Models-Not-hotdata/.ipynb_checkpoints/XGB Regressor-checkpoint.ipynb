# %% [markdown]
# - https://github.com/dmlc/xgboost/tree/master/demo/CLI/regression
# - https://github.com/dmlc/xgboost/tree/master/demo/CLI/binary_classification
# - https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
# - https://github.com/dmlc/xgboost/tree/master/demo
#
#
# - https://github.com/microsoft/FLAML
# - https://github.com/mpearmain/BayesBoost

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn import linear_model

import numpy as np

from scipy.stats import uniform, randint

from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split

import xgboost as xgb

# %%
# df = pd.read_csv('wc-7.csv')
df = pd.read_csv('wc-7-outliers.csv')

# %%
# df = df.drop(columns=[ 'country', 'year'])

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.20, random_state=2)

# %%
 xgb_model = xgb.XGBRegressor(n_estimators=20, learning_rate=.375, gamma=90,
                             max_delta_step=10000)

# %%
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

# %%
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test,y_pred)))) 
print('R2 : '+str(r2_score(y_test, y_pred)))
print('MSE: '+str(mean_squared_error(y_test, y_pred)))
print('MAE: '+str(mean_absolute_error(y_test, y_pred)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, y_pred)))
# Out:
# RMSE : 6.710377170918353
# R2 : 0.4311410941717009
# MSE: 45.02916177598219
# MAE: 5.364691136018285
# MAPE: 0.7090541706071127

# %%
# MAPE: 1.0743911059743543
# n_estimators=1 MAPE: 0.7442140613683098
# learning_rate=.375, MAPE: 0.7413981946339236
# gamma=100  MAPE: 0.7104114259788941


# MAPE: 0.870777396465787

# %%
# RMSE : 0.08422770998768268
# R2 : 0.9999076006231193
# MSE: 0.007094307129769182
# # MAE: 0.008098809854358647
# MAPE: 0.0005870913518544939

# %%
data = {'y_test': y_test, 'y_pred': y_pred}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - new_df['y_pred']).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)

# %%
new_df
# Out:
#      y_test     y_pred       diff
# 74        4   3.395215   0.604785
# 231      14  12.959924   1.040076
# 54       17  15.925918   1.074082
# 89        9   7.745007   1.254993
# 113      11  12.296996   1.296996
# 112      30  28.307552   1.692448
# 35       11   9.065583   1.934417
# 191      12  10.031682   1.968318
# 66       26  23.857885   2.142115
# 118      28  25.765676   2.234324
# 23       23  20.601147   2.398853
# 243      10  12.421927   2.421927
# 274      16  18.660896   2.660896
# 101      11  13.937303   2.937303
# 7        10   6.964362   3.035638
# 127      24  27.214851   3.214851
# 13       29  25.658447   3.341553
# 212      18  21.376589   3.376589
# 217      18  21.591776   3.591776
# 65       31  27.210875   3.789125
# 270      18  14.209399   3.790601
# 128      22  18.095018   3.904982
# 227      10  14.152677   4.152677
# 153      13  17.189873   4.189873
# 175      16  11.439288   4.560712
# 131       3   7.832283   4.832283
# 215       9  13.985129   4.985129
# 10       29  23.973366   5.026634
# 99       16  21.195625   5.195625
# 3        25  19.121855   5.878145
# 155       5  10.883063   5.883063
# 141      30  23.625549   6.374451
# 134      13   6.413689   6.586311
# 251      12  18.631317   6.631317
# 29        3   9.801354   6.801354
# 142       4  11.016133   7.016133
# 157      15  22.056633   7.056633
# 266      21  13.911521   7.088479
# 98       17  24.103872   7.103872
# 250       1   8.909976   7.909976
# 181       1   9.197171   8.197171
# 53       18   8.729331   9.270669
# 11        7  16.302189   9.302189
# 133      22  12.648604   9.351396
# 77        6  15.692319   9.692319
# 85       31  20.634581  10.365419
# 252      24  13.504249  10.495751
# 173       2  12.657132  10.657132
# 93        2  12.869456  10.869456
# 4        28  17.089451  10.910549
# 115       8  19.884451  11.884451
# 120       9  21.209166  12.209166
# 152      24  11.580869  12.419131
# 245       6  19.637993  13.637993
# 30       27  11.591842  15.408158
# 84       21   5.545702  15.454298
# 176      25   8.850121  16.149879

# %%
new_df['diff'].mean()
# Out:
# 6.267621809976143

# %%
new_df['diff'].median()
# Out:
# 5.195625305175781
