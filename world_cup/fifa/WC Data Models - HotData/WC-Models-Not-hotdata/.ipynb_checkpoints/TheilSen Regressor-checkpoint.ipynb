# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.linear_model import TheilSenRegressor

# %%
df = pd.read_csv('wc-7-outliers.csv')


# df = pd.read_csv('wc-7.csv')
# # df = pd.read_csv('outliers245.csv')
# df = pd.read_csv('outliers205.csv')
# df = pd.read_csv('outliers235.csv')

# df = pd.read_csv('prev_champs.csv')
# df = pd.read_csv('outliers_champs.csv')

# %%
# df = df.drop(columns=[ 'country'])

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.10, random_state=2)

# %%
df
# Out:
#         goals        xg   crosses  boxtouches    passes  progpasses   takeons  \
# 0   -0.410000  0.329231  0.606923    0.713846  0.467692   -0.033077  0.140769
# 1    0.553077  0.411538 -0.104615    0.026923 -0.352308   -0.238462 -0.254615
# 2    0.493846  0.406923 -0.040769    0.096923  0.100769   -0.169231  0.306154
# 3   -0.255385 -0.186923 -0.104615   -0.193846 -0.077692   -0.091538 -0.092308
# 4   -0.093077  0.301538  0.040769    0.026154  0.253077   -0.100769  0.447692
# ..        ...       ...       ...         ...       ...         ...       ...
# 258 -0.093077 -0.067692  0.272308    0.108462  0.023077    0.133846 -0.214615
# 259  0.877692  0.773846  0.428462    0.659231  0.754615    0.335385  0.023077
# 260 -0.063077 -0.180769 -0.305385   -0.201538 -0.146154   -0.009231 -0.426154
# 261  0.463846  0.343077  0.029231   -0.026154  0.173077    0.200769  0.092308
# 262 -0.400000 -0.104615  0.471538   -0.059231  0.270000    0.046154 -0.040000
#
# ...

# %%
# X_train = X.iloc[60:]

# %%
# X_train2 = X.iloc[:60]

# %%
# X_train = X_train2.append(X_train1)

# %%
# X_train

# %%
# X_test = X.iloc[:60]

# %%
# y_train = y.iloc[60:]

# %%
# y_train2 = y.iloc[:60]

# %%
# y_train = y_train2.append(y_train1)

# %%
# y_test = y.iloc[:60]

# %%
reg = TheilSenRegressor(tol=.000001)

# %%
reg.fit(X_train, y_train)
# Out:
# TheilSenRegressor(tol=1e-06)

# %%
pred_test= reg.predict(X_test)

# %%
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test,pred_test)))) 
print('R2 : '+str(r2_score(y_test, pred_test)))
print('MSE: '+str(mean_squared_error(y_test, pred_test)))
print('MAE: '+str(mean_absolute_error(y_test, pred_test)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, pred_test)))
# Out:
# RMSE : 6.675547084373772
# R2 : 0.37667648124680797
# MSE: 44.56292887569116
# MAE: 5.130904372773536
# MAPE: 0.49854815053851703

# %%
# MAPE: 0.7115513775307271
# MAPE: 0.614553083168057 w date

# MAPE: 0.5112052614107516

# %%
data = {'y_test': y_test, 'y_pred': pred_test}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - (new_df['y_pred'])).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)

# %%
new_df
# Out:
#      y_test     y_pred       diff
# 106      16  15.618174   0.381826
# 180      12  12.475581   0.475581
# 133       9   8.460177   0.539823
# 91        9   9.924759   0.924759
# 139      24  24.999942   0.999942
# 140      14  12.896323   1.103677
# 233      18  16.825967   1.174033
# 104      23  24.399897   1.399897
# 169      21  19.340178   1.659822
# 35       10   8.057706   1.942294
# 238      15  17.890033   2.890033
# 94       25  21.631676   3.368324
# 65       12  15.756333   3.756333
# 10       27  22.917049   4.082951
# 3        21  16.647766   4.352234
# 131       2   6.468628   4.468628
# 84       20  15.247370   4.752630
# 189       4   9.616876   5.616876
# 176       2   8.150931   6.150931
# 98       31  21.936554   9.063446
# 224      23  13.309963   9.690037
# 241      31  20.918393  10.081607
# 54       28  17.866505  10.133495
# 210       7  17.325140  10.325140
# 85       24  12.479026  11.520974
# 30       15   2.812624  12.187376
# ...

# %%
# y0_59 = new_df

# %%
new_df['diff'].mean()
# Out:
# 5.130904372773535

# %%
new_df['diff'].median()
# Out:
# 4.082950741376848

# %%
new_y4 = y200_262['y_pred']

# %%
new_y3 = y130_199['y_pred']

# %%
new_y2 = y60_129['y_pred']

# %%
new_y1 = y0_59['y_pred']

# %%
new_y = new_y1.append(new_y2)

# %%
new_y
# Out:
# 0      29.430477
# 1       2.310650
# 2       9.545702
# 3      14.952712
# 4      24.792431
#          ...
# 125    18.900784
# 126    14.847219
# 127    14.646112
# 128    12.490582
# 129    19.286592
# Name: y_pred, Length: 130, dtype: float64

# %%
new_y = new_y.append(new_y3)

# %%
new_y = new_y.append(new_y4)

# %%
new_y
# Out:
# 0      29.430477
# 1       2.310650
# 2       9.545702
# 3      14.952712
# 4      24.792431
#          ...
# 258    16.553711
# 259    -4.361641
# 260    18.597028
# 261     8.284043
# 262    27.631706
# Name: y_pred, Length: 263, dtype: float64

# %%
df['predz'] = new_y

# %%
df
# Out:
#         goals        xg   crosses  boxtouches    passes  progpasses   takeons  \
# 0   -0.410000  0.329231  0.606923    0.713846  0.467692   -0.033077  0.140769
# 1    0.553077  0.411538 -0.104615    0.026923 -0.352308   -0.238462 -0.254615
# 2    0.493846  0.406923 -0.040769    0.096923  0.100769   -0.169231  0.306154
# 3   -0.255385 -0.186923 -0.104615   -0.193846 -0.077692   -0.091538 -0.092308
# 4   -0.093077  0.301538  0.040769    0.026154  0.253077   -0.100769  0.447692
# ..        ...       ...       ...         ...       ...         ...       ...
# 258 -0.093077 -0.067692  0.272308    0.108462  0.023077    0.133846 -0.214615
# 259  0.877692  0.773846  0.428462    0.659231  0.754615    0.335385  0.023077
# 260 -0.063077 -0.180769 -0.305385   -0.201538 -0.146154   -0.009231 -0.426154
# 261  0.463846  0.343077  0.029231   -0.026154  0.173077    0.200769  0.092308
# 262 -0.400000 -0.104615  0.471538   -0.059231  0.270000    0.046154 -0.040000
#
# ...

# %%
df.corr()
# Out:
#                   goals        xg   crosses  boxtouches    passes  progpasses  \
# goals          1.000000  0.625420  0.114044    0.396976  0.262943    0.125643
# xg             0.625420  1.000000  0.373451    0.649700  0.310607    0.177050
# crosses        0.114044  0.373451  1.000000    0.641517  0.270523    0.361813
# boxtouches     0.396976  0.649700  0.641517    1.000000  0.341180    0.303466
# passes         0.262943  0.310607  0.270523    0.341180  1.000000    0.722068
# progpasses     0.125643  0.177050  0.361813    0.303466  0.722068    1.000000
# takeons        0.233713  0.266835  0.113207    0.171188  0.376856    0.155418
# progruns       0.239816  0.374909  0.269198    0.343823  0.602215    0.341634
# tackles        0.267671  0.347536  0.235787    0.369985  0.742389    0.479059
# interceptions  0.220964  0.276119  0.251521    0.292302  0.717357    0.500943
# clearances    -0.207952 -0.347021 -0.247883   -0.412085 -0.153410   -0.063770
# ...

# %%
y = df['results']
X = df.drop(columns=['results'])

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.15, random_state=2)

# %%
reg = TheilSenRegressor(tol=.000001)

# %%
reg.fit(X_train, y_train)
# Out:
# TheilSenRegressor(tol=1e-06)

# %%
pred_test= reg.predict(X_test)

# %%
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test,pred_test)))) 
print('R2 : '+str(r2_score(y_test, pred_test)))
print('MSE: '+str(mean_squared_error(y_test, pred_test)))
print('MAE: '+str(mean_absolute_error(y_test, pred_test)))
print('MAPE: '+str(mean_absolute_percentage_error(y_test, pred_test)))
# Out:
# RMSE : 5.789571926597966
# R2 : 0.5765077981569496
# MSE: 33.51914309325129
# MAE: 4.612961454926803
# MAPE: 0.5390365620337095

# %%
data = {'y_test': y_test, 'y_pred': pred_test}
new_df = pd.DataFrame(data)
diff = (new_df['y_test'] - (new_df['y_pred'])).abs()
new_df['diff'] = diff
new_df = new_df.sort_values(by='diff', ascending=True)
new_df
# Out:
#      y_test     y_pred       diff
# 233      18  17.948944   0.051056
# 106      16  16.064909   0.064909
# 113       4   3.640896   0.359104
# 94       25  24.570613   0.429387
# 133       9   8.332100   0.667900
# 120      21  21.738280   0.738280
# 242      12  13.287506   1.287506
# 139      24  25.297994   1.297994
# 91        9   7.637855   1.362145
# 140      14  12.429613   1.570387
# 3        21  22.771187   1.771187
# 24       17  18.780230   1.780230
# 238      15  17.088922   2.088922
# 144       1   3.089168   2.089168
# 10       27  24.527494   2.472506
# 41       32  29.514885   2.485115
# 35       10  13.145004   3.145004
# 169      21  17.599615   3.400385
# 227      10  13.529405   3.529405
# 65       12  15.957318   3.957318
# 104      23  27.276713   4.276713
# 84       20  15.140076   4.859924
# 180      12   6.972427   5.027573
# 131       2   7.163494   5.163494
# 182      20  14.736860   5.263140
# 98       31  25.237339   5.762661
# ...

# %%
new_df['diff'].mean()
# Out:
# 4.612961454926804

# %%
new_df['diff'].median()
# Out:
# 4.117015741562216
