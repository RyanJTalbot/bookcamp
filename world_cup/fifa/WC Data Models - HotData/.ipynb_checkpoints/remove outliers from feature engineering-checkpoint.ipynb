# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('features.csv')

# %%
df
# Out:
#         goals        xg   crosses  boxtouches    passes  progpasses   takeons  \
# 0   -0.040769 -0.080000  0.228462    0.070000  0.129231   -0.080000  0.228462
# 1   -0.247692 -0.058462  0.023077   -0.005385 -0.083077   -0.176154  0.573846
# 2    0.055385  0.266154  0.076923    0.214615  0.210000    0.326923 -0.112308
# 3    0.781538  0.256154  0.016923    0.298462 -0.303077   -0.243846  0.117692
# 4    0.472308  0.458462 -0.023846    0.078462  0.416923    0.273846  0.693077
# ..        ...       ...       ...         ...       ...         ...       ...
# 275 -0.093077 -0.197692 -0.366923   -0.434615  0.531538    0.181538 -0.248462
# 276  0.689231  0.773846 -0.020769    0.551538 -0.054615   -0.101538 -0.112308
# 277  0.243846  0.064615  0.097692    0.312308  0.330769    0.399231  0.216154
# 278 -0.040769  0.086154  0.800000    0.509231  0.105385    0.273077 -0.303846
# 279  0.264615  0.005385 -0.148462   -0.049231 -0.178462   -0.246923 -0.060000
#
# ...

# %%
new_df = df[(np.abs(stats.zscore(df)) < 15).all(axis=1)]

# %%
new_df.shape
# Out:
# (260, 96)

# %%
df.shape
# Out:
# (280, 96)

# %%
# new_df.to_csv('feature-outliers.csv', index=False)
