# %%
import numpy as np 
import pandas as pd

# %%
df = pd.concat(map(pd.read_csv, ['Brazil.csv', 'germany.csv','germany1.csv', 
                                 'Portugal1.csv', 'Spain1.csv', 'Switzerland.csv',
                                'Switzerland1.csv', 'France1.csv',
                                'Brazil1.csv', 'Netherlands.csv', 
                                'Belgium.csv', 'USA.csv', 'England.csv',
                                'Argentina.csv', 'Uruguay.csv', 
                                'Senegal.csv', 'Ecuador.csv', 'CostaRica.csv',
                                'Mexico.csv', 'France.csv', 'Denmark.csv',
                                'Australia.csv', 'Serbia.csv',
                                'Cameroon.csv', 'Ghana.csv', 'Iran.csv',
                                'Poland.csv', 'SaudI.csv', 'Tunisia.csv', 
                                 'Japan.csv', 'Croatia.csv', 'Morocco.csv',
                                'USA1.csv', 'Spain2.csv', 'Portugal2.csv', 
                                 'England2.csv', 'Belgium2.csv', 'Uruguay2.csv',
                                'Canada2.csv', 'Netherlands2.csv', 'Saudi2.csv', 
                                'Croatia2.csv', 'Cameroon2.csv', 'Denmark2.csv',
                                'Costa2.csv', 'Morocco2.csv', 'Poland2.csv',
                                'Tunisia2.csv', 'Japan2.csv', 'Argentina2.csv', 
                                 'Italy.csv', 'South_Korea.csv', 'Nigeria.csv',
                                'Colombia.csv', 'Paraguay.csv', 'Russia.csv',
                                'Algeria.csv', 'Chile.csv', 'Yugoslavia.csv',
                                'Scotland.csv', 'Romania.csv', 'Greece.csv',
                                'Honduras.csv', 'Austria.csv', 'Bulgaria.csv', 
                                 'IvoryCoast.csv', 'SouthAfrica.csv', 'RepIreland.csv',
                                'Slovenia.csv', 'Czechoslovakia.csv', 'Hungary.csv', 
                                'Egypt.csv', 'Norway.csv', 'Peru.csv',
                                'NewZealand.csv', 'Bosnia.csv', 'Panama.csv',
                                'Slovakia.csv', 'Iraq.csv', 'Jamaica.csv',
                                'Kuwait.csv', 'ElSalvador.csv', 'China.csv',
                                'Turkey.csv', 'Ukraine.csv', 'Bolivia.csv',
                                'Togo.csv', 'Togo.csv', 'Angola.csv', 'UAE.csv',
                                'Iceland.csv']))

# %%
# 158 with wc 2022 teams

# %%
df.shape
# Out:
# (267, 17)

# %%
df.duplicated().value_counts()
# Out:
# False    266
# True       1
# dtype: int64

# %%
df.corr()
# Out:
#                   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# goals_z          1.000000  0.639568   0.166928      0.406111  0.230525
# xg_z             0.639568  1.000000   0.433587      0.686752  0.329133
# crosses_z        0.166928  0.433587   1.000000      0.662592  0.274843
# boxtouches_z     0.406111  0.686752   0.662592      1.000000  0.385978
# passes_z         0.230525  0.329133   0.274843      0.385978  1.000000
# progpasses_z     0.088854  0.138992   0.300370      0.270085  0.742110
# takeons_z        0.289264  0.374156   0.166082      0.268009  0.398209
# progruns_z       0.241184  0.399911   0.298221      0.411440  0.592065
# tackles_z        0.262722  0.372845   0.259580      0.415036  0.743680
# interceptions_z  0.216164  0.294246   0.255157      0.309215  0.753684
# clearances_z    -0.224414 -0.390361  -0.281629     -0.419816 -0.134985
# blocks_z         0.067254  0.072775   0.047456      0.140099  0.393957
# aerials_z        0.061315  0.074259   0.238542      0.249719 -0.018648
# fouls_z         -0.054383  0.007858   0.078250      0.053504  0.079781
# fouled_z         0.091313  0.207780   0.189823      0.208027  0.319349
# nsxg_z           0.433447  0.674233   0.709194      0.870254  0.485282
# results         -0.621953 -0.349917  -0.055461     -0.251891 -0.176865
#
#                  progpasses_z  takeons_z  progruns_z  tackles_z  \
# goals_z              0.088854   0.289264    0.241184   0.262722
# xg_z                 0.138992   0.374156    0.399911   0.372845
# crosses_z            0.300370   0.166082    0.298221   0.259580
# boxtouches_z         0.270085   0.268009    0.411440   0.415036
# passes_z             0.742110   0.398209    0.592065   0.743680
# progpasses_z         1.000000   0.160717    0.330435   0.500588
# takeons_z            0.160717   1.000000    0.540931   0.401089
# progruns_z           0.330435   0.540931    1.000000   0.536689
# tackles_z            0.500588   0.401089    0.536689   1.000000
# interceptions_z      0.564228   0.383485    0.443333   0.708418
# clearances_z        -0.015846  -0.114159   -0.130345  -0.241163
# blocks_z             0.345354   0.190246    0.271621   0.283512
# aerials_z            0.046185  -0.113582   -0.076640   0.020177
# fouls_z              0.219871   0.128103    0.023590   0.019976
# fouled_z             0.203170   0.322325    0.277446   0.313497
# nsxg_z               0.382849   0.402196    0.484559   0.483442
# results             -0.052698  -0.196540   -0.227683  -0.225892
#
#                  interceptions_z  clearances_z  blocks_z  aerials_z   fouls_z  \
# goals_z                 0.216164     -0.224414  0.067254   0.061315 -0.054383
# xg_z                    0.294246     -0.390361  0.072775   0.074259  0.007858
# crosses_z               0.255157     -0.281629  0.047456   0.238542  0.078250
# boxtouches_z            0.309215     -0.419816  0.140099   0.249719  0.053504
# passes_z                0.753684     -0.134985  0.393957  -0.018648  0.079781
# progpasses_z            0.564228     -0.015846  0.345354   0.046185  0.219871
# takeons_z               0.383485     -0.114159  0.190246  -0.113582  0.128103
# progruns_z              0.443333     -0.130345  0.271621  -0.076640  0.023590
# tackles_z               0.708418     -0.241163  0.283512   0.020177  0.019976
# interceptions_z         1.000000     -0.147478  0.319499  -0.001498  0.143454
# clearances_z           -0.147478      1.000000  0.189532   0.277875  0.218165
# blocks_z                0.319499      0.189532  1.000000   0.026884  0.192848
# aerials_z              -0.001498      0.277875  0.026884   1.000000  0.155366
# fouls_z                 0.143454      0.218165  0.192848   0.155366  1.000000
# fouled_z                0.323127      0.011252  0.082935   0.022347  0.263966
# nsxg_z                  0.422123     -0.414364  0.168225   0.183427  0.103316
# results                -0.146282      0.127996 -0.087698  -0.072166  0.069473
#
#                  fouled_z    nsxg_z   results
# goals_z          0.091313  0.433447 -0.621953
# xg_z             0.207780  0.674233 -0.349917
# crosses_z        0.189823  0.709194 -0.055461
# boxtouches_z     0.208027  0.870254 -0.251891
# passes_z         0.319349  0.485282 -0.176865
# progpasses_z     0.203170  0.382849 -0.052698
# takeons_z        0.322325  0.402196 -0.196540
# progruns_z       0.277446  0.484559 -0.227683
# tackles_z        0.313497  0.483442 -0.225892
# interceptions_z  0.323127  0.422123 -0.146282
# clearances_z     0.011252 -0.414364  0.127996
# blocks_z         0.082935  0.168225 -0.087698
# aerials_z        0.022347  0.183427 -0.072166
# fouls_z          0.263966  0.103316  0.069473
# fouled_z         1.000000  0.283524 -0.142205
# nsxg_z           0.283524  1.000000 -0.273887
# results         -0.142205 -0.273887  1.000000

# %% [markdown]
# # convert to csv

# %%
df.to_csv('./WC Data Models/WC-stats.csv', index=False)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# %%
df.head()
# Out:
#     goals_z      xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0  0.423077  0.146923  -0.136154     -0.030000  0.429231      0.037692
# 1  0.216923  0.348462   0.031538      0.158462  0.835385      0.626923
# 2  0.113846  0.392308   0.599231      0.513846  0.833077      0.405385
# 3  0.479231  0.609231   0.227692      0.450769  0.770769      0.042308
# 4  0.877692  0.773846   0.428462      0.659231  0.754615      0.335385
#
#    takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  blocks_z  \
# 0   0.244615   -0.220000   0.216154         0.270000     -0.076923 -0.097692
# 1   0.270000    0.266923   1.143846         0.834615     -0.059231 -0.134615
# 2   0.521538    1.139231   1.109231         0.859231      0.084615  0.103077
# 3   0.337692    0.927692   0.506923         1.015385      0.020769  0.381538
# 4   0.023077    0.638462   0.493846         0.637692     -0.117692 -0.033846
#
#    aerials_z   fouls_z  fouled_z    nsxg_z  results
# 0  -0.020000 -0.224615  0.100769 -0.124615        2
# 1   0.196923 -0.016923  0.033846  0.146923        1
# 2   0.683846  0.213846  0.353846  0.786923        9
# 3   0.038462  0.039231  0.022308  0.692308        5
# 4   0.572308 -0.016154 -0.096923  0.890769        5

# %%
y = df['results']

# %%
X = df.drop(columns=['results'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.20, random_state=42)

# %%
model = Ridge(alpha=1e-2).fit(X_train, y_train)
model.score(X, y)
# Out:
# 0.4012771300488499

# %%
r = permutation_importance(model, X, y, n_repeats=30, random_state=0)

# %% [markdown]
# # Permutation feature importance

# %%
scoring = ['r2', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error']
r_multi = permutation_importance(
     model, X, y, n_repeats=30, random_state=0, scoring=scoring)

for metric in r_multi:
     print(f"{metric}") 
     r = r_multi[metric]
     for i in r.importances_mean.argsort()[::-1]:
            if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
                print(f"    {X.columns[i]:<8}"
                      f"{r.importances_mean[i]:.3f}"
                      f" +/- {r.importances_std[i]:.3f}")
# Out:
# r2
#     goals_z 0.891 +/- 0.089
#     xg_z    0.056 +/- 0.017
#     fouled_z0.029 +/- 0.011
#     progruns_z0.029 +/- 0.010
#     crosses_z0.012 +/- 0.006
# neg_mean_absolute_percentage_error
#     goals_z 0.659 +/- 0.066
#     fouled_z0.039 +/- 0.016
#     progruns_z0.028 +/- 0.012
#     fouls_z 0.023 +/- 0.011
#     tackles_z0.017 +/- 0.006
# neg_mean_squared_error
#     goals_z 66.643 +/- 6.680
#     xg_z    4.222 +/- 1.289
#     fouled_z2.158 +/- 0.859
#     progruns_z2.150 +/- 0.757
#     crosses_z0.932 +/- 0.433

# %% [markdown]
# - df.shape = (158, 17)
# - Ridge Regression = 0.42629810615686115
# - r2
#     - goals_z 1.282 +/- 0.149
#     - progruns_z0.096 +/- 0.029
#     - xg_z    0.095 +/- 0.030
#     - takeons_z0.026 +/- 0.013
# - neg_mean_absolute_percentage_error
#     - goals_z 0.988 +/- 0.115
# - neg_mean_squared_error
#     - goals_z 108.981 +/- 12.672
#     - progruns_z8.139 +/- 2.494
#     - xg_z    8.047 +/- 2.509
#     - takeons_z2.195 +/- 1.067

# %% [markdown]
# - df.shape = (125, 17)
#
# - Ridge Regression = 0.4494483686544971
#
# - r2
#     - goals_z 0.982 +/- 0.123
#     - progruns_z0.132 +/- 0.039
#     - xg_z    0.056 +/- 0.017
#     - boxtouches_z0.046 +/- 0.023
#     - nsxg_z  0.039 +/- 0.013
#     - aerials_z0.031 +/- 0.014
# - neg_mean_absolute_percentage_error
#     - goals_z 0.888 +/- 0.122
#     - progruns_z0.181 +/- 0.059
# - neg_mean_squared_error
#     - goals_z 89.125 +/- 11.206
#     - progruns_z11.964 +/- 3.505
#     - xg_z    5.055 +/- 1.543
#     - boxtouches_z4.180 +/- 2.062
#     - nsxg_z  3.509 +/- 1.182
#     - aerials_z2.782 +/- 1.244

# %% [markdown]
# - df.shape = (145, 17)
# - Ridge Regression = 0.43985733944194594
#
# - r2
#     - goals_z 0.919 +/- 0.122
#     - progruns_z0.077 +/- 0.028
#     - nsxg_z  0.069 +/- 0.026
#     - boxtouches_z0.034 +/- 0.015
# - neg_mean_absolute_percentage_error
#     - goals_z 0.817 +/- 0.115
#     - progruns_z0.124 +/- 0.036
#     - tackles_z0.060 +/- 0.022
#     - boxtouches_z0.048 +/- 0.023
# - neg_mean_squared_error
#     - goals_z 78.467 +/- 10.375
#     - progruns_z6.549 +/- 2.364
#     - nsxg_z  5.854 +/- 2.186
#     - boxtouches_z2.943 +/- 1.292

# %% [markdown]
# - NMAPE = the higher the better
# - NMSE
# - R2 =  is a statistical measure of how close the data are to the fitted regression line . It is the percentage of variation (from 0 to 1) explained by the relationship between two variables.. metric that is used to evaluate the performance of a regression-based machine learning model.
