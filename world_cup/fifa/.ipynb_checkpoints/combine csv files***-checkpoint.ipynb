# %%
import numpy as np 
import pandas as pd

# %%
df = pd.concat(map(pd.read_csv, ['Brazil.csv', 'germany.csv','germany1.csv', 
                                 'Portugal1.csv', 'Spain1.csv', 'Switzerland.csv',
                                'Switzerland1.csv', 'France1.csv',
                                'Brazil1.csv', 'Netherlands.csv', 
                                'Belgium.csv', 'USA.csv', 'England.csv',
                                'Argentina.csv', 'Uruguay.csv', 
                                'Senegal.csv', 'Ecuador.csv', 'CostaRica.csv',
                                'Mexico.csv', 'France.csv', 'Denmark.csv',
                                'Australia.csv', 'Serbia.csv',
                                'Cameroon.csv', 'Ghana.csv', 'Iran.csv',
                                'Poland.csv', 'SaudI.csv', 'Tunisia.csv', 
                                 'Japan.csv', 'Croatia.csv', 'Morocco.csv',
                                'USA1.csv', 'Spain2.csv', 'Portugal2.csv', 
                                 'England2.csv', 'Belgium2.csv', 'Uruguay2.csv',
                                'Canada2.csv', 'Netherlands2.csv', 'Saudi2.csv', 
                                'Croatia2.csv', 'Cameroon2.csv', 'Denmark2.csv',
                                'Costa2.csv', 'Morocco2.csv', 'Poland2.csv',
                                'Tunisia2.csv', 'Japan2.csv', 'Argentina2.csv', 
                                 'Italy.csv', 'South_Korea.csv', 'Nigeria.csv',
                                'Colombia.csv', 'Paraguay.csv', 'Russia.csv',
                                'Algeria.csv', 'Chile.csv', 'Yugoslavia.csv',
                                'Scotland.csv', 'Romania.csv', 'Greece.csv',
                                'Honduras.csv', 'Austria.csv', 'Bulgaria.csv', 
                                 'IvoryCoast.csv', 'SouthAfrica.csv', 'RepIreland.csv',
                                'Slovenia.csv', 'Czechoslovakia.csv', 'Hungary.csv', 
                                'Egypt.csv', 'Norway.csv', 'Peru.csv',
                                'NewZealand.csv', 'Bosnia.csv', 'Panama.csv',
                                'Slovakia.csv', 'Iraq.csv', 'Jamaica.csv',
                                'Kuwait.csv', 'ElSalvador.csv', 'China.csv',
                                'Turkey.csv', 'Ukraine.csv', 'Bolivia.csv',
                                'Togo.csv', 'Togo.csv', 'Angola.csv', 'UAE.csv',
                                'Iceland.csv']))

# %%
# 158 with wc 2022 teams

# %%
pd.read_csv('Iceland.csv')
# Out:
#   Unnamed: 0   goals_z  xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0  Iceland18 -0.066154   0.3   0.147692      0.244615 -0.453846      0.003846
#
#    takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  blocks_z  \
# 0   0.029231   -0.213846  -0.634615        -0.443077      0.395385 -0.274615
#
#    aerials_z   fouls_z  fouled_z    nsxg_z  results
# 0   0.235385  0.013846 -0.226154  0.127692       29

# %%
df.shape
# Out:
# (267, 18)

# %%
df.duplicated().value_counts()
# Out:
# False    266
# True       1
# dtype: int64

# %%
df.corr()
# Out:
#                   goals_z      xg_z  crosses_z  boxtouches_z  passes_z  \
# goals_z          1.000000  0.640288   0.165163      0.405518  0.229077
# xg_z             0.640288  1.000000   0.433126      0.685425  0.333139
# crosses_z        0.165163  0.433126   1.000000      0.662728  0.277521
# boxtouches_z     0.405518  0.685425   0.662728      1.000000  0.389737
# passes_z         0.229077  0.333139   0.277521      0.389737  1.000000
# progpasses_z     0.087212  0.150208   0.308299      0.281226  0.744277
# takeons_z        0.288423  0.372741   0.166079      0.266736  0.400630
# progruns_z       0.239154  0.404967   0.301806      0.416160  0.592466
# tackles_z        0.261051  0.372192   0.260507      0.414870  0.745846
# interceptions_z  0.212718  0.299976   0.260253      0.314939  0.753462
# clearances_z    -0.226032 -0.384992  -0.278800     -0.415332 -0.138256
# blocks_z         0.067151  0.069467   0.046185      0.137514  0.395875
# aerials_z        0.061521  0.075945   0.238721      0.251299 -0.019567
# fouls_z         -0.054652  0.011334   0.080012      0.056659  0.078886
# fouled_z         0.090182  0.219895   0.197162      0.219019  0.319604
# nsxg_z           0.431246  0.674253   0.709666      0.870559  0.487725
# results         -0.621044 -0.349797  -0.055782     -0.251658 -0.178185
#
#                  progpasses_z  takeons_z  progruns_z  tackles_z  \
# goals_z              0.087212   0.288423    0.239154   0.261051
# xg_z                 0.150208   0.372741    0.404967   0.372192
# crosses_z            0.308299   0.166079    0.301806   0.260507
# boxtouches_z         0.281226   0.266736    0.416160   0.414870
# passes_z             0.744277   0.400630    0.592466   0.745846
# progpasses_z         1.000000   0.168032    0.330777   0.509143
# takeons_z            0.168032   1.000000    0.543944   0.400966
# progruns_z           0.330777   0.543944    1.000000   0.539805
# tackles_z            0.509143   0.400966    0.539805   1.000000
# interceptions_z      0.565356   0.387070    0.444819   0.711707
# clearances_z        -0.027133  -0.109932   -0.134274  -0.238192
# blocks_z             0.352973   0.188674    0.273838   0.282342
# aerials_z            0.043536  -0.112970   -0.077819   0.020533
# fouls_z              0.216750   0.130277    0.022397   0.021731
# fouled_z             0.195099   0.330744    0.277075   0.321368
# nsxg_z               0.391084   0.402163    0.487880   0.484134
# results             -0.056429  -0.196351   -0.229369  -0.226033
#
#                  interceptions_z  clearances_z  blocks_z  aerials_z   fouls_z  \
# goals_z                 0.212718     -0.226032  0.067151   0.061521 -0.054652
# xg_z                    0.299976     -0.384992  0.069467   0.075945  0.011334
# crosses_z               0.260253     -0.278800  0.046185   0.238721  0.080012
# boxtouches_z            0.314939     -0.415332  0.137514   0.251299  0.056659
# passes_z                0.753462     -0.138256  0.395875  -0.019567  0.078886
# progpasses_z            0.565356     -0.027133  0.352973   0.043536  0.216750
# takeons_z               0.387070     -0.109932  0.188674  -0.112970  0.130277
# progruns_z              0.444819     -0.134274  0.273838  -0.077819  0.022397
# tackles_z               0.711707     -0.238192  0.282342   0.020533  0.021731
# interceptions_z         1.000000     -0.151666  0.321690  -0.003149  0.141864
# clearances_z           -0.151666      1.000000  0.195994   0.277110  0.215181
# blocks_z                0.321690      0.195994  1.000000   0.027898  0.195290
# aerials_z              -0.003149      0.277110  0.027898   1.000000  0.154579
# fouls_z                 0.141864      0.215181  0.195290   0.154579  1.000000
# fouled_z                0.322961     -0.000515  0.089425   0.019594  0.261099
# nsxg_z                  0.426717     -0.412161  0.167016   0.183590  0.105059
# results                -0.148572      0.126299 -0.086947  -0.072455  0.068541
#
#                  fouled_z    nsxg_z   results
# goals_z          0.090182  0.431246 -0.621044
# xg_z             0.219895  0.674253 -0.349797
# crosses_z        0.197162  0.709666 -0.055782
# boxtouches_z     0.219019  0.870559 -0.251658
# passes_z         0.319604  0.487725 -0.178185
# progpasses_z     0.195099  0.391084 -0.056429
# takeons_z        0.330744  0.402163 -0.196351
# progruns_z       0.277075  0.487880 -0.229369
# tackles_z        0.321368  0.484134 -0.226033
# interceptions_z  0.322961  0.426717 -0.148572
# clearances_z    -0.000515 -0.412161  0.126299
# blocks_z         0.089425  0.167016 -0.086947
# aerials_z        0.019594  0.183590 -0.072455
# fouls_z          0.261099  0.105059  0.068541
# fouled_z         1.000000  0.291319 -0.146379
# nsxg_z           0.291319  1.000000 -0.274059
# results         -0.146379 -0.274059  1.000000

# %% [markdown]
# # convert to csv

# %%
df.to_csv('./WC Data Models/WC-stats.csv', index=False)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# %%
df.head()
# Out:
#     goals_z      xg_z  crosses_z  boxtouches_z  passes_z  progpasses_z  \
# 0  0.423077  0.146923  -0.136154     -0.030000  0.429231      0.037692
# 1  0.216923  0.348462   0.031538      0.158462  0.835385      0.626923
# 2  0.113846  0.392308   0.599231      0.513846  0.833077      0.405385
# 3  0.479231  0.609231   0.227692      0.450769  0.770769      0.042308
# 4  0.877692  0.773846   0.428462      0.659231  0.754615      0.335385
#
#    takeons_z  progruns_z  tackles_z  interceptions_z  clearances_z  blocks_z  \
# 0   0.244615   -0.220000   0.216154         0.270000     -0.076923 -0.097692
# 1   0.270000    0.266923   1.143846         0.834615     -0.059231 -0.134615
# 2   0.521538    1.139231   1.109231         0.859231      0.084615  0.103077
# 3   0.337692    0.927692   0.506923         1.015385      0.020769  0.381538
# 4   0.023077    0.638462   0.493846         0.637692     -0.117692 -0.033846
#
#    aerials_z   fouls_z  fouled_z    nsxg_z  results
# 0  -0.020000 -0.224615  0.100769 -0.124615        2
# 1   0.196923 -0.016923  0.033846  0.146923        1
# 2   0.683846  0.213846  0.353846  0.786923        9
# 3   0.038462  0.039231  0.022308  0.692308        5
# 4   0.572308 -0.016154 -0.096923  0.890769        5

# %%
y = df['results']

# %%
X = df.drop(columns=['results'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.20, random_state=42)

# %%
model = Ridge(alpha=1e-2).fit(X_train, y_train)
model.score(X, y)
# Out:
# 0.4012771300488499

# %%
r = permutation_importance(model, X, y, n_repeats=30, random_state=0)

# %% [markdown]
# # Permutation feature importance

# %%
scoring = ['r2', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error']
r_multi = permutation_importance(
     model, X, y, n_repeats=30, random_state=0, scoring=scoring)

for metric in r_multi:
     print(f"{metric}") 
     r = r_multi[metric]
     for i in r.importances_mean.argsort()[::-1]:
            if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
                print(f"    {X.columns[i]:<8}"
                      f"{r.importances_mean[i]:.3f}"
                      f" +/- {r.importances_std[i]:.3f}")
# Out:
# r2
#     goals_z 0.891 +/- 0.089
#     xg_z    0.056 +/- 0.017
#     fouled_z0.029 +/- 0.011
#     progruns_z0.029 +/- 0.010
#     crosses_z0.012 +/- 0.006
# neg_mean_absolute_percentage_error
#     goals_z 0.659 +/- 0.066
#     fouled_z0.039 +/- 0.016
#     progruns_z0.028 +/- 0.012
#     fouls_z 0.023 +/- 0.011
#     tackles_z0.017 +/- 0.006
# neg_mean_squared_error
#     goals_z 66.643 +/- 6.680
#     xg_z    4.222 +/- 1.289
#     fouled_z2.158 +/- 0.859
#     progruns_z2.150 +/- 0.757
#     crosses_z0.932 +/- 0.433

# %% [markdown]
# - df.shape = (158, 17)
# - Ridge Regression = 0.42629810615686115
# - r2
#     - goals_z 1.282 +/- 0.149
#     - progruns_z0.096 +/- 0.029
#     - xg_z    0.095 +/- 0.030
#     - takeons_z0.026 +/- 0.013
# - neg_mean_absolute_percentage_error
#     - goals_z 0.988 +/- 0.115
# - neg_mean_squared_error
#     - goals_z 108.981 +/- 12.672
#     - progruns_z8.139 +/- 2.494
#     - xg_z    8.047 +/- 2.509
#     - takeons_z2.195 +/- 1.067

# %% [markdown]
# - df.shape = (125, 17)
#
# - Ridge Regression = 0.4494483686544971
#
# - r2
#     - goals_z 0.982 +/- 0.123
#     - progruns_z0.132 +/- 0.039
#     - xg_z    0.056 +/- 0.017
#     - boxtouches_z0.046 +/- 0.023
#     - nsxg_z  0.039 +/- 0.013
#     - aerials_z0.031 +/- 0.014
# - neg_mean_absolute_percentage_error
#     - goals_z 0.888 +/- 0.122
#     - progruns_z0.181 +/- 0.059
# - neg_mean_squared_error
#     - goals_z 89.125 +/- 11.206
#     - progruns_z11.964 +/- 3.505
#     - xg_z    5.055 +/- 1.543
#     - boxtouches_z4.180 +/- 2.062
#     - nsxg_z  3.509 +/- 1.182
#     - aerials_z2.782 +/- 1.244

# %% [markdown]
# - df.shape = (145, 17)
# - Ridge Regression = 0.43985733944194594
#
# - r2
#     - goals_z 0.919 +/- 0.122
#     - progruns_z0.077 +/- 0.028
#     - nsxg_z  0.069 +/- 0.026
#     - boxtouches_z0.034 +/- 0.015
# - neg_mean_absolute_percentage_error
#     - goals_z 0.817 +/- 0.115
#     - progruns_z0.124 +/- 0.036
#     - tackles_z0.060 +/- 0.022
#     - boxtouches_z0.048 +/- 0.023
# - neg_mean_squared_error
#     - goals_z 78.467 +/- 10.375
#     - progruns_z6.549 +/- 2.364
#     - nsxg_z  5.854 +/- 2.186
#     - boxtouches_z2.943 +/- 1.292

# %% [markdown]
# - NMAPE = the higher the better
# - NMSE
# - R2 =  is a statistical measure of how close the data are to the fitted regression line . It is the percentage of variation (from 0 to 1) explained by the relationship between two variables.. metric that is used to evaluate the performance of a regression-based machine learning model.
