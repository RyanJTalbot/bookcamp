# %%
import pandas as pd
import numpy as np

# %%
forecast = pd.read_csv('wc_forecasts.csv')

# %%
matches = pd.read_csv('wc_matches.csv')

# %%
matches
# Out:
#           date  league_id          league         team1         team2   spi1  \
# 0   2022-11-20       1908  FIFA World Cup         Qatar       Ecuador  51.00
# 1   2022-11-21       1908  FIFA World Cup       England          Iran  85.96
# 2   2022-11-21       1908  FIFA World Cup       Senegal   Netherlands  73.84
# 3   2022-11-21       1908  FIFA World Cup           USA         Wales  74.83
# 4   2022-11-22       1908  FIFA World Cup     Argentina  Saudi Arabia  87.21
# 5   2022-11-22       1908  FIFA World Cup       Denmark       Tunisia  80.02
# 6   2022-11-22       1908  FIFA World Cup        Mexico        Poland  74.30
# 7   2022-11-22       1908  FIFA World Cup        France     Australia  87.71
# 8   2022-11-23       1908  FIFA World Cup       Morocco       Croatia  75.62
# 9   2022-11-23       1908  FIFA World Cup       Germany         Japan  88.77
# 10  2022-11-23       1908  FIFA World Cup         Spain    Costa Rica  89.51
# ...

# %%
forecast
# Out:
#          forecast_timestamp          team group       spi  global_o  global_d  \
# 0   2022-11-21 18:02:14 UTC        Brazil     G  93.54699   3.22213   0.29634
# 1   2022-11-21 18:02:14 UTC         Spain     E  89.50604   2.80203   0.38627
# 2   2022-11-21 18:02:14 UTC        France     D  87.70516   2.77362   0.47923
# 3   2022-11-21 18:02:14 UTC     Argentina     C  87.20776   2.62755   0.43170
# 4   2022-11-21 18:02:14 UTC      Portugal     H  87.77456   2.78861   0.48293
# ..                      ...           ...   ...       ...       ...       ...
# 59  2022-11-16 16:00:55 UTC  Saudi Arabia     C  56.86592   1.50018   0.99118
# 60  2022-11-16 16:00:55 UTC     Australia     D  60.83178   1.59388   0.91112
# 61  2022-11-16 16:00:55 UTC         Qatar     A  51.00223   1.57111   1.31642
# 62  2022-11-16 16:00:55 UTC         Ghana     H  58.62702   1.43347   0.85806
# 63  2022-11-16 16:00:55 UTC    Costa Rica     E  55.45518   1.39816   0.95388
#
# ...

# %%
forecast.columns
# Out:
# Index(['forecast_timestamp', 'team', 'group', 'spi', 'global_o', 'global_d',
#        'sim_wins', 'sim_ties', 'sim_losses', 'sim_goal_diff', 'goals_scored',
#        'goals_against', 'group_1', 'group_2', 'group_3', 'group_4',
#        'make_round_of_16', 'make_quarters', 'make_semis', 'make_final',
#        'win_league', 'timestamp'],
#       dtype='object')

# %%
forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   forecast_timestamp  64 non-null     object
#  1   team                64 non-null     object
#  2   group               64 non-null     object
#  3   spi                 64 non-null     float64
#  4   global_o            64 non-null     float64
#  5   global_d            64 non-null     float64
#  6   sim_wins            64 non-null     float64
#  7   sim_ties            64 non-null     float64
#  8   sim_losses          64 non-null     float64
#  9   sim_goal_diff       64 non-null     float64
#  10  goals_scored        64 non-null     float64
#  11  goals_against       64 non-null     float64
#  12  group_1             64 non-null     float64
#  13  group_2             64 non-null     float64
#  14  group_3             64 non-null     float64
# ...
