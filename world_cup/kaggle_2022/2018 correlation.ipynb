# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('wc2018.csv')

# %%
df.head()
# Out:
#           Squad  result  # Pl   Age  pass attmpt  Gls  Ast  G-PK   PK  PKatt  \
# 0  ar Argentina       9    20  29.6         65.3    4   44   360  4.0   1.50
# 1  au Australia      30    15  27.7         51.7    3   33   270  3.0   0.67
# 2    be Belgium       3    21  27.7         52.9    7   77   630  7.0   2.14
# 3     br Brazil       5    18  28.2         58.6    5   55   450  5.0   1.60
# 4   co Colombia       9    20  26.8         50.5    4   44   390  4.3   1.40
#
#    ...  xg-opp  npxg-opp  xa-opp  npxgxa-opp  xg-90-opp  xa-90-opp  \
# 0  ...       9         0    2.25        1.00       3.25       1.75
# 1  ...       5         0    1.33        0.67       2.00       1.00
# 2  ...      13         0    0.86        0.86       1.71       0.86
# 3  ...      13         0    0.40        0.40       0.80       0.40
# 4  ...       6         0    0.69        0.23       0.92       0.23
#
#    xgxa-90-opp  npxg-90-opp  npxG+xA-90-opp  results
# ...

# %%
df = df.drop(columns=['Squad'])

# %%
df.shape
# Out:
# (32, 50)

# %%
df = df.iloc[:, :49]

# %%
df.shape
# Out:
# (32, 49)

# %%
df.head()
# Out:
#    result  # Pl   Age  pass attmpt  Gls  Ast  G-PK   PK  PKatt  CrdY  ...  \
# 0       9    20  29.6         65.3    4   44   360  4.0   1.50  1.50  ...
# 1      30    15  27.7         51.7    3   33   270  3.0   0.67  0.00  ...
# 2       3    21  27.7         52.9    7   77   630  7.0   2.14  1.71  ...
# 3       5    18  28.2         58.6    5   55   450  5.0   1.60  1.40  ...
# 4       9    20  26.8         50.5    4   44   390  4.3   1.40  1.16  ...
#
#    gapk-90-opp  xg-opp  npxg-opp  xa-opp  npxgxa-opp  xg-90-opp  xa-90-opp  \
# 0            2       9         0    2.25        1.00       3.25       1.75
# 1            1       5         0    1.33        0.67       2.00       1.00
# 2            0      13         0    0.86        0.86       1.71       0.86
# 3            0      13         0    0.40        0.40       0.80       0.40
# 4            2       6         0    0.69        0.23       0.92       0.23
#
#    xgxa-90-opp  npxg-90-opp  npxG+xA-90-opp
# ...

# %%
df.corr()
# Out:
#                   result      # Pl       Age  pass attmpt       Gls       Ast  \
# result          1.000000 -0.336877  0.229903    -0.361869 -0.769540 -0.769540
# # Pl           -0.336877  1.000000 -0.067924     0.143933  0.407190  0.407190
# Age             0.229903 -0.067924  1.000000     0.040341 -0.119091 -0.119091
# pass attmpt    -0.361869  0.143933  0.040341     1.000000  0.191437  0.191437
# Gls            -0.769540  0.407190 -0.119091     0.191437  1.000000  1.000000
# Ast            -0.769540  0.407190 -0.119091     0.191437  1.000000  1.000000
# G-PK           -0.761573  0.410587 -0.105696     0.191918  0.990552  0.990552
# PK             -0.760242  0.410433 -0.105781     0.189642  0.990539  0.990539
# PKatt          -0.756635  0.351998 -0.106468     0.393155  0.737120  0.737120
# CrdY           -0.692956  0.459318  0.005367     0.421920  0.556866  0.556866
# CrdR           -0.758732  0.405345 -0.033402     0.434441  0.650089  0.650089
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.corr());

# %%
plt.figure(figsize=(108, 48))
           
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.           
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)

# Give a title to the heatmap. Pad defines the distance of the title 
#from the top of the heatmap.
        
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':52}, pad=2);

# %%
plt.figure(figsize=(108, 42))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':26}, pad=8);
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_57155/878084777.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# %%
y = df['result']

# %%
X = df.drop(columns=['result'])

# %%
X
# Out:
#     # Pl   Age  pass attmpt  Gls  Ast  G-PK   PK  PKatt  CrdY  CrdR  ...  \
# 0     20  29.6         65.3    4   44   360  4.0   1.50  1.50  1.50  ...
# 1     15  27.7         51.7    3   33   270  3.0   0.67  0.00  0.00  ...
# 2     21  27.7         52.9    7   77   630  7.0   2.14  1.71  2.00  ...
# 3     18  28.2         58.6    5   55   450  5.0   1.60  1.40  1.60  ...
# 4     20  26.8         50.5    4   44   390  4.3   1.40  1.16  1.40  ...
# 5     20  29.9         39.3    3   33   270  3.0   0.33  0.33  0.33  ...
# 6     21  28.8         56.6    7   77   720  8.0   1.63  1.00  1.50  ...
# 7     20  26.9         43.8    4   44   390  4.3   0.70  0.70  0.70  ...
# 8     16  28.9         43.3    3   33   270  3.0   0.67  0.33  0.33  ...
# 9     21  25.5         54.4    7   77   690  7.7   1.56  0.78  1.17  ...
# 10    21  25.5         48.6    7   77   630  7.0   1.71  0.86  1.29  ...
# 11    20  27.2         72.0    3   33   270  3.0   0.67  0.67  0.67  ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
import matplotlib.pyplot as plt
