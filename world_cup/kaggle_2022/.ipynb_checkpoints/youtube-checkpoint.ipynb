# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('results.csv')

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.shape
# Out:
# (39654, 9)

# %%
39654*9
# Out:
# 356886

# %%
df["home_team"].value_counts()
# Out:
# Brazil                       550
# Argentina                    535
# Germany                      495
# Mexico                       494
# England                      483
#                             ...
# Wallis Islands and Futuna      1
# Crimea                         1
# Sark                           1
# Cascadia                       1
# Kabylia                        1
# Name: home_team, Length: 291, dtype: int64

# %%
df[df["tournament"] == "FIFA World Cup"]
# Out:
#              date    home_team   away_team  home_score  away_score  \
# 1277   1930-07-13      Belgium         USA           0           3
# 1278   1930-07-13       France      Mexico           4           1
# 1279   1930-07-14       Brazil  Yugoslavia           1           2
# 1280   1930-07-14         Peru     Romania           1           3
# 1281   1930-07-15    Argentina      France           1           0
# ...           ...          ...         ...         ...         ...
# 39649  2018-06-27  Switzerland  Costa Rica           2           2
# 39650  2018-06-28        Japan      Poland           0           1
# 39651  2018-06-28      Senegal    Colombia           0           1
# 39652  2018-06-28       Panama     Tunisia           1           2
# 39653  2018-06-28      England     Belgium           0           1
#
#            tournament             city  country  neutral
# 1277   FIFA World Cup       Montevideo  Uruguay     True
# 1278   FIFA World Cup       Montevideo  Uruguay     True
# 1279   FIFA World Cup       Montevideo  Uruguay     True
# 1280   FIFA World Cup       Montevideo  Uruguay     True
# 1281   FIFA World Cup       Montevideo  Uruguay     True
# ...               ...              ...      ...      ...
# 39649  FIFA World Cup  Nizhny Novgorod   Russia     True
# 39650  FIFA World Cup        Volgograd   Russia     True
# 39651  FIFA World Cup           Samara   Russia     True
# 39652  FIFA World Cup          Saransk   Russia     True
# 39653  FIFA World Cup      Kaliningrad   Russia     True
#
# [884 rows x 9 columns]

# %%
wc = df[df["tournament"] == "FIFA World Cup"]

# %%
wc
# Out:
#              date    home_team   away_team  home_score  away_score  \
# 1277   1930-07-13      Belgium         USA           0           3
# 1278   1930-07-13       France      Mexico           4           1
# 1279   1930-07-14       Brazil  Yugoslavia           1           2
# 1280   1930-07-14         Peru     Romania           1           3
# 1281   1930-07-15    Argentina      France           1           0
# ...           ...          ...         ...         ...         ...
# 39649  2018-06-27  Switzerland  Costa Rica           2           2
# 39650  2018-06-28        Japan      Poland           0           1
# 39651  2018-06-28      Senegal    Colombia           0           1
# 39652  2018-06-28       Panama     Tunisia           1           2
# 39653  2018-06-28      England     Belgium           0           1
#
#            tournament             city  country  neutral
# 1277   FIFA World Cup       Montevideo  Uruguay     True
# 1278   FIFA World Cup       Montevideo  Uruguay     True
# 1279   FIFA World Cup       Montevideo  Uruguay     True
# 1280   FIFA World Cup       Montevideo  Uruguay     True
# 1281   FIFA World Cup       Montevideo  Uruguay     True
# ...               ...              ...      ...      ...
# 39649  FIFA World Cup  Nizhny Novgorod   Russia     True
# 39650  FIFA World Cup        Volgograd   Russia     True
# 39651  FIFA World Cup           Samara   Russia     True
# 39652  FIFA World Cup          Saransk   Russia     True
# 39653  FIFA World Cup      Kaliningrad   Russia     True
#
# [884 rows x 9 columns]

# %%
wc.describe()
# Out:
#        home_score  away_score
# count  884.000000  884.000000
# mean     1.566742    1.262443
# std      1.494824    1.320246
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    1.000000
# 75%      2.000000    2.000000
# max     10.000000    8.000000

# %%
wc = wc.drop(columns=["city", "country", "tournament", "date"])

# %%
wc
# Out:
#          home_team   away_team  home_score  away_score  neutral
# 1277       Belgium         USA           0           3     True
# 1278        France      Mexico           4           1     True
# 1279        Brazil  Yugoslavia           1           2     True
# 1280          Peru     Romania           1           3     True
# 1281     Argentina      France           1           0     True
# ...            ...         ...         ...         ...      ...
# 39649  Switzerland  Costa Rica           2           2     True
# 39650        Japan      Poland           0           1     True
# 39651      Senegal    Colombia           0           1     True
# 39652       Panama     Tunisia           1           2     True
# 39653      England     Belgium           0           1     True
#
# [884 rows x 5 columns]

# %%
wc.dtypes.value_counts()
# Out:
# object    2
# int64     2
# bool      1
# dtype: int64

# %%
wc["home_team"].value_counts()
# Out:
# Brazil                  82
# Germany                 77
# Argentina               60
# Italy                   49
# France                  37
#                         ..
# El Salvador              1
# United Arab Emirates     1
# Iraq                     1
# Canada                   1
# Panama                   1
# Name: home_team, Length: 78, dtype: int64

# %%
wc.isnull().sum().sort_values()
# Out:
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# neutral       0
# dtype: int64

# %%
wc.shape[0]
# Out:
# 884

# %%
wc.shape[1]
# Out:
# 5

# %%
hot_encode_cols = wc.dtypes[wc.dtypes==np.object]

# %%
wc_list = hot_encode_cols.index.tolist()

# %%
wc_list
# Out:
# ['home_team', 'away_team']

# %%
hot_encode_cols
# Out:
# home_team    object
# away_team    object
# dtype: object

# %%
wc
# Out:
#          home_team   away_team  home_score  away_score  neutral
# 1277       Belgium         USA           0           3     True
# 1278        France      Mexico           4           1     True
# 1279        Brazil  Yugoslavia           1           2     True
# 1280          Peru     Romania           1           3     True
# 1281     Argentina      France           1           0     True
# ...            ...         ...         ...         ...      ...
# 39649  Switzerland  Costa Rica           2           2     True
# 39650        Japan      Poland           0           1     True
# 39651      Senegal    Colombia           0           1     True
# 39652       Panama     Tunisia           1           2     True
# 39653      England     Belgium           0           1     True
#
# [884 rows x 5 columns]

# %%
data = wc.copy()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=2, include_bias=False,)
X = wc.drop(axis=1, columns=['home_score', 'away_score', 'neutral'])
X_pf = pf.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size=0.2, random_state=72018)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_20800/4095093773.py in <module>
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 pf = PolynomialFeatures(degree=2, include_bias=False,)
# ----> 3 X = pd.get_dummies(X, drop_first=True)
#       4 X_pf = pf.fit_transform(X)
#       5 X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size=0.2, random_state=72018)
#
# NameError: name 'X' is not defined
