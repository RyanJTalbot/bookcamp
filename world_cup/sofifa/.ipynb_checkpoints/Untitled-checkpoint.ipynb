# %%
import pandas as pd

# %%
# player_data = pd.read_csv('basicplayerdata.csv')
player_data = pd.read_csv('work.csv')

# %%
player_data.head()
# Out:
#        ID            Name                                             Photo  \
# 0  215223      W. Benítez  https://cdn.sofifa.net/players/215/223/22_60.png
# 1  230767  Renato Sanches  https://cdn.sofifa.net/players/230/767/22_60.png
# 2  225713     J. Augustin  https://cdn.sofifa.net/players/225/713/22_60.png
# 3  255253         Vitinha  https://cdn.sofifa.net/players/255/253/22_60.png
# 4  256197     P. Hincapié  https://cdn.sofifa.net/players/256/197/22_60.png
#
#    Nationality       Flag  Overall  Potential                 Club  \
# 0          NaN  Argentina       80         82             OGC Nice
# 1          NaN   Portugal       80         86           LOSC Lille
# 2          NaN     France       65         68            FC Nantes
# 3          NaN   Portugal       78         88             FC Porto
# 4          NaN    Ecuador       76         84  Bayer 04 Leverkusen
#
#                                  Club Logo   Value  Wage  Special
# 0   https://cdn.sofifa.net/teams/72/30.png    €18M  €32K     1281
# 1   https://cdn.sofifa.net/teams/65/30.png    €33M  €38K     2218
# 2   https://cdn.sofifa.net/teams/71/30.png     €1M   €6K     1593
# 3  https://cdn.sofifa.net/teams/236/30.png  €31.5M  €12K     1999
# 4   https://cdn.sofifa.net/teams/32/30.png    €15M  €21K     1817

# %%
player_data.drop(['Nationality'], axis=1, inplace=True)

# %%
df = player_data.rename(columns={'Flag': 'Nationality'})

# %%
df.head()
# Out:
#        ID            Name                                             Photo  \
# 0  215223      W. Benítez  https://cdn.sofifa.net/players/215/223/22_60.png
# 1  230767  Renato Sanches  https://cdn.sofifa.net/players/230/767/22_60.png
# 2  225713     J. Augustin  https://cdn.sofifa.net/players/225/713/22_60.png
# 3  255253         Vitinha  https://cdn.sofifa.net/players/255/253/22_60.png
# 4  256197     P. Hincapié  https://cdn.sofifa.net/players/256/197/22_60.png
#
#   Nationality  Overall  Potential                 Club  \
# 0   Argentina       80         82             OGC Nice
# 1    Portugal       80         86           LOSC Lille
# 2      France       65         68            FC Nantes
# 3    Portugal       78         88             FC Porto
# 4     Ecuador       76         84  Bayer 04 Leverkusen
#
#                                  Club Logo   Value  Wage  Special
# 0   https://cdn.sofifa.net/teams/72/30.png    €18M  €32K     1281
# 1   https://cdn.sofifa.net/teams/65/30.png    €33M  €38K     2218
# 2   https://cdn.sofifa.net/teams/71/30.png     €1M   €6K     1593
# 3  https://cdn.sofifa.net/teams/236/30.png  €31.5M  €12K     1999
# 4   https://cdn.sofifa.net/teams/32/30.png    €15M  €21K     1817

# %%
df.shape
# Out:
# (13500, 11)

# %%
13500*11
# Out:
# 148500

# %%
print(df['Nationality'].value_counts())
# Out:
# England              1232
# Spain                 779
# Germany               736
# Argentina             670
# France                626
#                      ...
# Philippines             1
# Malawi                  1
# Libya                   1
# Brunei Darussalam       1
# Kazakhstan              1
# Name: Nationality, Length: 151, dtype: int64

# %%
england = df[df["Nationality"] == "England"]

# %%
germany = df[df["Nationality"] == "Germany"]

# %%
spain = df[df["Nationality"] == "Spain"]

# %%
france = df[df["Nationality"] == "France"]

# %%
argentina = df[df["Nationality"] == "Argentina"]

# %%
brazil = df[df["Nationality"] == "Brazil"]

# %%
swiss = df[df["Nationality"] == "Switzerland"]

# %%
usa = df[df["Nationality"] == "USA"]

# %%
netherlands = df[df["Nationality"] == "Netherlands"]

# %%
senegal = df[df["Nationality"] == "senegal"]

# %%
ecuador = df[df["Nationality"] == "Ecuador"]

# %%
wales = df[df["Nationality"] == "Wales"]

# %%
iran = df[df["Nationality"] == "Iran"]

# %%
poland = df[df["Nationality"] == "Poland"]

# %%
mexico = df[df["Nationality"] == "Mexico"]

# %%
saudi_arabia = df[df["Nationality"] == "Saudi Arabia"]

# %%
denmark = df[df["Nationality"] == "Denmark"]

# %%
tunisia = df[df["Nationality"] == "Tunisia"]

# %%
australia = df[df["Nationality"] == "Australia"]

# %%
japan = df[df["Nationality"] == "Japan"]

# %%
costa_rica = df[df["Nationality"] == "Costa Rica"]

# %%
belgium = df[df["Nationality"] == "Belgium"]

# %%
croatia = df[df["Nationality"] == "Croatia"]

# %%
canada = df[df["Nationality"] == "Canada"]

# %%
morocco = df[df["Nationality"] == "Morocco"]

# %%
serbia = df[df["Nationality"] == "Serbia"]

# %%
cameroon = df[df["Nationality"] == "Cameroon"]

# %%
portugal = df[df["Nationality"] == "Portugal"]

# %%
uruguay = df[df["Nationality"] == "Uruguay"]

# %%
ghana = df[df["Nationality"] == "Ghana"]

# %%
korea_republic = df[df["Nationality"] == "Korea Republic"]

# %%
teams = [netherlands, senegal, ecuador, england, usa, wales, iran, 
         argentina, poland, mexico, saudi_arabia, france, denmark, tunisia, 
         australia, germany, spain, japan, costa_rica, belgium, croatia, 
         canada, morocco, brazil, swiss, serbia, cameroon, portugal, 
         uruguay, ghana, korea_republic]

# %%
wc_teams = pd.concat(teams)

# %%
wc_teams
# Out:
#            ID             Name  \
# 12     238041       T. Malacia
# 27     246104   R. Gravenberch
# 35     251805        J. Timber
# 40     239380          N. Lang
# 53     228702       F. de Jong
# ...       ...              ...
# 13492  251159  20 Lee Kyu Hyuk
# 13493  251161      21 Choi Jun
# 13494  251162   21 Kim Ju Sung
# 13495  251163  21 Lee Sang Jun
# 13496  251164       21 K. Harr
#
#                                                   Photo     Nationality  \
# 12     https://cdn.sofifa.net/players/238/041/22_60.png     Netherlands
# 27     https://cdn.sofifa.net/players/246/104/22_60.png     Netherlands
# 35     https://cdn.sofifa.net/players/251/805/22_60.png     Netherlands
# 40     https://cdn.sofifa.net/players/239/380/22_60.png     Netherlands
# 53     https://cdn.sofifa.net/players/228/702/22_60.png     Netherlands
# ...                                                 ...             ...
# 13492  https://cdn.sofifa.net/players/251/159/20_60.png  Korea Republic
# 13493  https://cdn.sofifa.net/players/251/161/21_60.png  Korea Republic
# 13494  https://cdn.sofifa.net/players/251/162/21_60.png  Korea Republic
# 13495  https://cdn.sofifa.net/players/251/163/21_60.png  Korea Republic
# 13496  https://cdn.sofifa.net/players/251/164/21_60.png  Korea Republic
#
#        Overall  Potential               Club  \
# 12          79         85          Feyenoord
# 27          78         90               Ajax
# 35          79         88               Ajax
# 40          78         85     Club Brugge KV
# 53          87         92       FC Barcelona
# ...        ...        ...                ...
# 13492       51         59     Jeju United FC
# 13493       61         72        Busan IPark
# 13494       58         73   Sangju Sangmu FC
# 13495       56         64        Busan IPark
# 13496       57         70  FC Erzgebirge Aue
#
#                                       Club Logo    Value   Wage  Special
# 12      https://cdn.sofifa.net/teams/246/30.png   €26.5M   €10K     2003
# 27      https://cdn.sofifa.net/teams/245/30.png     €33M   €11K     2085
# 35      https://cdn.sofifa.net/teams/245/30.png     €36M   €13K     1935
# 40      https://cdn.sofifa.net/teams/231/30.png   €28.5M   €27K     2012
# 53      https://cdn.sofifa.net/teams/241/30.png  €119.5M  €210K     2234
# ...                                         ...      ...    ...      ...
# 13492  https://cdn.sofifa.net/teams/1478/30.png     €50K   €700     1320
# 13493  https://cdn.sofifa.net/teams/1476/30.png    €700K   €900     1600
# 13494  https://cdn.sofifa.net/teams/2055/30.png    €450K   €900     1368
# 13495  https://cdn.sofifa.net/teams/1476/30.png    €300K   €800     1365
# 13496   https://cdn.sofifa.net/teams/506/30.png    €350K   €800      999
#
# [8201 rows x 11 columns]

# %%
wc = wc_teams.drop(['Photo', 'Club Logo', 'Club'], axis=1)

# %%
wc
# Out:
#            ID             Name     Nationality  Overall  Potential    Value  \
# 12     238041       T. Malacia     Netherlands       79         85   €26.5M
# 27     246104   R. Gravenberch     Netherlands       78         90     €33M
# 35     251805        J. Timber     Netherlands       79         88     €36M
# 40     239380          N. Lang     Netherlands       78         85   €28.5M
# 53     228702       F. de Jong     Netherlands       87         92  €119.5M
# ...       ...              ...             ...      ...        ...      ...
# 13492  251159  20 Lee Kyu Hyuk  Korea Republic       51         59     €50K
# 13493  251161      21 Choi Jun  Korea Republic       61         72    €700K
# 13494  251162   21 Kim Ju Sung  Korea Republic       58         73    €450K
# 13495  251163  21 Lee Sang Jun  Korea Republic       56         64    €300K
# 13496  251164       21 K. Harr  Korea Republic       57         70    €350K
#
#         Wage  Special
# 12      €10K     2003
# 27      €11K     2085
# 35      €13K     1935
# 40      €27K     2012
# 53     €210K     2234
# ...      ...      ...
# 13492   €700     1320
# 13493   €900     1600
# 13494   €900     1368
# 13495   €800     1365
# 13496   €800      999
#
# [8201 rows x 8 columns]

# %% [markdown]
# Teams:
# * Group A:
#     - Qatar
#     - Netherlands
#     - Senegal
#     - Ecuador
#
# * Group B:
#     - England
#     - USA
#     - Wales
#     - Iran
#
# * Group C:
#     - Argentina
#     - Poland
#     - Mexico
#     - Saudi Arabia
#
# * Group D:
#     - France
#     - Denmark
#     - Tunisia
#     - Australia
#
# * Group E:
#     - Germany
#     - Spain
#     - Canada
#     - Morocco
#
# * Group F:
#     - Belgium
#     - Croatia
#     - Canada
#     - Morocoo
#
# * Group G
#     - Brazil
#     - Switzerland
#     - Serbia
#     - Cameroon
#
# * Group H:
#     - Portugal
#     - Uruguay
#     - Ghana
#     - Korea Republic
